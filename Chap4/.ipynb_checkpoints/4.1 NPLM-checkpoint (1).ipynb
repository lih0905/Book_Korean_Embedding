# %% [markdown]
# # 4.1 NPLM (Neural Probability Language Model)
#
# NPLM을 파이토치로 구현해보자!
#
# <img src = '../images/NPLM.png' width=500>

# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

dev = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
N = 4 # n-gram의 갯수
VEC_DIM = 100 # 임베딩 차원
HIDDEN_DIM = 100 # 은닉 차원

# %% [markdown]
# ### 먼저 데이터를 벡터화부터 시작하자.

# %%
txt_path = '../data/tokenized/korquad_mecab.txt'
corpus = [sent.strip().split() for sent in open(txt_path, 'r', encoding='utf-8').readlines()]

# %%
for word in corpus[1]:
    print(word)
# Out:
# 바그너
# 는
# 괴테
# 의
# 파우스트
# 를
# 읽
# 고
# 무엇
# 을
# 쓰
# 고자
# 했
# 는가
# ?
# 교향곡

# %%
def sent_to_ngram(n, sent):
    ngrams = []
    
    for i in range(len(sent)-n+1):
        ngram = []
        for j in range(n):
            ngram.append(sent[i+j])
        ngrams.append(ngram)
            
    return ngrams

# %%
sent_to_ngram(N, corpus[1])
# Out:
# [['바그너', '는', '괴테', '의'],
#  ['는', '괴테', '의', '파우스트'],
#  ['괴테', '의', '파우스트', '를'],
#  ['의', '파우스트', '를', '읽'],
#  ['파우스트', '를', '읽', '고'],
#  ['를', '읽', '고', '무엇'],
#  ['읽', '고', '무엇', '을'],
#  ['고', '무엇', '을', '쓰'],
#  ['무엇', '을', '쓰', '고자'],
#  ['을', '쓰', '고자', '했'],
#  ['쓰', '고자', '했', '는가'],
#  ['고자', '했', '는가', '?'],
#  ['했', '는가', '?', '교향곡']]

# %% [markdown]
# 단어장과 인덱스를 만들자

# %%
vocab = set()
for i in range(len(corpus)):
    vocab.update(corpus[i])
    
len(vocab)
# Out:
# 83593

# %%
word_to_id = dict()
for word in vocab:
    word_to_id[word]=len(word_to_id)    

len(word_to_id)
# Out:
# 83593

# %%
word_to_id
# Out:
# {'Energy': 0,
#  '불효': 1,
#  '침실': 2,
#  '이후락': 3,
#  '로젠베르크': 4,
#  '염출': 5,
#  '京劇': 6,
#  '희곡집': 7,
#  '중세기': 8,
#  '조르다노': 9,
#  '간음': 10,
#  '직기': 11,
#  '축하': 12,
#  'gateau': 13,
#  '별똥별': 14,
#  '잭맨': 15,
#  '도면': 16,
#  '니스트': 17,
#  '마스다': 18,
#  '히포크라테스': 19,
#  '장강': 20,
#  '틔우': 21,
#  '富': 22,
#  '와': 23,
#  '더라고': 24,
#  '노론': 25,
#  '백스': 26,
#  '목인': 27,
#  '아모이': 28,
#  'NEADS': 29,
#  '정수론': 30,
#  '세멜레': 31,
#  'Glass': 32,
#  '전설': 33,
#  'regenerastion': 34,
#  '서반구': 35,
#  '어두우': 36,
#  '지원자': 37,
#  '조광윤': 38,
#  '올라갔으며': 39,
#  '기구': 40,
#  '라주': 41,
#  '노블레스': 42,
#  '교지': 43,
#  '비지니스': 44,
#  '냄': 45,
#  '강조': 46,
#  '쓸려가': 47,
#  '이외': 48,
#  '』」(': 49,
#  '곁들이': 50,
#  '강제집행': 51,
#  '임병직': 52,
#  '사회복음주의': 53,
#  'Selfridge': 54,
#  '묘실': 55,
#  '二障': 56,
#  '웃간': 57,
#  '인품': 58,
#  '날치기': 59,
#  '화란': 60,
#  'Bass': 61,
#  '여명': 62,
#  '찰기': 63,
#  '남레이테': 64,
#  '삐리': 65,
#  '일러스트레이션': 66,
#  '淑行': 67,
#  'Aguilera': 68,
#  '泥': 69,
#  '빛났': 70,
#  '버펄로스': 71,
#  'AAM': 72,
#  '모였': 73,
#  'whole': 74,
#  '시시덕': 75,
#  '엥케': 76,
#  '축간거리': 77,
#  'borehole': 78,
#  '공룡': 79,
#  '탈각': 80,
#  '미판': 81,
#  '옥션': 82,
#  '서광': 83,
#  'Tbps': 84,
#  '풀리': 85,
#  '운동학': 86,
#  '유저': 87,
#  '경심': 88,
#  '뼛속': 89,
#  '정금미옥': 90,
#  '부레': 91,
#  'Libra': 92,
#  '양립': 93,
#  'liǔ': 94,
#  '스라파': 95,
#  '환경': 96,
#  '슈미트': 97,
#  'would': 98,
#  'general': 99,
#  '의술': 100,
#  '지구당': 101,
#  '사각형': 102,
#  '베니치오': 103,
#  '파키스탄': 104,
#  'Catch': 105,
#  '용안': 106,
#  'KENJI': 107,
#  '屠殺': 108,
#  '구리하라': 109,
#  '김익환': 110,
#  '분청사기': 111,
#  '피어싱': 112,
#  'Wahhab': 113,
#  '겉돌': 114,
#  'Tennis': 115,
#  '머피': 116,
#  'Blegen': 117,
#  '젔는가': 118,
#  'Ding': 119,
#  'Estádio': 120,
#  '생활력': 121,
#  '저변': 122,
#  'Electronics': 123,
#  '다이옥신': 124,
#  '색': 125,
#  '신정환': 126,
#  '曲': 127,
#  'A': 128,
#  'Wrestling': 129,
#  '문화인': 130,
#  'S': 131,
#  '결혼반지': 132,
#  '조각조각': 133,
#  '增補': 134,
#  '장춘': 135,
#  'Zeitung': 136,
#  '향단': 137,
#  '벨베데레': 138,
#  '각선미': 139,
#  '유정인': 140,
#  '화단': 141,
#  '통고문': 142,
#  '화호': 143,
#  '妻': 144,
#  '불쾌감': 145,
#  '트라이아스기': 146,
#  '동량': 147,
#  '걸릴': 148,
#  '소크라테스': 149,
#  '두정': 150,
#  '날아와': 151,
#  'gnathobase': 152,
#  '거포': 153,
#  '가린다': 154,
#  '항의문': 155,
#  '어트랙션': 156,
#  'Suica': 157,
#  '크레이': 158,
#  '비상식': 159,
#  'Miri': 160,
#  '天道': 161,
#  'multikulturelle': 162,
#  '히메지': 163,
#  '이단자': 164,
#  '윤일상': 165,
#  '이해영': 166,
#  '싸돌아다니': 167,
#  '아파르트헤이트': 168,
#  '튼실': 169,
#  '프롬': 170,
#  '수크레': 171,
#  'Coss': 172,
#  'professor': 173,
#  'MIDI': 174,
#  '라비니아': 175,
#  '동박': 176,
#  '격하': 177,
#  '아열대': 178,
#  'Panaghia': 179,
#  '갈라테아': 180,
#  '로커': 181,
#  '남몰래': 182,
#  '내접': 183,
#  '풀려서': 184,
#  'λ': 185,
#  '산악회': 186,
#  '공예': 187,
#  '펜싱': 188,
#  '조형기': 189,
#  '셔벗': 190,
#  '도메': 191,
#  '표기': 192,
#  '목욕탕집': 193,
#  '炎': 194,
#  'IEG': 195,
#  '우가리트': 196,
#  '겹겹이': 197,
#  '표상': 198,
#  '유다이': 199,
#  '시험': 200,
#  '외판원': 201,
#  '살수차': 202,
#  '표징': 203,
#  '용진': 204,
#  '겹쳐질': 205,
#  '간통죄': 206,
#  'RockShow': 207,
#  'ePRIVACY': 208,
#  '탱고': 209,
#  '말갛': 210,
#  '사죄': 211,
#  '百駿圖': 212,
#  '퍼스': 213,
#  '다툼': 214,
#  '집법': 215,
#  '스치': 216,
#  '沿海': 217,
#  '우여곡절': 218,
#  '차질': 219,
#  '안겔루스': 220,
#  '미이라': 221,
#  '실버톤': 222,
#  '키아라': 223,
#  '부하': 224,
#  '입방미터': 225,
#  '근막': 226,
#  '아권': 227,
#  '여비': 228,
#  'Morse': 229,
#  'Hot': 230,
#  '메이블': 231,
#  '지명자': 232,
#  '무구': 233,
#  '才': 234,
#  '휩쓴': 235,
#  '고꾸라지': 236,
#  '가니메데': 237,
#  'Valensi': 238,
#  '東夷': 239,
#  '卷': 240,
#  'Theatre': 241,
#  '산염': 242,
#  '튜': 243,
#  '외워': 244,
#  '전진교': 245,
#  '원수정': 246,
#  '코만도르스키예': 247,
#  '전매': 248,
#  '야자수': 249,
#  '이뤄낸': 250,
#  '배회': 251,
#  '시스타': 252,
#  '버간': 253,
#  '구마토리': 254,
#  '청불': 255,
#  '빼았겼': 256,
#  'medii': 257,
#  '속옷': 258,
#  'Vosgros': 259,
#  'Odeo': 260,
#  'Keesom': 261,
#  'KU': 262,
#  '기초': 263,
#  '변함없이': 264,
#  '하가': 265,
#  'Gonzales': 266,
#  'Pacific': 267,
#  '政': 268,
#  '민공': 269,
#  '운영': 270,
#  '분카': 271,
#  '제압': 272,
#  '내부대신': 273,
#  '안구': 274,
#  '부지깽이': 275,
#  '뛰어들': 276,
#  '야단': 277,
#  '빼냈': 278,
#  '했었': 279,
#  '雲宮': 280,
#  'Jaron': 281,
#  '몰아세웠': 282,
#  'Seydlitz': 283,
#  '리미': 284,
#  '일루': 285,
#  '내려졌으며': 286,
#  'ANGEL': 287,
#  '토카막': 288,
#  'Lankler': 289,
#  '엔시나': 290,
#  '격돌': 291,
#  'Juni': 292,
#  '용기순위사': 293,
#  '전면': 294,
#  '바둑판': 295,
#  'Amiot': 296,
#  '옮기': 297,
#  '두리': 298,
#  '호흐': 299,
#  '들어준다': 300,
#  '업종': 301,
#  '錄': 302,
#  '비스': 303,
#  '복수': 304,
#  'AIBA': 305,
#  '바이패스': 306,
#  'staer': 307,
#  '태양광': 308,
#  '원반': 309,
#  '엄미리': 310,
#  '벌여': 311,
#  '藏': 312,
#  '조영철': 313,
#  '급강하': 314,
#  'Nurhaliza': 315,
#  '工法': 316,
#  '務': 317,
#  '이수': 318,
#  '증이': 319,
#  '스토클리': 320,
#  '이안': 321,
#  '가모프': 322,
#  '쇠악': 323,
#  '출원자': 324,
#  '멘': 325,
#  '시공법': 326,
#  '나옵니까': 327,
#  '和合': 328,
#  '체현': 329,
#  '주입식': 330,
#  '스폿': 331,
#  '대타협': 332,
#  '감투': 333,
#  '정희철': 334,
#  '어벤져스': 335,
#  '복근': 336,
#  '추적추적': 337,
#  'Lawrence': 338,
#  '장괴': 339,
#  '이사부': 340,
#  '대격': 341,
#  '순군': 342,
#  '황남': 343,
#  '켓': 344,
#  '백미러': 345,
#  '山': 346,
#  '피오': 347,
#  '덧셈': 348,
#  '아뢰야식': 349,
#  'ny': 350,
#  '梅毒': 351,
#  'Crown': 352,
#  '커싱': 353,
#  '떠날까': 354,
#  'Ginger': 355,
#  '수도관': 356,
#  '레기아': 357,
#  '대국인': 358,
#  '체스터': 359,
#  '문예학': 360,
#  '훈련장': 361,
#  '눈금': 362,
#  '이낙선': 363,
#  '키클롭스': 364,
#  '비율': 365,
#  '등식': 366,
#  '묘금': 367,
#  '헤시오도스': 368,
#  '내리치': 369,
#  '모래알': 370,
#  '순교': 371,
#  '반공': 372,
#  '파면': 373,
#  '리스본': 374,
#  '동년배': 375,
#  '후쿠': 376,
#  '불량기': 377,
#  'ακτίς': 378,
#  '과로': 379,
#  'USAspending': 380,
#  '번데기': 381,
#  '⑤': 382,
#  '게이머': 383,
#  '친했': 384,
#  '신났': 385,
#  'collaborative': 386,
#  'Commonwealth': 387,
#  '베유': 388,
#  '평등주의': 389,
#  '오이': 390,
#  '묻힐까': 391,
#  '망하': 392,
#  '날아오를': 393,
#  '신덕': 394,
#  '제작자': 395,
#  '시사회': 396,
#  '에조': 397,
#  '빼들': 398,
#  '며칠': 399,
#  '타운센트': 400,
#  '일라이자': 401,
#  '서의': 402,
#  '작단': 403,
#  '요시하루': 404,
#  '에선': 405,
#  '라고도': 406,
#  '겐키치': 407,
#  '사쿠라이': 408,
#  '輯': 409,
#  '國父': 410,
#  '후지무라': 411,
#  '어느': 412,
#  'Two': 413,
#  '면책특권': 414,
#  '다이빙궈': 415,
#  '난전': 416,
#  'stab': 417,
#  '그런고로': 418,
#  '갔으며': 419,
#  '낵': 420,
#  '최병도': 421,
#  '브루스터': 422,
#  'unicity': 423,
#  '節': 424,
#  '제이컵': 425,
#  'humifusa': 426,
#  '박만수': 427,
#  '클라이맥스': 428,
#  'Davis': 429,
#  '메노': 430,
#  '거머쥐': 431,
#  '봉황': 432,
#  '장필화': 433,
#  'enter': 434,
#  'heterokonts': 435,
#  '달랑베르': 436,
#  'for': 437,
#  '강운태': 438,
#  '부왕령': 439,
#  'Hermione': 440,
#  '아키나': 441,
#  'information': 442,
#  '듀스': 443,
#  '성악곡': 444,
#  '지부티': 445,
#  '대파': 446,
#  '工房': 447,
#  '랜서': 448,
#  '공범자': 449,
#  '고법': 450,
#  '삼위일체': 451,
#  '도시조': 452,
#  '포브스': 453,
#  '국회법': 454,
#  'Butera': 455,
#  '플라테': 456,
#  '프레드릭': 457,
#  '순수히': 458,
#  '공림': 459,
#  '숭정제': 460,
#  '정진영': 461,
#  '다스릴': 462,
#  '연구가': 463,
#  '곤궁': 464,
#  '조형익': 465,
#  '트리오': 466,
#  '소녀시대-태티서': 467,
#  'specialty': 468,
#  '홍색': 469,
#  '왼편': 470,
#  '한애순': 471,
#  'Fight': 472,
#  '야스코': 473,
#  '조준각': 474,
#  '몰라': 475,
#  '국경일': 476,
#  '아디스아바바': 477,
#  '대': 478,
#  '지린': 479,
#  '노르아드레날린': 480,
#  '식부성': 481,
#  '세라이': 482,
#  '面': 483,
#  'Unionspolitik': 484,
#  '스타즈': 485,
#  '가을철': 486,
#  '골퍼': 487,
#  '발라서': 488,
#  '유한회사': 489,
#  '정밀': 490,
#  '어여쁜': 491,
#  '울라마': 492,
#  '사과드린다': 493,
#  '서유견문': 494,
#  '단발령': 495,
#  '끝남': 496,
#  '이범석': 497,
#  '뎃페이': 498,
#  '카이두': 499,
#  '속인': 500,
#  '야영지': 501,
#  'cuts': 502,
#  '나무껍질': 503,
#  '천만': 504,
#  'Laughing': 505,
#  '유상훈': 506,
#  'Blanketmen': 507,
#  'Lemdadella': 508,
#  '자형': 509,
#  '公卿': 510,
#  'Nudo': 511,
#  'Rhipidura': 512,
#  '신구': 513,
#  '라토': 514,
#  '-〉(': 515,
#  'natural': 516,
#  '거느렸': 517,
#  '첼스': 518,
#  '지엄': 519,
#  '사업비': 520,
#  '）,': 521,
#  '비대위': 522,
#  '換局': 523,
#  '빼먹': 524,
#  '브룬': 525,
#  '함석헌': 526,
#  '주요부': 527,
#  '恩顧': 528,
#  '태평': 529,
#  'Internatinal': 530,
#  '밑도': 531,
#  '팽팽': 532,
#  '둘러': 533,
#  'ARS': 534,
#  '앙수': 535,
#  '뉴요커': 536,
#  '리버사이드': 537,
#  '총강': 538,
#  'INLA': 539,
#  '돔구장': 540,
#  '일류': 541,
#  '진경지': 542,
#  'shelter': 543,
#  '트임': 544,
#  'Without': 545,
#  '구락부': 546,
#  '범양': 547,
#  '협객': 548,
#  '뵈르트': 549,
#  '심청': 550,
#  'Offenburger': 551,
#  '자술서': 552,
#  '민감': 553,
#  '톰보이': 554,
#  '聚落': 555,
#  '톨텍': 556,
#  'recruitment': 557,
#  '방정식': 558,
#  '진성준': 559,
#  'ɣ': 560,
#  '빙글빙글': 561,
#  '화력': 562,
#  'Octopus': 563,
#  '복잡다기': 564,
#  '니르': 565,
#  '플로리안': 566,
#  '할둔': 567,
#  '생과': 568,
#  'Hallikainen': 569,
#  '영력': 570,
#  'Adrianus': 571,
#  '보수파': 572,
#  '분라쿠': 573,
#  '허가윤': 574,
#  '착륙': 575,
#  'Wade': 576,
#  '마담': 577,
#  'tinnunculus': 578,
#  '한국프로축구연맹': 579,
#  '차량': 580,
#  '콜린': 581,
#  '열병식': 582,
#  '패디': 583,
#  '♭': 584,
#  '마우': 585,
#  '끝내': 586,
#  '양성매념': 587,
#  '국학자': 588,
#  '카타리나': 589,
#  '가져간다는': 590,
#  '형주': 591,
#  '릴리앙': 592,
#  '해운': 593,
#  '삼광': 594,
#  '실축': 595,
#  '浮世': 596,
#  'Liar': 597,
#  '해밀': 598,
#  '가즈히사': 599,
#  '절하': 600,
#  'surface': 601,
#  '似': 602,
#  '리파': 603,
#  '가도': 604,
#  '객석': 605,
#  '살색': 606,
#  '강호동': 607,
#  '값': 608,
#  '절호': 609,
#  '조촐': 610,
#  '발지': 611,
#  '창백': 612,
#  '감군': 613,
#  '충적': 614,
#  '진물': 615,
#  '키엘리니': 616,
#  '학식': 617,
#  '하운드': 618,
#  '김응석': 619,
#  '監營': 620,
#  '금괴': 621,
#  '으머': 622,
#  '딕슨': 623,
#  '상운': 624,
#  '우사마': 625,
#  '통감': 626,
#  '琬': 627,
#  '쇼니족': 628,
#  '구인장': 629,
#  '로게': 630,
#  '可': 631,
#  '므트와라지역': 632,
#  '기엔': 633,
#  '공간': 634,
#  '뒤덮일': 635,
#  '새로이': 636,
#  'Europe': 637,
#  '음파': 638,
#  '이정식': 639,
#  'Use': 640,
#  '몬트리올': 641,
#  '마테': 642,
#  '다져졌': 643,
#  '식관': 644,
#  '督軍': 645,
#  '동역자': 646,
#  '겨울': 647,
#  '연세': 648,
#  'Stare': 649,
#  'Eight': 650,
#  '잉골슈타트': 651,
#  '순작': 652,
#  '넘어지': 653,
#  '좌익선': 654,
#  '實刑': 655,
#  'Danny': 656,
#  '루이사': 657,
#  '성분': 658,
#  '메릿': 659,
#  'Partridge': 660,
#  'classic': 661,
#  '로레': 662,
#  '에구치': 663,
#  '戰役': 664,
#  '소수자': 665,
#  'MKMF': 666,
#  '的': 667,
#  '이큐': 668,
#  '서두르': 669,
#  '인근': 670,
#  '계십니다': 671,
#  '유카탄': 672,
#  '梨子': 673,
#  '끓는점': 674,
#  '김애란': 675,
#  '따돌리': 676,
#  '산화나트륨': 677,
#  '비키': 678,
#  'Wachensturm': 679,
#  '취한다': 680,
#  '눌린': 681,
#  '벤다': 682,
#  '박태순': 683,
#  '켜진': 684,
#  '대방': 685,
#  '왈가왈부': 686,
#  '지독': 687,
#  '아비코': 688,
#  '안전여객': 689,
#  '악곡': 690,
#  '아오': 691,
#  '고했': 692,
#  '레이아웃': 693,
#  '오스먼트': 694,
#  'outrage': 695,
#  '일절': 696,
#  '해와': 697,
#  '저성장': 698,
#  '정경석': 699,
#  '낵스': 700,
#  '사이언': 701,
#  '메시지': 702,
#  'Spirit': 703,
#  '판테온': 704,
#  '아이코': 705,
#  '신지식인': 706,
#  '원미구': 707,
#  '틀릴': 708,
#  '인터내셔널': 709,
#  '크릴새우': 710,
#  '광우병': 711,
#  '拍子': 712,
#  '아스': 713,
#  '도트': 714,
#  '진열관': 715,
#  '적서': 716,
#  '탄피': 717,
#  '라꼬': 718,
#  '증한': 719,
#  '四書義': 720,
#  '성자': 721,
#  '제논': 722,
#  '도체': 723,
#  '새먼': 724,
#  '탁본': 725,
#  '삼지연': 726,
#  '내려앉': 727,
#  '가리킨다고': 728,
#  '臟': 729,
#  'this': 730,
#  '획기적으로': 731,
#  'Mythologie': 732,
#  '후시': 733,
#  '뤼터': 734,
#  '잿': 735,
#  '류성룡': 736,
#  '동악': 737,
#  '밀항': 738,
#  '朴': 739,
#  '햘일': 740,
#  '이한영': 741,
#  '익혀': 742,
#  '콘스탄티노폴리스': 743,
#  'Ferdinand': 744,
#  'flip': 745,
#  'Smoker': 746,
#  'such': 747,
#  '신윤창': 748,
#  '애머스트': 749,
#  '종정부': 750,
#  '잡동사니': 751,
#  '잡지사': 752,
#  '케어': 753,
#  '묘당': 754,
#  'BOOMERANG': 755,
#  '%(': 756,
#  '성가시': 757,
#  '플레어': 758,
#  '정모': 759,
#  'Pantev': 760,
#  '모루': 761,
#  '여중생': 762,
#  '다관': 763,
#  'grandeur': 764,
#  '끌어올리': 765,
#  '친할머니': 766,
#  '비친다': 767,
#  'Köpenick': 768,
#  'Tèbié': 769,
#  '아까워': 770,
#  '모조': 771,
#  '방문단': 772,
#  '중쇠': 773,
#  '김영룡': 774,
#  'Povera': 775,
#  'Märzregierung': 776,
#  'Aristoxenus': 777,
#  '발기인': 778,
#  '카탈루냐': 779,
#  '眞否': 780,
#  '드라기': 781,
#  '가림성': 782,
#  '오인한': 783,
#  '더없이': 784,
#  '본고사': 785,
#  '植': 786,
#  'Alan': 787,
#  'Lotto': 788,
#  '樹冠': 789,
#  '천황제': 790,
#  '짝꿍': 791,
#  '광진': 792,
#  'Palo': 793,
#  '비웃': 794,
#  'affaire': 795,
#  '거친다': 796,
#  '헤이키': 797,
#  '괵': 798,
#  '产': 799,
#  '도나우': 800,
#  '접해본': 801,
#  '금월': 802,
#  '코르노': 803,
#  '천만에': 804,
#  '실질': 805,
#  '노토': 806,
#  '교향악축제': 807,
#  '컸으며': 808,
#  '코앞': 809,
#  'bourgeoisie': 810,
#  '쳤으나': 811,
#  'Helter': 812,
#  '萬人': 813,
#  '한모': 814,
#  '戌': 815,
#  '리아': 816,
#  '수천': 817,
#  '\'"': 818,
#  '선부동': 819,
#  '케호': 820,
#  '동중서': 821,
#  '데빌드': 822,
#  '현주': 823,
#  '낮춰': 824,
#  '추석': 825,
#  '제휴': 826,
#  '외과의사': 827,
#  '오데사': 828,
#  '한카이': 829,
#  'FinFET': 830,
#  '정청래': 831,
#  '위성': 832,
#  '맥마스터': 833,
#  '해변가': 834,
#  '헤어나': 835,
#  '아고라': 836,
#  '고위직': 837,
#  '將': 838,
#  '뜸해졌': 839,
#  '수두': 840,
#  '천안시': 841,
#  '육박전': 842,
#  '톈좡좡': 843,
#  'HIT': 844,
#  '로젠버그': 845,
#  '소비물': 846,
#  '레안드루': 847,
#  '더콰이엇': 848,
#  'Dizzee': 849,
#  '장하진': 850,
#  '마사타케': 851,
#  '되돌아온다': 852,
#  '탐했': 853,
#  'applied': 854,
#  '김형호': 855,
#  '섭리': 856,
#  '하여간': 857,
#  '맵시': 858,
#  '맡겼으나': 859,
#  'LinguaExpress': 860,
#  '十廻向': 861,
#  '견주': 862,
#  'Tolstoy': 863,
#  '최연성': 864,
#  '근거지': 865,
#  '한밭': 866,
#  '신구약': 867,
#  '주장자': 868,
#  '헬리오': 869,
#  '~〉': 870,
#  '律': 871,
#  '신파': 872,
#  '자한': 873,
#  '제크': 874,
#  'Basichis': 875,
#  '샤를로트': 876,
#  'executing': 877,
#  '할': 878,
#  '카로': 879,
#  '정서': 880,
#  '책망': 881,
#  '참이슬': 882,
#  '식물원': 883,
#  '純': 884,
#  '오르도비스기': 885,
#  '입기': 886,
#  '증광': 887,
#  '쟤': 888,
#  '신동윤': 889,
#  '줄기차': 890,
#  '랃틴어로': 891,
#  '우안': 892,
#  'Firaxis': 893,
#  '돌릴': 894,
#  '스스로': 895,
#  '피비': 896,
#  'Touring': 897,
#  '박물학': 898,
#  '데려가': 899,
#  '화랑': 900,
#  'curve': 901,
#  '세븐': 902,
#  '암초': 903,
#  '예절': 904,
#  '견딜': 905,
#  '몬태나': 906,
#  'Rhinae': 907,
#  '잔재': 908,
#  '오버바이에른': 909,
#  'TN': 910,
#  'IMAX': 911,
#  '종교관': 912,
#  'Police': 913,
#  'Verfassungsvernichtung': 914,
#  '이야기': 915,
#  '판매액': 916,
#  '아우슈비츠': 917,
#  '끊기': 918,
#  '뚜렷히': 919,
#  'MLB': 920,
#  '앞날': 921,
#  '니끼': 922,
#  '토속': 923,
#  '뼈': 924,
#  '증권사': 925,
#  '울워스': 926,
#  'Esslingen': 927,
#  '호외': 928,
#  '충복': 929,
#  '넋': 930,
#  'Mixtape': 931,
#  'Lóch': 932,
#  '추도기': 933,
#  '맥길': 934,
#  '々)': 935,
#  '젔던': 936,
#  '우사인': 937,
#  '결정': 938,
#  '덴쇼': 939,
#  '소라탑': 940,
#  '백승주': 941,
#  '心氣': 942,
#  'Gēbāopí': 943,
#  '반소': 944,
#  '윤사윤': 945,
#  '구혼': 946,
#  '복원성': 947,
#  '키스': 948,
#  '코펜하겐': 949,
#  '정준': 950,
#  '트라파니': 951,
#  '추자': 952,
#  '墻': 953,
#  '항성목록': 954,
#  '동궤': 955,
#  '영화상': 956,
#  '폰투스': 957,
#  '고분군': 958,
#  '國防': 959,
#  '강경': 960,
#  '파이어': 961,
#  'Advisory': 962,
#  '죠': 963,
#  '한풀이': 964,
#  '유키요시': 965,
#  '김일성': 966,
#  '살아난다': 967,
#  '큰딸': 968,
#  '증거력': 969,
#  '파더': 970,
#  '베로니카': 971,
#  '배기': 972,
#  '트레이': 973,
#  '짜여져': 974,
#  '못했었': 975,
#  '다친다': 976,
#  '濉': 977,
#  '컨트롤': 978,
#  'Wojsko': 979,
#  '화진포': 980,
#  'superfamily': 981,
#  '신채호': 982,
#  '공동묘지': 983,
#  '데몬': 984,
#  '낮춘': 985,
#  '암브로시니': 986,
#  '범하': 987,
#  '파견대': 988,
#  '다중화': 989,
#  '리크': 990,
#  '모양': 991,
#  '내옹': 992,
#  '후삼국': 993,
#  '정성일': 994,
#  '상반기': 995,
#  '보초': 996,
#  '진전': 997,
#  '플라인': 998,
#  '학명': 999,
#  ...}

# %%
id_to_word = []
for word in word_to_id.keys():
    id_to_word.append(word)

# %% [markdown]
# 훈련 데이터를 만들자

# %%
train_data = []
for i in range(len(corpus)):
    train_data += sent_to_ngram(N, corpus[i])

# %%
train_data
# Out:
# [['1', '8', '3', '9'],
#  ['8', '3', '9', '년'],
#  ['3', '9', '년', '바그너'],
#  ['9', '년', '바그너', '는'],
#  ['년', '바그너', '는', '괴테'],
#  ['바그너', '는', '괴테', '의'],
#  ['는', '괴테', '의', '파우스트'],
#  ['괴테', '의', '파우스트', '을'],
#  ['의', '파우스트', '을', '처음'],
#  ['파우스트', '을', '처음', '읽'],
#  ['을', '처음', '읽', '고'],
#  ['처음', '읽', '고', '그'],
#  ['읽', '고', '그', '내용'],
#  ['고', '그', '내용', '에'],
#  ['그', '내용', '에', '마음'],
#  ['내용', '에', '마음', '이'],
#  ['에', '마음', '이', '끌려'],
#  ['마음', '이', '끌려', '이'],
#  ['이', '끌려', '이', '를'],
#  ['끌려', '이', '를', '소재'],
#  ['이', '를', '소재', '로'],
#  ['를', '소재', '로', '해서'],
#  ['소재', '로', '해서', '하나'],
#  ['로', '해서', '하나', '의'],
#  ['해서', '하나', '의', '교향곡'],
#  ['하나', '의', '교향곡', '을'],
#  ['의', '교향곡', '을', '쓰'],
#  ['교향곡', '을', '쓰', '려는'],
#  ['을', '쓰', '려는', '뜻'],
#  ['쓰', '려는', '뜻', '을'],
#  ['려는', '뜻', '을', '갖'],
#  ['뜻', '을', '갖', '는다'],
#  ['을', '갖', '는다', '.'],
#  ['갖', '는다', '.', '이'],
#  ['는다', '.', '이', '시기'],
#  ['.', '이', '시기', '바그너'],
#  ['이', '시기', '바그너', '는'],
#  ['시기', '바그너', '는', '1'],
#  ['바그너', '는', '1', '8'],
#  ['는', '1', '8', '3'],
#  ['1', '8', '3', '8'],
#  ['8', '3', '8', '년'],
#  ['3', '8', '년', '에'],
#  ['8', '년', '에', '빛'],
#  ['년', '에', '빛', '독촉'],
#  ['에', '빛', '독촉', '으로'],
#  ['빛', '독촉', '으로', '산전수전'],
#  ['독촉', '으로', '산전수전', '을'],
#  ['으로', '산전수전', '을', '다'],
#  ['산전수전', '을', '다', '걲은'],
#  ['을', '다', '걲은', '상황'],
#  ['다', '걲은', '상황', '이'],
#  ['걲은', '상황', '이', '라'],
#  ['상황', '이', '라', '좌절'],
#  ['이', '라', '좌절', '과'],
#  ['라', '좌절', '과', '실망'],
#  ['좌절', '과', '실망', '에'],
#  ['과', '실망', '에', '가득'],
#  ['실망', '에', '가득', '했으며'],
#  ['에', '가득', '했으며', '메피스토펠레스'],
#  ['가득', '했으며', '메피스토펠레스', '를'],
#  ['했으며', '메피스토펠레스', '를', '만나'],
#  ['메피스토펠레스', '를', '만나', '는'],
#  ['를', '만나', '는', '파우스트'],
#  ['만나', '는', '파우스트', '의'],
#  ['는', '파우스트', '의', '심경'],
#  ['파우스트', '의', '심경', '에'],
#  ['의', '심경', '에', '공감'],
#  ['심경', '에', '공감', '했'],
#  ['에', '공감', '했', '다고'],
#  ['공감', '했', '다고', '한다'],
#  ['했', '다고', '한다', '.'],
#  ['다고', '한다', '.', '또한'],
#  ['한다', '.', '또한', '파리'],
#  ['.', '또한', '파리', '에서'],
#  ['또한', '파리', '에서', '아'],
#  ['파리', '에서', '아', '브네'],
#  ['에서', '아', '브네', '크'],
#  ['아', '브네', '크', '의'],
#  ['브네', '크', '의', '지휘'],
#  ['크', '의', '지휘', '로'],
#  ['의', '지휘', '로', '파리'],
#  ['지휘', '로', '파리', '음악원'],
#  ['로', '파리', '음악원', '관현악단'],
#  ['파리', '음악원', '관현악단', '이'],
#  ['음악원', '관현악단', '이', '연주'],
#  ['관현악단', '이', '연주', '하'],
#  ['이', '연주', '하', '는'],
#  ['연주', '하', '는', '베토벤'],
#  ['하', '는', '베토벤', '의'],
#  ['는', '베토벤', '의', '교향곡'],
#  ['베토벤', '의', '교향곡', '9'],
#  ['의', '교향곡', '9', '번'],
#  ['교향곡', '9', '번', '을'],
#  ['9', '번', '을', '듣'],
#  ['번', '을', '듣', '고'],
#  ['을', '듣', '고', '깊'],
#  ['듣', '고', '깊', '은'],
#  ['고', '깊', '은', '감명'],
#  ['깊', '은', '감명', '을'],
#  ['은', '감명', '을', '받'],
#  ['감명', '을', '받', '았'],
#  ['을', '받', '았', '는데'],
#  ['받', '았', '는데', ','],
#  ['았', '는데', ',', '이것'],
#  ['는데', ',', '이것', '이'],
#  [',', '이것', '이', '이듬해'],
#  ['이것', '이', '이듬해', '1'],
#  ['이', '이듬해', '1', '월'],
#  ['이듬해', '1', '월', '에'],
#  ['1', '월', '에', '파우스트'],
#  ['월', '에', '파우스트', '의'],
#  ['에', '파우스트', '의', '서곡'],
#  ['파우스트', '의', '서곡', '으로'],
#  ['의', '서곡', '으로', '쓰여진'],
#  ['서곡', '으로', '쓰여진', '이'],
#  ['으로', '쓰여진', '이', '작품'],
#  ['쓰여진', '이', '작품', '에'],
#  ['이', '작품', '에', '조금'],
#  ['작품', '에', '조금', '이'],
#  ['에', '조금', '이', '라도'],
#  ['조금', '이', '라도', '영향'],
#  ['이', '라도', '영향', '을'],
#  ['라도', '영향', '을', '끼쳤'],
#  ['영향', '을', '끼쳤', '으리라는'],
#  ['을', '끼쳤', '으리라는', '것'],
#  ['끼쳤', '으리라는', '것', '은'],
#  ['으리라는', '것', '은', '의심'],
#  ['것', '은', '의심', '할'],
#  ['은', '의심', '할', '여지'],
#  ['의심', '할', '여지', '가'],
#  ['할', '여지', '가', '없'],
#  ['여지', '가', '없', '다'],
#  ['가', '없', '다', '.'],
#  ['없', '다', '.', '여기'],
#  ['다', '.', '여기', '의'],
#  ['.', '여기', '의', '라단조'],
#  ['여기', '의', '라단조', '조성'],
#  ['의', '라단조', '조성', '의'],
#  ['라단조', '조성', '의', '경우'],
#  ['조성', '의', '경우', '에'],
#  ['의', '경우', '에', '도'],
#  ['경우', '에', '도', '그'],
#  ['에', '도', '그', '의'],
#  ['도', '그', '의', '전기'],
#  ['그', '의', '전기', '에'],
#  ['의', '전기', '에', '적혀'],
#  ['전기', '에', '적혀', '있'],
#  ['에', '적혀', '있', '는'],
#  ['적혀', '있', '는', '것'],
#  ['있', '는', '것', '처럼'],
#  ['는', '것', '처럼', '단순'],
#  ['것', '처럼', '단순', '한'],
#  ['처럼', '단순', '한', '정신'],
#  ['단순', '한', '정신', '적'],
#  ['한', '정신', '적', '피로'],
#  ['정신', '적', '피로', '나'],
#  ['적', '피로', '나', '실의'],
#  ['피로', '나', '실의', '가'],
#  ['나', '실의', '가', '반영'],
#  ['실의', '가', '반영', '된'],
#  ['가', '반영', '된', '것'],
#  ['반영', '된', '것', '이'],
#  ['된', '것', '이', '아니'],
#  ['것', '이', '아니', '라'],
#  ['이', '아니', '라', '베토벤'],
#  ['아니', '라', '베토벤', '의'],
#  ['라', '베토벤', '의', '합창'],
#  ['베토벤', '의', '합창', '교향곡'],
#  ['의', '합창', '교향곡', '조성'],
#  ['합창', '교향곡', '조성', '의'],
#  ['교향곡', '조성', '의', '영향'],
#  ['조성', '의', '영향', '을'],
#  ['의', '영향', '을', '받'],
#  ['영향', '을', '받', '은'],
#  ['을', '받', '은', '것'],
#  ['받', '은', '것', '을'],
#  ['은', '것', '을', '볼'],
#  ['것', '을', '볼', '수'],
#  ['을', '볼', '수', '있'],
#  ['볼', '수', '있', '다'],
#  ['수', '있', '다', '.'],
#  ['있', '다', '.', '그렇게'],
#  ['다', '.', '그렇게', '교향곡'],
#  ['.', '그렇게', '교향곡', '작곡'],
#  ['그렇게', '교향곡', '작곡', '을'],
#  ['교향곡', '작곡', '을', '1'],
#  ['작곡', '을', '1', '8'],
#  ['을', '1', '8', '3'],
#  ['1', '8', '3', '9'],
#  ['8', '3', '9', '년'],
#  ['3', '9', '년', '부터'],
#  ['9', '년', '부터', '4'],
#  ['년', '부터', '4', '0'],
#  ['부터', '4', '0', '년'],
#  ['4', '0', '년', '에'],
#  ['0', '년', '에', '걸쳐'],
#  ['년', '에', '걸쳐', '파리'],
#  ['에', '걸쳐', '파리', '에서'],
#  ['걸쳐', '파리', '에서', '착수'],
#  ['파리', '에서', '착수', '했으나'],
#  ['에서', '착수', '했으나', '1'],
#  ['착수', '했으나', '1', '악장'],
#  ['했으나', '1', '악장', '을'],
#  ['1', '악장', '을', '쓴'],
#  ['악장', '을', '쓴', '뒤'],
#  ['을', '쓴', '뒤', '에'],
#  ['쓴', '뒤', '에', '중단'],
#  ['뒤', '에', '중단', '했'],
#  ['에', '중단', '했', '다'],
#  ['중단', '했', '다', '.'],
#  ['했', '다', '.', '또한'],
#  ['다', '.', '또한', '작품'],
#  ['.', '또한', '작품', '의'],
#  ['또한', '작품', '의', '완성'],
#  ['작품', '의', '완성', '과'],
#  ['의', '완성', '과', '동시'],
#  ['완성', '과', '동시', '에'],
#  ['과', '동시', '에', '그'],
#  ['동시', '에', '그', '는'],
#  ['에', '그', '는', '이'],
#  ['그', '는', '이', '서곡'],
#  ['는', '이', '서곡', '('],
#  ['이', '서곡', '(', '1'],
#  ['서곡', '(', '1', '악장'],
#  ['(', '1', '악장', ')'],
#  ['1', '악장', ')', '을'],
#  ['악장', ')', '을', '파리'],
#  [')', '을', '파리', '음악원'],
#  ['을', '파리', '음악원', '의'],
#  ['파리', '음악원', '의', '연주회'],
#  ['음악원', '의', '연주회', '에서'],
#  ['의', '연주회', '에서', '연주'],
#  ['연주회', '에서', '연주', '할'],
#  ['에서', '연주', '할', '파트'],
#  ['연주', '할', '파트', '보'],
#  ['할', '파트', '보', '까지'],
#  ['파트', '보', '까지', '준비'],
#  ['보', '까지', '준비', '하'],
#  ['까지', '준비', '하', '였으나'],
#  ['준비', '하', '였으나', ','],
#  ['하', '였으나', ',', '실제로'],
#  ['였으나', ',', '실제로', '는'],
#  [',', '실제로', '는', '이루'],
#  ['실제로', '는', '이루', '어'],
#  ['는', '이루', '어', '지지'],
#  ['이루', '어', '지지', '는'],
#  ['어', '지지', '는', '않'],
#  ['지지', '는', '않', '았'],
#  ['는', '않', '았', '다'],
#  ['않', '았', '다', '.'],
#  ['았', '다', '.', '결국'],
#  ['다', '.', '결국', '초연'],
#  ['.', '결국', '초연', '은'],
#  ['결국', '초연', '은', '4'],
#  ['초연', '은', '4', '년'],
#  ['은', '4', '년', '반'],
#  ['4', '년', '반', '이'],
#  ['년', '반', '이', '지난'],
#  ['반', '이', '지난', '후'],
#  ['이', '지난', '후', '에'],
#  ['지난', '후', '에', '드레스덴'],
#  ['후', '에', '드레스덴', '에서'],
#  ['에', '드레스덴', '에서', '연주'],
#  ['드레스덴', '에서', '연주', '되'],
#  ['에서', '연주', '되', '었'],
#  ['연주', '되', '었', '고'],
#  ['되', '었', '고', '재연'],
#  ['었', '고', '재연', '도'],
#  ['고', '재연', '도', '이루'],
#  ['재연', '도', '이루', '어'],
#  ['도', '이루', '어', '졌'],
#  ['이루', '어', '졌', '지만'],
#  ['어', '졌', '지만', ','],
#  ['졌', '지만', ',', '이후'],
#  ['지만', ',', '이후', '에'],
#  [',', '이후', '에', '그대로'],
#  ['이후', '에', '그대로', '방치'],
#  ['에', '그대로', '방치', '되'],
#  ['그대로', '방치', '되', '고'],
#  ['방치', '되', '고', '말'],
#  ['되', '고', '말', '았'],
#  ['고', '말', '았', '다'],
#  ['말', '았', '다', '.'],
#  ['았', '다', '.', '그'],
#  ['다', '.', '그', '사이'],
#  ['.', '그', '사이', '에'],
#  ['그', '사이', '에', '그'],
#  ['사이', '에', '그', '는'],
#  ['에', '그', '는', '리엔치'],
#  ['그', '는', '리엔치', '와'],
#  ['는', '리엔치', '와', '방황'],
#  ['리엔치', '와', '방황', '하'],
#  ['와', '방황', '하', '는'],
#  ['방황', '하', '는', '네덜란드인'],
#  ['하', '는', '네덜란드인', '을'],
#  ['는', '네덜란드인', '을', '완성'],
#  ['네덜란드인', '을', '완성', '하'],
#  ['을', '완성', '하', '고'],
#  ['완성', '하', '고', '탄호이저'],
#  ['하', '고', '탄호이저', '에'],
#  ['고', '탄호이저', '에', '도'],
#  ['탄호이저', '에', '도', '착수'],
#  ['에', '도', '착수', '하'],
#  ['도', '착수', '하', '는'],
#  ['착수', '하', '는', '등'],
#  ['하', '는', '등', '분주'],
#  ['는', '등', '분주', '한'],
#  ['등', '분주', '한', '시간'],
#  ['분주', '한', '시간', '을'],
#  ['한', '시간', '을', '보냈'],
#  ['시간', '을', '보냈', '는데'],
#  ['을', '보냈', '는데', ','],
#  ['보냈', '는데', ',', '그런'],
#  ['는데', ',', '그런', '바쁜'],
#  [',', '그런', '바쁜', '생활'],
#  ['그런', '바쁜', '생활', '이'],
#  ['바쁜', '생활', '이', '이'],
#  ['생활', '이', '이', '곡'],
#  ['이', '이', '곡', '을'],
#  ['이', '곡', '을', '잊'],
#  ['곡', '을', '잊', '게'],
#  ['을', '잊', '게', '한'],
#  ['잊', '게', '한', '것'],
#  ['게', '한', '것', '이'],
#  ['한', '것', '이', '아닌가'],
#  ['것', '이', '아닌가', '하'],
#  ['이', '아닌가', '하', '는'],
#  ['아닌가', '하', '는', '의견'],
#  ['하', '는', '의견', '도'],
#  ['는', '의견', '도', '있'],
#  ['의견', '도', '있', '다'],
#  ['도', '있', '다', '.'],
#  ['바그너', '는', '괴테', '의'],
#  ['는', '괴테', '의', '파우스트'],
#  ['괴테', '의', '파우스트', '를'],
#  ['의', '파우스트', '를', '읽'],
#  ['파우스트', '를', '읽', '고'],
#  ['를', '읽', '고', '무엇'],
#  ['읽', '고', '무엇', '을'],
#  ['고', '무엇', '을', '쓰'],
#  ['무엇', '을', '쓰', '고자'],
#  ['을', '쓰', '고자', '했'],
#  ['쓰', '고자', '했', '는가'],
#  ['고자', '했', '는가', '?'],
#  ['했', '는가', '?', '교향곡'],
#  ['바그너', '는', '교향곡', '작곡'],
#  ['는', '교향곡', '작곡', '을'],
#  ['교향곡', '작곡', '을', '어디'],
#  ['작곡', '을', '어디', '까지'],
#  ['을', '어디', '까지', '쓴'],
#  ['어디', '까지', '쓴', '뒤'],
#  ['까지', '쓴', '뒤', '에'],
#  ['쓴', '뒤', '에', '중단'],
#  ['뒤', '에', '중단', '했'],
#  ['에', '중단', '했', '는가'],
#  ['중단', '했', '는가', '?'],
#  ['했', '는가', '?', '1'],
#  ['는가', '?', '1', '악장'],
#  ['바그너', '가', '파우스트', '서곡'],
#  ['가', '파우스트', '서곡', '을'],
#  ['파우스트', '서곡', '을', '쓸'],
#  ['서곡', '을', '쓸', '때'],
#  ['을', '쓸', '때', '어떤'],
#  ['쓸', '때', '어떤', '곡'],
#  ['때', '어떤', '곡', '의'],
#  ['어떤', '곡', '의', '영향'],
#  ['곡', '의', '영향', '을'],
#  ['의', '영향', '을', '받'],
#  ['영향', '을', '받', '았'],
#  ['을', '받', '았', '는가'],
#  ['받', '았', '는가', '?'],
#  ['았', '는가', '?', '베토벤'],
#  ['는가', '?', '베토벤', '의'],
#  ['?', '베토벤', '의', '교향곡'],
#  ['베토벤', '의', '교향곡', '9'],
#  ['의', '교향곡', '9', '번'],
#  ['1', '8', '3', '9'],
#  ['8', '3', '9', '년'],
#  ['3', '9', '년', '바그너'],
#  ['9', '년', '바그너', '가'],
#  ['년', '바그너', '가', '교향곡'],
#  ['바그너', '가', '교향곡', '의'],
#  ['가', '교향곡', '의', '소재'],
#  ['교향곡', '의', '소재', '로'],
#  ['의', '소재', '로', '쓰'],
#  ['소재', '로', '쓰', '려고'],
#  ['로', '쓰', '려고', '했'],
#  ['쓰', '려고', '했', '던'],
#  ['려고', '했', '던', '책'],
#  ['했', '던', '책', '은'],
#  ['던', '책', '은', '?'],
#  ['책', '은', '?', '파우스트'],
#  ['파우스트', '서곡', '의', '라단조'],
#  ['서곡', '의', '라단조', '조성'],
#  ['의', '라단조', '조성', '이'],
#  ['라단조', '조성', '이', '영향'],
#  ['조성', '이', '영향', '을'],
#  ['이', '영향', '을', '받'],
#  ['영향', '을', '받', '은'],
#  ['을', '받', '은', '베토벤'],
#  ['받', '은', '베토벤', '의'],
#  ['은', '베토벤', '의', '곡'],
#  ['베토벤', '의', '곡', '은'],
#  ['의', '곡', '은', '?'],
#  ['곡', '은', '?', '합창'],
#  ['은', '?', '합창', '교향곡'],
#  ['바그너', '가', '파우스트', '를'],
#  ['가', '파우스트', '를', '처음'],
#  ['파우스트', '를', '처음', '으로'],
#  ['를', '처음', '으로', '읽'],
#  ['처음', '으로', '읽', '은'],
#  ['으로', '읽', '은', '년'],
#  ['읽', '은', '년', '도'],
#  ['은', '년', '도', '는'],
#  ['년', '도', '는', '?'],
#  ['도', '는', '?', '1'],
#  ['는', '?', '1', '8'],
#  ['?', '1', '8', '3'],
#  ['1', '8', '3', '9'],
#  ['바그너', '가', '처음', '교향곡'],
#  ['가', '처음', '교향곡', '작곡'],
#  ['처음', '교향곡', '작곡', '을'],
#  ['교향곡', '작곡', '을', '한'],
#  ['작곡', '을', '한', '장소'],
#  ['을', '한', '장소', '는'],
#  ['한', '장소', '는', '?'],
#  ['장소', '는', '?', '파리'],
#  ['바그너', '의', '1', '악장'],
#  ['의', '1', '악장', '의'],
#  ['1', '악장', '의', '초연'],
#  ['악장', '의', '초연', '은'],
#  ['의', '초연', '은', '어디'],
#  ['초연', '은', '어디', '서'],
#  ['은', '어디', '서', '연주'],
#  ['어디', '서', '연주', '되'],
#  ['서', '연주', '되', '었'],
#  ['연주', '되', '었', '는가'],
#  ['되', '었', '는가', '?'],
#  ['었', '는가', '?', '드레스'],
#  ['는가', '?', '드레스', '덴'],
#  ['한편', '1', '8', '4'],
#  ['1', '8', '4', '0'],
#  ['8', '4', '0', '년'],
#  ['4', '0', '년', '부터'],
#  ['0', '년', '부터', '바그너'],
#  ['년', '부터', '바그너', '와'],
#  ['부터', '바그너', '와', '알'],
#  ['바그너', '와', '알', '고'],
#  ['와', '알', '고', '지내'],
#  ['알', '고', '지내', '던'],
#  ['고', '지내', '던', '리스트'],
#  ['지내', '던', '리스트', '가'],
#  ['던', '리스트', '가', '잊혀져'],
#  ['리스트', '가', '잊혀져', '있'],
#  ['가', '잊혀져', '있', '던'],
#  ['잊혀져', '있', '던', '1'],
#  ['있', '던', '1', '악장'],
#  ['던', '1', '악장', '을'],
#  ['1', '악장', '을', '부활'],
#  ['악장', '을', '부활', '시켜'],
#  ['을', '부활', '시켜', '1'],
#  ['부활', '시켜', '1', '8'],
#  ['시켜', '1', '8', '5'],
#  ['1', '8', '5', '2'],
#  ['8', '5', '2', '년'],
#  ['5', '2', '년', '에'],
#  ['2', '년', '에', '바이마르'],
#  ['년', '에', '바이마르', '에서'],
#  ['에', '바이마르', '에서', '연주'],
#  ['바이마르', '에서', '연주', '했'],
#  ['에서', '연주', '했', '다'],
#  ['연주', '했', '다', '.'],
#  ['했', '다', '.', '이것'],
#  ['다', '.', '이것', '을'],
#  ['.', '이것', '을', '계기'],
#  ['이것', '을', '계기', '로'],
#  ['을', '계기', '로', '바그너'],
#  ['계기', '로', '바그너', '도'],
#  ['로', '바그너', '도', '이'],
#  ['바그너', '도', '이', '작품'],
#  ['도', '이', '작품', '에'],
#  ['이', '작품', '에', '다시'],
#  ['작품', '에', '다시', '관심'],
#  ['에', '다시', '관심', '을'],
#  ['다시', '관심', '을', '갖'],
#  ['관심', '을', '갖', '게'],
#  ['을', '갖', '게', '되'],
#  ['갖', '게', '되', '었'],
#  ['게', '되', '었', '고'],
#  ['되', '었', '고', ','],
#  ['었', '고', ',', '그'],
#  ['고', ',', '그', '해'],
#  [',', '그', '해', '9'],
#  ['그', '해', '9', '월'],
#  ['해', '9', '월', '에'],
#  ['9', '월', '에', '는'],
#  ['월', '에', '는', '총보'],
#  ['에', '는', '총보', '의'],
#  ['는', '총보', '의', '반환'],
#  ['총보', '의', '반환', '을'],
#  ['의', '반환', '을', '요구'],
#  ['반환', '을', '요구', '하'],
#  ['을', '요구', '하', '여'],
#  ['요구', '하', '여', '이'],
#  ['하', '여', '이', '를'],
#  ['여', '이', '를', '서곡'],
#  ['이', '를', '서곡', '으로'],
#  ['를', '서곡', '으로', '간추린'],
#  ['서곡', '으로', '간추린', '다음'],
#  ['으로', '간추린', '다음', '수정'],
#  ['간추린', '다음', '수정', '을'],
#  ['다음', '수정', '을', '했'],
#  ['수정', '을', '했', '고'],
#  ['을', '했', '고', '브라이트'],
#  ['했', '고', '브라이트', '코프'],
#  ['고', '브라이트', '코프', '흐'],
#  ['브라이트', '코프', '흐', '&'],
#  ['코프', '흐', '&', '헤르'],
#  ['흐', '&', '헤르', '텔'],
#  ['&', '헤르', '텔', '출판사'],
#  ['헤르', '텔', '출판사', '에서'],
#  ['텔', '출판사', '에서', '출판'],
#  ['출판사', '에서', '출판', '할'],
#  ['에서', '출판', '할', '개정판'],
#  ['출판', '할', '개정판', '도'],
#  ['할', '개정판', '도', '준비'],
#  ['개정판', '도', '준비', '했'],
#  ['도', '준비', '했', '다'],
#  ['준비', '했', '다', '.'],
#  ['했', '다', '.', '1'],
#  ['다', '.', '1', '8'],
#  ['.', '1', '8', '5'],
#  ['1', '8', '5', '3'],
#  ['8', '5', '3', '년'],
#  ['5', '3', '년', '5'],
#  ['3', '년', '5', '월'],
#  ['년', '5', '월', '에'],
#  ['5', '월', '에', '는'],
#  ['월', '에', '는', '리스트'],
#  ['에', '는', '리스트', '가'],
#  ['는', '리스트', '가', '이'],
#  ['리스트', '가', '이', '작품'],
#  ['가', '이', '작품', '이'],
#  ['이', '작품', '이', '수정'],
#  ['작품', '이', '수정', '되'],
#  ['이', '수정', '되', '었'],
#  ['수정', '되', '었', '다는'],
#  ['되', '었', '다는', '것'],
#  ['었', '다는', '것', '을'],
#  ['다는', '것', '을', '인정'],
#  ['것', '을', '인정', '했'],
#  ['을', '인정', '했', '지만'],
#  ['인정', '했', '지만', ','],
#  ['했', '지만', ',', '끝내'],
#  ['지만', ',', '끝내', '바그너'],
#  [',', '끝내', '바그너', '의'],
#  ['끝내', '바그너', '의', '출판'],
#  ['바그너', '의', '출판', '계획'],
#  ['의', '출판', '계획', '은'],
#  ['출판', '계획', '은', '무산'],
#  ['계획', '은', '무산', '되'],
#  ['은', '무산', '되', '고'],
#  ['무산', '되', '고', '말'],
#  ['되', '고', '말', '았'],
#  ['고', '말', '았', '다'],
#  ['말', '았', '다', '.'],
#  ['았', '다', '.', '이후'],
#  ['다', '.', '이후', '1'],
#  ['.', '이후', '1', '8'],
#  ['이후', '1', '8', '5'],
#  ['1', '8', '5', '5'],
#  ['8', '5', '5', '년'],
#  ['5', '5', '년', '에'],
#  ['5', '년', '에', '리스트'],
#  ['년', '에', '리스트', '가'],
#  ['에', '리스트', '가', '자신'],
#  ['리스트', '가', '자신', '의'],
#  ['가', '자신', '의', '작품'],
#  ['자신', '의', '작품', '파우스트'],
#  ['의', '작품', '파우스트', '교향곡'],
#  ['작품', '파우스트', '교향곡', '을'],
#  ['파우스트', '교향곡', '을', '거의'],
#  ['교향곡', '을', '거의', '완성'],
#  ['을', '거의', '완성', '하'],
#  ['거의', '완성', '하', '여'],
#  ['완성', '하', '여', '그'],
#  ['하', '여', '그', '사실'],
#  ['여', '그', '사실', '을'],
#  ['그', '사실', '을', '바그너'],
#  ['사실', '을', '바그너', '에게'],
#  ['을', '바그너', '에게', '알렸'],
#  ['바그너', '에게', '알렸', '고'],
#  ['에게', '알렸', '고', ','],
#  ['알렸', '고', ',', '바그너'],
#  ['고', ',', '바그너', '는'],
#  [',', '바그너', '는', '다시'],
#  ['바그너', '는', '다시', '개정'],
#  ['는', '다시', '개정', '된'],
#  ['다시', '개정', '된', '총보'],
#  ['개정', '된', '총보', '를'],
#  ['된', '총보', '를', '리스트'],
#  ['총보', '를', '리스트', '에게'],
#  ['를', '리스트', '에게', '보내'],
#  ['리스트', '에게', '보내', '고'],
#  ['에게', '보내', '고', '브라이트'],
#  ['보내', '고', '브라이트', '코프'],
#  ['고', '브라이트', '코프', '흐'],
#  ['브라이트', '코프', '흐', '&'],
#  ['코프', '흐', '&', '헤르'],
#  ['흐', '&', '헤르', '텔'],
#  ['&', '헤르', '텔', '출판사'],
#  ['헤르', '텔', '출판사', '에'],
#  ['텔', '출판사', '에', '는'],
#  ['출판사', '에', '는', '2'],
#  ['에', '는', '2', '0'],
#  ['는', '2', '0', '루이'],
#  ['2', '0', '루이', '의'],
#  ['0', '루이', '의', '금'],
#  ['루이', '의', '금', '을'],
#  ['의', '금', '을', '받'],
#  ['금', '을', '받', '고'],
#  ['을', '받', '고', '팔'],
#  ['받', '고', '팔', '았'],
#  ['고', '팔', '았', '다'],
#  ['팔', '았', '다', '.'],
#  ['았', '다', '.', '또한'],
#  ['다', '.', '또한', '그'],
#  ['.', '또한', '그', '의'],
#  ['또한', '그', '의', '작품'],
#  ['그', '의', '작품', '을'],
#  ['의', '작품', '을', '“'],
#  ['작품', '을', '“', '하나하나'],
#  ['을', '“', '하나하나', '의'],
#  ['“', '하나하나', '의', '음표'],
#  ['하나하나', '의', '음표', '가'],
#  ['의', '음표', '가', '시인'],
#  ['음표', '가', '시인', '의'],
#  ['가', '시인', '의', '피'],
#  ['시인', '의', '피', '로'],
#  ['의', '피', '로', '쓰여졌'],
#  ['피', '로', '쓰여졌', '다'],
#  ['로', '쓰여졌', '다', '”'],
#  ['쓰여졌', '다', '”', '며'],
#  ['다', '”', '며', '극찬'],
#  ['”', '며', '극찬', '했'],
#  ['며', '극찬', '했', '던'],
#  ['극찬', '했', '던', '한스'],
#  ['했', '던', '한스', '폰'],
#  ['던', '한스', '폰', '뷜로'],
#  ['한스', '폰', '뷜로', '가'],
#  ['폰', '뷜로', '가', '그것'],
#  ['뷜로', '가', '그것', '을'],
#  ['가', '그것', '을', '피아노'],
#  ['그것', '을', '피아노', '독주'],
#  ['을', '피아노', '독주', '용'],
#  ['피아노', '독주', '용', '으로'],
#  ['독주', '용', '으로', '편곡'],
#  ['용', '으로', '편곡', '했'],
#  ['으로', '편곡', '했', '는데'],
#  ['편곡', '했', '는데', ','],
#  ['했', '는데', ',', '리스트'],
#  ['는데', ',', '리스트', '는'],
#  [',', '리스트', '는', '그것'],
#  ['리스트', '는', '그것', '을'],
#  ['는', '그것', '을', '약간'],
#  ['그것', '을', '약간', '변형'],
#  ['을', '약간', '변형', '되'],
#  ['약간', '변형', '되', '었'],
#  ['변형', '되', '었', '을'],
#  ['되', '었', '을', '뿐'],
#  ['었', '을', '뿐', '이'],
#  ['을', '뿐', '이', '라고'],
#  ['뿐', '이', '라고', '지적'],
#  ['이', '라고', '지적', '했'],
#  ['라고', '지적', '했', '다'],
#  ['지적', '했', '다', '.'],
#  ['했', '다', '.', '이'],
#  ['다', '.', '이', '서곡'],
#  ['.', '이', '서곡', '의'],
#  ['이', '서곡', '의', '총보'],
#  ['서곡', '의', '총보', '첫머리'],
#  ['의', '총보', '첫머리', '에'],
#  ['총보', '첫머리', '에', '는'],
#  ['첫머리', '에', '는', '파우스트'],
#  ['에', '는', '파우스트', '1'],
#  ['는', '파우스트', '1', '부'],
#  ['파우스트', '1', '부', '의'],
#  ['1', '부', '의', '내용'],
#  ['부', '의', '내용', '중'],
#  ['의', '내용', '중', '한'],
#  ['내용', '중', '한', '구절'],
#  ['중', '한', '구절', '을'],
#  ['한', '구절', '을', '인용'],
#  ['구절', '을', '인용', '하'],
#  ['을', '인용', '하', '고'],
#  ['인용', '하', '고', '있'],
#  ['하', '고', '있', '다'],
#  ['고', '있', '다', '.'],
#  ['바그너', '의', '작품', '을'],
#  ['의', '작품', '을', '시인'],
#  ['작품', '을', '시인', '의'],
#  ['을', '시인', '의', '피'],
#  ['시인', '의', '피', '로'],
#  ['의', '피', '로', '쓰여졌'],
#  ['피', '로', '쓰여졌', '다고'],
#  ['로', '쓰여졌', '다고', '극찬'],
#  ['쓰여졌', '다고', '극찬', '한'],
#  ['다고', '극찬', '한', '것'],
#  ['극찬', '한', '것', '은'],
#  ['한', '것', '은', '누구'],
#  ['것', '은', '누구', '인가'],
#  ['은', '누구', '인가', '?'],
#  ['누구', '인가', '?', '한스'],
#  ['인가', '?', '한스', '폰'],
#  ['?', '한스', '폰', '뷜로'],
#  ['잊혀져', '있', '는', '파우스트'],
#  ['있', '는', '파우스트', '서곡'],
#  ['는', '파우스트', '서곡', '1'],
#  ['파우스트', '서곡', '1', '악장'],
#  ['서곡', '1', '악장', '을'],
#  ['1', '악장', '을', '부활'],
#  ['악장', '을', '부활', '시킨'],
#  ['을', '부활', '시킨', '것'],
#  ['부활', '시킨', '것', '은'],
#  ['시킨', '것', '은', '누구'],
#  ['것', '은', '누구', '인가'],
#  ['은', '누구', '인가', '?'],
#  ['누구', '인가', '?', '리스트'],
#  ['바그너', '는', '다시', '개정'],
#  ['는', '다시', '개정', '된'],
#  ['다시', '개정', '된', '총보'],
#  ['개정', '된', '총보', '를'],
#  ['된', '총보', '를', '얼마'],
#  ['총보', '를', '얼마', '를'],
#  ['를', '얼마', '를', '받'],
#  ['얼마', '를', '받', '고'],
#  ['를', '받', '고', '팔'],
#  ['받', '고', '팔', '았'],
#  ['고', '팔', '았', '는가'],
#  ['팔', '았', '는가', '?'],
#  ['았', '는가', '?', '2'],
#  ['는가', '?', '2', '0'],
#  ['?', '2', '0', '루이'],
#  ['2', '0', '루이', '의'],
#  ['0', '루이', '의', '금'],
#  ['파우스트', '교향곡', '을', '부활'],
#  ['교향곡', '을', '부활', '시킨'],
#  ['을', '부활', '시킨', '사람'],
#  ['부활', '시킨', '사람', '은'],
#  ['시킨', '사람', '은', '?'],
#  ['사람', '은', '?', '리스트'],
#  ['파우스트', '교향곡', '을', '피아노'],
#  ['교향곡', '을', '피아노', '독주'],
#  ['을', '피아노', '독주', '용'],
#  ['피아노', '독주', '용', '으로'],
#  ['독주', '용', '으로', '편곡'],
#  ['용', '으로', '편곡', '한'],
#  ['으로', '편곡', '한', '사람'],
#  ['편곡', '한', '사람', '은'],
#  ['한', '사람', '은', '?'],
#  ['사람', '은', '?', '한스'],
#  ['은', '?', '한스', '폰'],
#  ['?', '한스', '폰', '뷜로'],
#  ['1', '악장', '을', '부활'],
#  ['악장', '을', '부활', '시켜'],
#  ['을', '부활', '시켜', '연주'],
#  ['부활', '시켜', '연주', '한'],
#  ['시켜', '연주', '한', '사람'],
#  ['연주', '한', '사람', '은'],
#  ['한', '사람', '은', '?'],
#  ['사람', '은', '?', '리스트'],
#  ['파우스트', '교향곡', '에', '감탄'],
#  ['교향곡', '에', '감탄', '하'],
#  ['에', '감탄', '하', '여'],
#  ['감탄', '하', '여', '피아노'],
#  ['하', '여', '피아노', '곡'],
#  ['여', '피아노', '곡', '으로'],
#  ['피아노', '곡', '으로', '편곡'],
#  ['곡', '으로', '편곡', '한'],
#  ['으로', '편곡', '한', '사람'],
#  ['편곡', '한', '사람', '은'],
#  ['한', '사람', '은', '?'],
#  ['사람', '은', '?', '한스'],
#  ['은', '?', '한스', '폰'],
#  ['?', '한스', '폰', '뷜로'],
#  ['리스트', '가', '바그너', '와'],
#  ['가', '바그너', '와', '알'],
#  ['바그너', '와', '알', '게'],
#  ['와', '알', '게', '된'],
#  ['알', '게', '된', '연도'],
#  ['게', '된', '연도', '는'],
#  ['된', '연도', '는', '?'],
#  ['연도', '는', '?', '1'],
#  ['는', '?', '1', '8'],
#  ['?', '1', '8', '4'],
#  ['1', '8', '4', '0'],
#  ['8', '4', '0', '년'],
#  ['이', '작품', '은', '라단조'],
#  ['작품', '은', '라단조', ','],
#  ['은', '라단조', ',', 'Sehr'],
#  ['라단조', ',', 'Sehr', 'gehalten'],
#  [',', 'Sehr', 'gehalten', '('],
#  ['Sehr', 'gehalten', '(', '아주'],
#  ['gehalten', '(', '아주', '신중'],
#  ['(', '아주', '신중', '하'],
#  ['아주', '신중', '하', '게'],
#  ['신중', '하', '게', ')'],
#  ['하', '게', ')', ','],
#  ['게', ')', ',', '4'],
#  [')', ',', '4', '/'],
#  [',', '4', '/', '4'],
#  ['4', '/', '4', '박자'],
#  ['/', '4', '박자', '의'],
#  ['4', '박자', '의', '부드러운'],
#  ['박자', '의', '부드러운', '서주'],
#  ['의', '부드러운', '서주', '로'],
#  ['부드러운', '서주', '로', '서주'],
#  ['서주', '로', '서주', '로'],
#  ['로', '서주', '로', '시작'],
#  ['서주', '로', '시작', '되'],
#  ['로', '시작', '되', '는데'],
#  ['시작', '되', '는데', ','],
#  ['되', '는데', ',', '여기'],
#  ['는데', ',', '여기', '에'],
#  [',', '여기', '에', '는'],
#  ['여기', '에', '는', '주요'],
#  ['에', '는', '주요', '주제'],
#  ['는', '주요', '주제', ','],
#  ['주요', '주제', ',', '동기'],
#  ['주제', ',', '동기', '의'],
#  [',', '동기', '의', '대부분'],
#  ['동기', '의', '대부분', '이'],
#  ['의', '대부분', '이', '암시'],
#  ['대부분', '이', '암시', ','],
#  ['이', '암시', ',', '예고'],
#  ['암시', ',', '예고', '되'],
#  [',', '예고', '되', '어'],
#  ['예고', '되', '어', '있'],
#  ['되', '어', '있', '다'],
#  ['어', '있', '다', '.'],
#  ['있', '다', '.', '첫'],
#  ['다', '.', '첫', '부분'],
#  ['.', '첫', '부분', '의'],
#  ['첫', '부분', '의', '저음'],
#  ['부분', '의', '저음', '주제'],
#  ['의', '저음', '주제', '는'],
#  ['저음', '주제', '는', '주요'],
#  ['주제', '는', '주요', '주제'],
#  ['는', '주요', '주제', '('],
#  ['주요', '주제', '(', '고뇌'],
#  ['주제', '(', '고뇌', '와'],
#  ['(', '고뇌', '와', '갈망'],
#  ['고뇌', '와', '갈망', '동기'],
#  ['와', '갈망', '동기', ','],
#  ['갈망', '동기', ',', '청춘'],
#  ['동기', ',', '청춘', '의'],
#  [',', '청춘', '의', '사랑'],
#  ['청춘', '의', '사랑', '동기'],
#  ['의', '사랑', '동기', ')'],
#  ['사랑', '동기', ')', '를'],
#  ['동기', ')', '를', '암시'],
#  [')', '를', '암시', '하'],
#  ['를', '암시', '하', '고'],
#  ['암시', '하', '고', '있'],
#  ['하', '고', '있', '으며'],
#  ['고', '있', '으며', ','],
#  ['있', '으며', ',', '제'],
#  ['으며', ',', '제', '1'],
#  [',', '제', '1', '바이올린'],
#  ['제', '1', '바이올린', '으로'],
#  ['1', '바이올린', '으로', '더욱'],
#  ['바이올린', '으로', '더욱', '명확'],
#  ['으로', '더욱', '명확', '하'],
#  ['더욱', '명확', '하', '게'],
#  ['명확', '하', '게', '나타난다'],
#  ['하', '게', '나타난다', '.'],
#  ['게', '나타난다', '.', '또한'],
#  ['나타난다', '.', '또한', '그것'],
#  ['.', '또한', '그것', '을'],
#  ['또한', '그것', '을', '이어받'],
#  ['그것', '을', '이어받', '는'],
#  ['을', '이어받', '는', '동기'],
#  ['이어받', '는', '동기', '도'],
#  ['는', '동기', '도', '중요'],
#  ['동기', '도', '중요', '한'],
#  ['도', '중요', '한', '역할'],
#  ['중요', '한', '역할', '을'],
#  ['한', '역할', '을', '한다'],
#  ['역할', '을', '한다', '.'],
#  ['을', '한다', '.', '여기'],
#  ['한다', '.', '여기', '에'],
#  ['.', '여기', '에', '새로운'],
#  ['여기', '에', '새로운', '소재'],
#  ['에', '새로운', '소재', '가'],
#  ['새로운', '소재', '가', '더'],
#  ['소재', '가', '더', '해진'],
#  ['가', '더', '해진', '뒤'],
#  ['더', '해진', '뒤', '에'],
#  ['해진', '뒤', '에', '새로운'],
#  ['뒤', '에', '새로운', '주제'],
#  ['에', '새로운', '주제', '도'],
#  ['새로운', '주제', '도', '연주'],
#  ['주제', '도', '연주', '된다'],
#  ['도', '연주', '된다', '.'],
#  ['연주', '된다', '.', '주요부'],
#  ['된다', '.', '주요부', '는'],
#  ['.', '주요부', '는', 'Sehr'],
#  ['주요부', '는', 'Sehr', 'bewegt'],
#  ['는', 'Sehr', 'bewegt', '('],
#  ['Sehr', 'bewegt', '(', '아주'],
#  ['bewegt', '(', '아주', '격동'],
#  ['(', '아주', '격동', '적'],
#  ['아주', '격동', '적', '으로'],
#  ['격동', '적', '으로', ')'],
#  ['적', '으로', ')', ','],
#  ['으로', ')', ',', '2'],
#  [')', ',', '2', '/'],
#  [',', '2', '/', '2'],
#  ['2', '/', '2', '박자'],
#  ['/', '2', '박자', '의'],
#  ['2', '박자', '의', '자유'],
#  ['박자', '의', '자유', '로운'],
#  ['의', '자유', '로운', '소나타'],
#  ['자유', '로운', '소나타', '형식'],
#  ['로운', '소나타', '형식', '으로'],
#  ['소나타', '형식', '으로', '매우'],
#  ['형식', '으로', '매우', '드라마틱'],
#  ['으로', '매우', '드라마틱', '한'],
#  ['매우', '드라마틱', '한', '구상'],
#  ['드라마틱', '한', '구상', '과'],
#  ['한', '구상', '과', '유기'],
#  ['구상', '과', '유기', '적'],
#  ['과', '유기', '적', '인'],
#  ['유기', '적', '인', '구성'],
#  ['적', '인', '구성', '을'],
#  ['인', '구성', '을', '하'],
#  ['구성', '을', '하', '고'],
#  ['을', '하', '고', '있'],
#  ['하', '고', '있', '다'],
#  ['고', '있', '다', '.'],
#  ['있', '다', '.', '여기'],
#  ['다', '.', '여기', '에'],
#  ['.', '여기', '에', '는'],
#  ['여기', '에', '는', '지금'],
#  ['에', '는', '지금', '까지'],
#  ['는', '지금', '까지', '의'],
#  ['지금', '까지', '의', '주제'],
#  ['까지', '의', '주제', '나'],
#  ['의', '주제', '나', '소재'],
#  ['주제', '나', '소재', '외'],
#  ['나', '소재', '외', '에'],
#  ['소재', '외', '에', '도'],
#  ['외', '에', '도', '오보에'],
#  ['에', '도', '오보에', '에'],
#  ['도', '오보에', '에', '의한'],
#  ['오보에', '에', '의한', '선율'],
#  ['에', '의한', '선율', '과'],
#  ['의한', '선율', '과', '제'],
#  ['선율', '과', '제', '2'],
#  ['과', '제', '2', '주제'],
#  ['제', '2', '주제', '를'],
#  ['2', '주제', '를', '떠올리'],
#  ['주제', '를', '떠올리', '게'],
#  ['를', '떠올리', '게', '하'],
#  ['떠올리', '게', '하', '는'],
#  ['게', '하', '는', '부차'],
#  ['하', '는', '부차', '적'],
#  ['는', '부차', '적', '인'],
#  ['부차', '적', '인', '주제'],
#  ['적', '인', '주제', '가'],
#  ['인', '주제', '가', '더'],
#  ['주제', '가', '더', '해'],
#  ['가', '더', '해', '지'],
#  ['더', '해', '지', '는데'],
#  ['해', '지', '는데', ','],
#  ['지', '는데', ',', '중간부'],
#  ['는데', ',', '중간부', '에서'],
#  [',', '중간부', '에서', '는'],
#  ['중간부', '에서', '는', '약보'],
#  ['에서', '는', '약보', '3'],
#  ['는', '약보', '3', '이'],
#  ['약보', '3', '이', '중심'],
#  ['3', '이', '중심', '이'],
#  ['이', '중심', '이', '되'],
#  ['중심', '이', '되', '고'],
#  ['이', '되', '고', '제'],
#  ['되', '고', '제', '2'],
#  ['고', '제', '2', '주제'],
#  ['제', '2', '주제', '는'],
#  ['2', '주제', '는', '축소'],
#  ['주제', '는', '축소', '된'],
#  ['는', '축소', '된', '재현부'],
#  ['축소', '된', '재현부', '에서'],
#  ['된', '재현부', '에서', 'D'],
#  ['재현부', '에서', 'D', '장조'],
#  ['에서', 'D', '장조', '로'],
#  ['D', '장조', '로', '재현'],
#  ['장조', '로', '재현', '된다'],
#  ['로', '재현', '된다', '.'],
#  ...]

# %%
len(train_data)
# Out:
# 3862986

# %%
def sent_to_vec(sent):
    vec = []
    for word in sent:
        vec.append(word_to_id[word])
    return vec

# %%
train_input = []
train_target = []
for data in train_data:
    train_input.append(sent_to_vec(data[:-1]))
    train_target.append(word_to_id[data[-1]])

# %%
len(train_input), len(train_target)
# Out:
# (3862986, 3862986)

# %%
train_input[0], train_target[0]
# Out:
# ([9588, 64699, 68693], 55945)

# %%
train_input_ts = torch.tensor(train_input)
train_target_ts = torch.tensor(train_target)

# %%
train = torch.utils.data.TensorDataset(train_input_ts, train_target_ts)

# %% [markdown]
# ### 모델을 만들어보자.
#
# 먼저 임베딩 벡터를 concatenate하는 방법에 대해 고민해보자.

# %%
emb = nn.Embedding(len(vocab) * (N-1), 5)

# %%
vec = emb(torch.tensor([train_input[0]]))
vec.shape
# Out:
# torch.Size([1, 3, 5])

# %%
torch.flatten(vec[0])
# Out:
# tensor([-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#          1.9236,  0.6581,  1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#        grad_fn=<AsStridedBackward>)

# %% [markdown]
# 따라서 입력을 하나씩 받을 경우는 그냥 flatten 쓰면 되지만, 배치로 받을 때는?

# %%
vec = emb(torch.tensor([train_input[0],train_input[1]]))
vec.shape
# Out:
# torch.Size([2, 3, 5])

# %%
vec
# Out:
# tensor([[[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704],
#          [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581],
#          [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994]],
#
#         [[ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581],
#          [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#          [-3.7253,  0.1673,  0.1281,  0.9819, -0.5825]]],
#        grad_fn=<EmbeddingBackward>)

# %%
vec_tu= torch.cat(tuple(vec),1)
vec_tu
# Out:
# tensor([[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#           1.9236,  0.6581],
#         [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581,  1.2249, -0.0710,  0.6953,
#          -0.9278, -0.0994],
#         [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994, -3.7253,  0.1673,  0.1281,
#           0.9819, -0.5825]], grad_fn=<CatBackward>)

# %% [markdown]
# torch.cat은 안될 것 같고, 찾아보니 flatten에 start_dim 옵션이 있음!

# %%
torch.flatten??

# %%
vec_tu= torch.flatten(vec,1)
vec_tu
# Out:
# tensor([[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#           1.9236,  0.6581,  1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#         [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581,  1.2249, -0.0710,  0.6953,
#          -0.9278, -0.0994, -3.7253,  0.1673,  0.1281,  0.9819, -0.5825]],
#        grad_fn=<AsStridedBackward>)

# %% [markdown]
# 원하는 결과를 얻음!

# %% [markdown]
# 근데 어차피 Linear layer가 필요하므로 원핫인코딩을 해야함...

# %%
batch = torch.tensor([train_input[0],train_input[1]])
batch.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# 인덱스 벡터를 받으면 원핫인코딩 벡터를 반환하는 함수를 만들자

# %%
def vec_to_onehot(vec, oh_len):
    ohv = torch.zeros((batch.shape[0], batch.shape[1], oh_len))
    for i in range(vec.shape[0]):
        for j in range(vec.shape[1]):
            ohv[i][j][vec[i][j]] = 1
            
    return ohv

# %%
vec_to_onehot(batch, len(vocab)).shape
# Out:
# torch.Size([2, 3, 83593])

# %%
vec_oh = vec_to_onehot(batch, len(vocab))
vec_oh_tu= torch.flatten(vec_oh,1)

# %%
vec_oh_tu.shape
# Out:
# torch.Size([2, 250779])

# %%
lin = nn.Linear(len(vocab) * (N-1), 5)

# %%
lin(vec_oh_tu).shape
# Out:
# torch.Size([2, 5])

# %% [markdown]
# 아예 이 과정을 하나의 함수로 만들자.

# %%
def batch_to_input(batch, oh_len):
    ohv = torch.zeros((batch.shape[0], batch.shape[1], oh_len))
    for i in range(batch.shape[0]):
        for j in range(batch.shape[1]):
            ohv[i][j][batch[i][j]] = 1
            
    return torch.flatten(ohv,1)

# %%
batch_to_input(batch, len(vocab)).shape
# Out:
# torch.Size([2, 250779])

# %%
lin(batch_to_input(batch, len(vocab))).shape
# Out:
# torch.Size([2, 5])

# %% [markdown]
# 생각해보니 착각을 했다. 모델의 입력은 인덱스로 받아서 먼저 벡터 임베딩 후 Linear layer에 태우면 되니까, 그냥 임베딩 써도 됨

# %%
loss_f = nn.CrossEntropyLoss()

# %%
class NPLM(nn.Module):
    def __init__(self, n, vec_dim, hidden_dim):
        super(NPLM,self).__init__()
        self.emb = nn.Embedding(len(vocab), vec_dim)
        self.lin1 = nn.Linear(vec_dim * (n-1), hidden_dim)
        self.lin2 = nn.Linear(hidden_dim, len(vocab), bias=False)
        self.lin3 = nn.Linear(vec_dim * (n-1), len(vocab))
        
    def forward(self, x):
        # x : [BATCH_SIZE, N-1]
        # self.emb(x) : [BATCH_SIZE, N-1, VEC_DIM]
        x = self.emb(x).view(len(x),-1)
        y = torch.tanh(self.lin1(x))
        z = self.lin3(x) + self.lin2(y)
        return z

# %%
model = NPLM(N, VEC_DIM, HIDDEN_DIM)

# %%
target_batch = torch.tensor([train_target[0],train_target[1]])
target_batch
# Out:
# tensor([ 9126, 52737])

# %%
loss_f(output, target_batch)
# Out:
# tensor(11.2042, grad_fn=<NllLossBackward>)

# %% [markdown]
# 이 loss가 올바른 결과인지 확인해보자

# %%
F.softmax(output, 1) # output을 소프트맥스 변환
# Out:
# tensor([[1.4428e-05, 1.2722e-05, 2.4266e-05,  ..., 7.4909e-06, 8.3130e-06,
#          2.4767e-06],
#         [1.2748e-05, 1.0737e-05, 1.9825e-05,  ..., 8.3171e-06, 2.4149e-05,
#          3.8782e-06]], grad_fn=<SoftmaxBackward>)

# %%
F.softmax(output, 1)[0].sum() # 차원이 맞게 되었는지 확인
# Out:
# tensor(1.0000, grad_fn=<SumBackward0>)

# %%
torch.log(F.softmax(output, 1)[0][target_batch[0]]) # 출력의 target번째 좌표의 로그값
# Out:
# tensor(-11.4189, grad_fn=<LogBackward>)

# %%
torch.log(F.softmax(output, 1)[1][target_batch[1]])
# Out:
# tensor(-10.9895, grad_fn=<LogBackward>)

# %%
-(torch.log(F.softmax(output, 1)[0][target_batch[0]]) + torch.log(F.softmax(output, 1)[1][target_batch[1]]))/2
# Out:
# tensor(11.2042, grad_fn=<DivBackward0>)

# %% [markdown]
# 따라서 각각의 negative loss의 평균이다! 맞게 계산됨

# %% [markdown]
# ### 훈련 과정

# %%
BATCH_SIZE = 64
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
input_loader = torch.utils.data.DataLoader(train, batch_size=BATCH_SIZE)

# %%
x, y = next(iter(input_loader))

# %%
x.shape
# Out:
# torch.Size([64, 3])

# %%
y.shape
# Out:
# torch.Size([64])

# %% [markdown]
# 앞에서 임베딩도 잘못 했음...

# %%
emb = nn.Embedding(len(vocab), 10)

# %%
emb(x).shape
# Out:
# torch.Size([64, 3, 10])

# %%
out = emb(x)

# %%
out
# Out:
# tensor([[[-1.3797, -0.5497, -0.1819,  ...,  0.2293,  1.3921,  0.3705],
#          [-0.9443, -1.9360,  1.0009,  ...,  1.3524, -0.2080,  1.1619],
#          [ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067]],
#
#         [[-0.9443, -1.9360,  1.0009,  ...,  1.3524, -0.2080,  1.1619],
#          [ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067],
#          [ 0.6412, -0.5177,  1.2241,  ..., -0.3652, -0.4658,  1.4531]],
#
#         [[ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067],
#          [ 0.6412, -0.5177,  1.2241,  ..., -0.3652, -0.4658,  1.4531],
#          [-0.6553, -0.0878,  0.1446,  ..., -0.9161,  1.3431,  0.0070]],
#
#         ...,
#
#         [[-0.6617,  0.6439, -0.0419,  ..., -0.3900,  0.9162, -0.4438],
#          [ 0.4282, -0.8271, -0.3454,  ..., -1.4361,  0.6106, -0.6443],
#          [ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068]],
#
#         [[ 0.4282, -0.8271, -0.3454,  ..., -1.4361,  0.6106, -0.6443],
#          [ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068],
#          [-0.9041,  0.3556, -0.0400,  ..., -0.0195, -1.1323, -1.1402]],
#
#         [[ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068],
#          [-0.9041,  0.3556, -0.0400,  ..., -0.0195, -1.1323, -1.1402],
#          [ 0.7355,  0.0207, -1.0938,  ...,  0.7455, -1.3573, -1.6670]]],
#        grad_fn=<EmbeddingBackward>)

# %%
out.view(BATCH_SIZE,-1)
# Out:
# tensor([[-1.3797, -0.5497, -0.1819,  ..., -0.1276,  0.3939,  0.1067],
#         [-0.9443, -1.9360,  1.0009,  ..., -0.3652, -0.4658,  1.4531],
#         [ 1.2290, -0.0642,  0.6032,  ..., -0.9161,  1.3431,  0.0070],
#         ...,
#         [-0.6617,  0.6439, -0.0419,  ...,  1.2346, -0.0447,  0.2068],
#         [ 0.4282, -0.8271, -0.3454,  ..., -0.0195, -1.1323, -1.1402],
#         [ 1.0708, -1.7279,  0.0475,  ...,  0.7455, -1.3573, -1.6670]],
#        grad_fn=<ViewBackward>)

# %%
import time

# %%
# CPU time
start = time.time()

epoch = 1
loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % 50 == 0:        
            loss_list.append(loss_sum/50)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}s'.format(epo, i, loss_sum/50, time.time()-start))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 0.02, Elapsed time : 1
# Epoch : 0, Iteration : 50, Loss : 4.04, Elapsed time : 43
# Epoch : 0, Iteration : 100, Loss : 3.65, Elapsed time : 85
# Epoch : 0, Iteration : 150, Loss : 3.99, Elapsed time : 127
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-309-c5e025b229d9> in <module>
#      13         output = model(x)
#      14
# ---> 15         loss = loss_f(output, y)
#      16         loss.backward()
#      17         optimizer.step()
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     914     def forward(self, input, target):
#     915         return F.cross_entropy(input, target, weight=self.weight,
# --> 916                                ignore_index=self.ignore_index, reduction=self.reduction)
#     917
#     918
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1993     if size_average is not None or reduce is not None:
#    1994         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 1995     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    1996
#    1997
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\functional.py in log_softmax(input, dim, _stacklevel, dtype)
#    1314         dim = _get_softmax_dim('log_softmax', input.dim(), _stacklevel)
#    1315     if dtype is None:
# -> 1316         ret = input.log_softmax(dim)
#    1317     else:
#    1318         ret = input.log_softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# CPU 에서 GPU 로 옮겨서 해보자

# %%
model.to(dev)
# Out:
# NPLM(
#   (emb): Embedding(83593, 100)
#   (lin1): Linear(in_features=300, out_features=100, bias=True)
#   (lin2): Linear(in_features=100, out_features=83593, bias=False)
#   (lin3): Linear(in_features=300, out_features=83593, bias=True)
# )

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# GPU time
start = time.time()

epoch = 1
loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        x,y = x.to(dev), y.to(dev)
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % 50 == 0:        
            loss_list.append(loss_sum/50)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}s'.format(epo, i, loss_sum/50, time.time()-start))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 0.23, Elapsed time : 1s
# Epoch : 0, Iteration : 50, Loss : 8.84, Elapsed time : 2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-d4f6fb487592> in <module>
#      18         optimizer.step()
#      19
# ---> 20         loss_sum += loss.item()
#      21
#      22
#
# KeyboardInterrupt:

# %% [markdown]
# 대략 43/2 = 20배 정도 빨라짐... 갓 GPU

# %%
check = 5000
epoch = 1

# %%
# GPU time
start = time.time()

#loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        x,y = x.to(dev), y.to(dev)
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % check == 0:        
            elap = int(time.time() - start)
            loss_list.append(loss_sum/check)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}h {:.0f}m {}s'.format(\
                epo, i, loss_sum / check, elap // 3600, (elap % 3600) // 60, str(int((elap % 3600) % 60))))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 0.00, Elapsed time : 0h 0m 0s
# Epoch : 0, Iteration : 5000, Loss : 10.00, Elapsed time : 0h 2m 59s
# Epoch : 0, Iteration : 10000, Loss : 11.37, Elapsed time : 0h 5m 58s
# Epoch : 0, Iteration : 15000, Loss : 11.74, Elapsed time : 0h 8m 55s
# Epoch : 0, Iteration : 20000, Loss : 12.34, Elapsed time : 0h 11m 55s
# Epoch : 0, Iteration : 25000, Loss : 12.17, Elapsed time : 0h 14m 57s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1cd62cc349c2> in <module>
#      17         optimizer.step()
#      18
# ---> 19         loss_sum += loss.item()
#      20
#      21
#
# KeyboardInterrupt:

# %%
loss_list
# Out:
# [0.0005745605945587158,
#  10.02176511733532,
#  11.425098068523408,
#  11.826040039253234,
#  12.383334763216972,
#  12.225234103822707,
#  12.67880032248497,
#  12.86963236951828,
#  13.007843869209289,
#  13.13612280216217,
#  13.476271239161491,
#  13.453285447978974,
#  13.470668102693558,
#  0.003104225730895996,
#  13.157839833402633,
#  13.535968757152558,
#  13.607075172042848,
#  13.974857963848114,
#  13.591038508081436,
#  13.921441784286499,
#  14.014648396110534,
#  14.00666575360298,
#  14.127059470653533,
#  14.351413330006599,
#  14.363250390291213,
#  14.28175492105484,
#  0.0036888301849365233,
#  14.223878271436691,
#  14.517246251249313,
#  14.586306466960908,
#  14.891861845588684,
#  14.466046053171159,
#  14.762128620672225,
#  14.8515643948555,
#  14.79289354031086,
#  14.860556393527984,
#  15.09759289278984,
#  15.066067840290069,
#  14.960454318523407,
#  0.0039915313720703125,
#  14.946340364265442,
#  15.281578950119018,
#  15.319596318340302,
#  15.589763642263412,
#  15.07018791975975,
#  15.447830223941803,
#  15.49682971944809,
#  15.365013433384895,
#  15.488087014198303,
#  15.700103702926636,
#  15.627354362773895,
#  15.482599057722092,
#  0.003897018814086914,
#  15.461206577634812,
#  15.799407032775878,
#  15.810027851104737,
#  16.07196064274311,
#  15.611324257183075,
#  15.941523934268952,
#  15.983788032531738,
#  15.822558518075944,
#  15.942191675567628,
#  16.19963607826233,
#  16.1072118224144,
#  15.961309335899353,
#  0.004267244720458984,
#  15.923095729970932,
#  16.249126905298233,
#  16.29218107290268,
#  16.54239594554901,
#  16.0307047478199,
#  16.360100191164015,
#  16.36438196468353,
#  16.29197000761032,
#  16.351906469535827,
#  16.58254429552555,
#  16.5109531832695,
#  16.348442587804794]

# %%
plt.plot(loss_list)

# %%
save_path = 'NPLM_{}epoch.pt'.format(epoch)
torch.save(model.state_dict(), save_path)

# %%
for data in model.emb.parameters():
    nplm_matrix = data

# %%
nplm_matrix
# Out:
# Parameter containing:
# tensor([[-1.5547, -1.6560, -2.5690,  ...,  0.2747,  0.7930, -1.5978],
#         [ 3.8324, -0.7555, -0.3985,  ..., -1.9352, -1.5792, -0.8591],
#         [-2.1034, -1.4747, -0.8482,  ...,  0.4838,  1.0369,  1.6503],
#         ...,
#         [ 0.6600, -2.3893, -0.4946,  ...,  0.7379, -0.7645,  2.1367],
#         [-1.1037,  0.1370,  2.3035,  ..., -1.9119, -0.9394, -0.0061],
#         [-0.0583,  0.2920, -0.8484,  ..., -0.7517, -0.2395,  0.7358]],
#        device='cuda:0', requires_grad=True)

# %%
save_path = 'NPLM_5epoch.pt'
model = model = NPLM(N, VEC_DIM, HIDDEN_DIM)
model.load_state_dict(torch.load(save_path))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-595ddc751920> in <module>
#       1 save_path = 'NPLM_5epoch.pt'
#       2 model = model = NPLM(N, VEC_DIM, HIDDEN_DIM)
# ----> 3 model.load_state_dict(torch.load(save_path))
#       4 model.eval()
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NPLM_5epoch.pt'
