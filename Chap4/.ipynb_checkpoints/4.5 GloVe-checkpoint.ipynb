# %% [markdown]
# # 4.5 GloVe
#
# 글로브를 구현...은 좀 귀찮고, 대신 저자들이 제공한 모델을 이용해서 학습시킨 후 벡터 표현을 점검해보자.
#
# 일단 GloVe 는 C++ 구현체로 돌릴 수 있다.
#
# 옵션은 다음과 같다.
# * min-count : 최소 빈도수
# * window-size : 고려 대상 문맥 길이
# * vector-size : 임베딩 차원수
#
# ### 1) vocab_count
# This tool requires an input corpus that should already consist of whitespace-separated tokens. Use something like the Stanford Tokenizer first on raw text. From the corpus, it constructs unigram counts from a corpus, and optionally thresholds the resulting vocabulary based on total vocabulary size or minimum frequency count.
#
# `models/glove/build/vocab_count -min-count 5 -verbose 2 < data/tokenized/corpus_mecab.txt > data/word-embeddings/glove/glove.vocab`
#
# ### 2) cooccur
# Constructs word-word cooccurrence statistics from a corpus. The user should supply a vocabulary file, as produced by `vocab_count`, and may specify a variety of parameters, as described by running `./build/cooccur`.
#
# `models/glove/build/cooccur -memory 10.0 -vocab-file data/word-embeddings/glove/glove.vocab -verbose 2 -window-size 15 < data/tokenized/corpus_mecab.txt > data/word-embeddings/glove/glove.cooc`
#
# ### 3) shuffle
# Shuffles the binary file of cooccurrence statistics produced by `cooccur`. For large files, the file is automatically split into chunks, each of which is shuffled and stored on disk before being merged and shuffled together. The user may specify a number of parameters, as described by running `./build/shuffle`.
#
# `models/glove/build/shuffle -memory 10.0 -verbose 2 < data/word-embeddings/glove/glove.cooc > data/word-embeddings/glove/glove.shuf`
#
# ### 4) glove
# Train the GloVe model on the specified cooccurrence data, which typically will be the output of the `shuffle` tool. The user should supply a vocabulary file, as given by vocab_count, and may specify a number of other parameters, which are described by running `./build/glove`.
#
# `models/glove/build/glove -save-file data/word-embeddings/glove/glove.vecs -threads 4 -input-file data/word-embeddings/glove/glove.shuf -x-max 10 -iter 15 -vector-size 100 -binary 2 -vocab-file data/word-embeddings/glove/glove.vocab -verbose 2`

# %% [markdown]
# ### 이렇게 훈련한 GloVe 데이터를 불러와보자.

# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd

dev = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
dev
# Out:
# device(type='cuda')

# %%
vec_path = '../data/word-embeddings/glove/glove.vecs.txt'
#word2id_path = '../data/word-embeddings/glove/glove.vocab'

# %% [markdown]
# ### 원래 vocab 파일을 불러서 아래와 같이 딕셔너리 구성하려고 했으나... 그럴 필요가 없다는 걸 깨달음.
#
# 따라서 안해도 됨... 이유는 word2id 의 id와 vector matrix의 index가 일치하지 않기 때문.

# %%
word2id = dict()
for sent in open(word2id_path, 'r', encoding='utf-8').readlines():
    (word, id) = sent.replace('\n','').strip().split() 
    word2id[word] = int(id)

# %%
id2word = []
for word, _ in word2id.items():
    id2word.append(word)

# %%
len(word2id), len(id2word)
# Out:
# (358042, 358042)

# %%
word2id['한국']
# Out:
# 138609

# %%
mat_df2.iloc[138609]
# Out:
# 1     -0.354456
# 2      0.058935
# 3      0.115488
# 4      0.076369
# 5      0.624948
#          ...
# 96     0.206904
# 97    -0.097000
# 98    -0.085081
# 99    -0.179100
# 100   -0.396120
# Name: 박세훈, Length: 100, dtype: float32

# %% [markdown]
# 위와 같이 word2id와 mat_df2의 index가 일치하지 않음....
#
# ### GloVe의 결과 벡터를 불러와서 처리하자.

# %%
mat = [vec.replace('\n','').split() for vec in open(vec_path, 'r', encoding='utf-8').readlines()]

# %%
mat_df = pd.DataFrame(mat)

# %%
ind = mat_df[0]

# %%
mat_df2 = mat_df.iloc[:,1:].astype(np.float32).copy()

# %%
mat_df2.index = ind

# %%
mat_df2.head()
# Out:
#         1         2         3         4         5         6         7    \
# 0
# 1 -0.358644  0.245709  0.216245 -0.190436 -0.756802 -0.563763 -0.328874
# . -0.291055  0.236648 -0.276704 -0.208636 -0.269282  0.119725 -0.307835
# 0 -0.091244  0.077856  0.729488  0.075314 -0.957595 -0.647040 -0.490441
# 2 -0.163885 -0.170753  0.440817 -0.027542 -0.971290 -0.643265 -0.368717
# 의  0.002961  0.369871  0.323835 -0.402710  0.380283 -0.841707 -0.030860
#
#         8         9         10   ...       91        92        93        94   \
# 0                                ...
# 1  0.017780 -0.797071 -0.240773  ... -0.482112  0.669735 -0.020597 -0.428709
# . -0.857031 -0.106891 -0.828509  ...  0.616154 -0.067340  0.387378 -0.022754
# 0  0.066009 -0.465373 -0.746489  ... -0.511708  0.235092 -0.045828 -0.399763
# 2  0.307056 -0.738059 -0.345742  ... -0.548439  0.551585  0.184272 -0.720818
# 의  0.863469 -0.992069 -0.827821  ...  0.581238  0.168463  0.432114 -1.164212
#
#         95        96        97        98        99        100
# 0
# 1 -0.446869 -0.444151  1.327251  0.145156 -0.057706  0.518008
# . -1.108870 -0.222616  1.889070  0.173319 -0.077478  1.213262
# 0 -0.744628 -0.772276  1.392470 -0.256552 -0.144649  0.454234
# 2 -0.860157 -0.475679  1.411633 -0.299546 -0.047707  0.105494
# 의 -0.625309 -0.036693  1.908723  0.173384  0.200731  0.152150
#
# [5 rows x 100 columns]

# %%
mat_df2.values
# Out:
# array([[-0.358644,  0.245709,  0.216245, ...,  0.145156, -0.057706,
#          0.518008],
#        [-0.291055,  0.236648, -0.276704, ...,  0.173319, -0.077478,
#          1.213262],
#        [-0.091244,  0.077856,  0.729488, ..., -0.256552, -0.144649,
#          0.454234],
#        ...,
#        [ 0.10549 , -0.031464, -0.103652, ..., -0.043713, -0.007134,
#         -0.082403],
#        [-0.174097, -0.066783,  0.121074, ...,  0.035401,  0.001533,
#         -0.125724],
#        [-0.011894, -0.004993,  0.022187, ...,  0.040329, -0.075547,
#         -0.08533 ]], dtype=float32)

# %% [markdown]
# ### 이렇게 생성된 데이터프레임으로 word2id 재생성

# %%
word2id = dict()
id2word = []
for i, word in enumerate(ind):
    word2id[word] = i
    id2word.append(word)

# %%
word2id
# Out:
# {'1': 0,
#  '.': 1,
#  '0': 2,
#  '2': 3,
#  '의': 4,
#  ',': 5,
#  '이': 6,
#  '는': 7,
#  '다': 8,
#  ')': 9,
#  '(': 10,
#  '9': 11,
#  '년': 12,
#  '에': 13,
#  '을': 14,
#  '하': 15,
#  '3': 16,
#  '5': 17,
#  '4': 18,
#  '8': 19,
#  '은': 20,
#  '6': 21,
#  '7': 22,
#  ':': 23,
#  '를': 24,
#  '월': 25,
#  '분류': 26,
#  '일': 27,
#  '고': 28,
#  '-': 29,
#  '가': 30,
#  '있': 31,
#  '에서': 32,
#  '으로': 33,
#  '로': 34,
#  '한': 35,
#  '되': 36,
#  '었': 37,
#  '과': 38,
#  '들': 39,
#  '와': 40,
#  '도': 41,
#  '했': 42,
#  '적': 43,
#  '인': 44,
#  '였': 45,
#  '그': 46,
#  '어': 47,
#  '기': 48,
#  '《': 49,
#  '제': 50,
#  '것': 51,
#  '*': 52,
#  '~': 53,
#  '게': 54,
#  '지': 55,
#  '"': 56,
#  '》': 57,
#  '여': 58,
#  '한다': 59,
#  '수': 60,
#  '역': 61,
#  '된': 62,
#  '등': 63,
#  '/': 64,
#  '며': 65,
#  '대': 66,
#  '·': 67,
#  '회': 68,
#  '선수': 69,
#  '영화': 70,
#  '대한민국': 71,
#  '할': 72,
#  '던': 73,
#  '해': 74,
#  '아': 75,
#  '만': 76,
#  '%': 77,
#  '명': 78,
#  '않': 79,
#  '자': 80,
#  '시': 81,
#  '에게': 82,
#  '중': 83,
#  '주': 84,
#  '까지': 85,
#  '미국': 86,
#  '았': 87,
#  '나': 88,
#  '번': 89,
#  '면': 90,
#  '지만': 91,
#  '일본': 92,
#  '없': 93,
#  '사람': 94,
#  '받': 95,
#  '성': 96,
#  '위': 97,
#  '때': 98,
#  '축구': 99,
#  '전': 100,
#  '으며': 101,
#  '#': 102,
#  '된다': 103,
#  '세': 104,
#  '개': 105,
#  '부터': 106,
#  '후': 107,
#  '화': 108,
#  '라고': 109,
#  '사용': 110,
#  '호': 111,
#  '같': 112,
#  '말': 113,
#  '라는': 114,
#  '팀': 115,
#  '학교': 116,
#  '이후': 117,
#  '및': 118,
#  '?': 119,
#  '는데': 120,
#  '두': 121,
#  '면서': 122,
#  '선': 123,
#  '한국': 124,
#  '차': 125,
#  '라': 126,
#  '대학교': 127,
#  '서울': 128,
#  '–': 129,
#  '보': 130,
#  '대한': 131,
#  '권': 132,
#  '상': 133,
#  '경기': 134,
#  '|': 135,
#  '지역': 136,
#  '군': 137,
#  '리그': 138,
#  '다고': 139,
#  '!': 140,
#  '때문': 141,
#  '국가': 142,
#  '이름': 143,
#  '시작': 144,
#  '더': 145,
#  '함께': 146,
#  '세계': 147,
#  '다른': 148,
#  '내': 149,
#  '경우': 150,
#  '현재': 151,
#  '살': 152,
#  '위해': 153,
#  '많': 154,
#  '방송': 155,
#  'KBS': 156,
#  'of': 157,
#  '부': 158,
#  '여자': 159,
#  '자신': 160,
#  '기록': 161,
#  '조선': 162,
#  '또한': 163,
#  '대표': 164,
#  'A': 165,
#  '안': 166,
#  '다음': 167,
#  '째': 168,
#  '대학': 169,
#  '사': 170,
#  '당시': 171,
#  '게임': 172,
#  '분': 173,
#  '형': 174,
#  '오': 175,
#  '하나': 176,
#  '신': 177,
#  '서': 178,
#  '다는': 179,
#  '배우': 180,
#  '이나': 181,
#  '가지': 182,
#  'm': 183,
#  '감독': 184,
#  '고등학교': 185,
#  '출신': 186,
#  '작품': 187,
#  '가장': 188,
#  '씨': 189,
#  '계': 190,
#  '구': 191,
#  '시즌': 192,
#  '드라마': 193,
#  '활동': 194,
#  '남': 195,
#  '당': 196,
#  '그러나': 197,
#  '+': 198,
#  '〈': 199,
#  '또는': 200,
#  '데': 201,
#  '..': 202,
#  '위치': 203,
#  '간': 204,
#  '동': 205,
#  '영국': 206,
#  '점': 207,
#  'MBC': 208,
#  '시간': 209,
#  '따라': 210,
#  '‘': 211,
#  '첫': 212,
#  '원': 213,
#  '태어남': 214,
#  '남자': 215,
#  '그리고': 216,
#  '중국': 217,
#  '대회': 218,
#  '아니': 219,
#  '시대': 220,
#  '만들': 221,
#  '지방': 222,
#  '세기': 223,
#  '다시': 224,
#  '올림픽': 225,
#  '의해': 226,
#  '음': 227,
#  '설립': 228,
#  '도시': 229,
#  '전쟁': 230,
#  '보다': 231,
#  '함': 232,
#  '정부': 233,
#  '프랑스': 234,
#  '뒤': 235,
#  'px': 236,
#  '독일': 237,
#  '조': 238,
#  'TV': 239,
#  '사이': 240,
#  '’': 241,
#  '현': 242,
#  '〉': 243,
#  '길': 244,
#  '포함': 245,
#  '사회': 246,
#  '가능': 247,
#  '통해': 248,
#  '참가': 249,
#  'the': 250,
#  '이상': 251,
#  'The': 252,
#  '음악': 253,
#  '알': 254,
#  '스': 255,
#  '비': 256,
#  '동문': 257,
#  '초등': 258,
#  '교육': 259,
#  '네': 260,
#  '좋': 261,
#  '모든': 262,
#  '는다': 263,
#  '우승': 264,
#  '강': 265,
#  '로서': 266,
#  'km': 267,
#  '연구': 268,
#  '역사': 269,
#  '다가': 270,
#  '장': 271,
#  '모두': 272,
#  '왕': 273,
#  '사건': 274,
#  '정치': 275,
#  '으나': 276,
#  '지정': 277,
#  '집': 278,
#  '일부': 279,
#  '공식': 280,
#  '문화': 281,
#  '&': 282,
#  '위한': 283,
#  '처음': 284,
#  '여러': 285,
#  '문제': 286,
#  '졸업': 287,
#  '큰': 288,
#  '사랑': 289,
#  '초': 290,
#  '국제': 291,
#  'SBS': 292,
#  '개발': 293,
#  '위원회': 294,
#  '지원': 295,
#  '소속': 296,
#  '일반': 297,
#  '대통령': 298,
#  '아들': 299,
#  '기술': 300,
#  '크': 301,
#  '**': 302,
#  '곡': 303,
#  '정보': 304,
#  '산': 305,
#  '정도': 306,
#  '총': 307,
#  '속': 308,
#  '제작': 309,
#  'B': 310,
#  '리': 311,
#  '결과': 312,
#  '동안': 313,
#  '출연': 314,
#  '프로그램': 315,
#  '존재': 316,
#  '될': 317,
#  '이용': 318,
#  '진': 319,
#  '최고': 320,
#  '또': 321,
#  'FC': 322,
#  '설치': 323,
#  '중학교': 324,
#  '관계': 325,
#  '약': 326,
#  '거나': 327,
#  '주장': 328,
#  '트': 329,
#  '드': 330,
#  '삼': 331,
#  '야': 332,
#  '나라': 333,
#  'C': 334,
#  '무': 335,
#  '발표': 336,
#  '》(': 337,
#  '구성': 338,
#  '였으며': 339,
#  '곳': 340,
#  '단': 341,
#  '시리즈': 342,
#  '편': 343,
#  '그룹': 344,
#  '정': 345,
#  '변경': 346,
#  'and': 347,
#  '생각': 348,
#  '높': 349,
#  '이전': 350,
#  '대상': 351,
#  '대해': 352,
#  '경제': 353,
#  '섬': 354,
#  '대전': 355,
#  'K': 356,
#  '“': 357,
#  '우리': 358,
#  '법': 359,
#  '센터': 360,
#  '중앙': 361,
#  '운동': 362,
#  '”': 363,
#  '운영': 364,
#  '최초': 365,
#  '가수': 366,
#  '시키': 367,
#  '로부터': 368,
#  '재': 369,
#  '잘': 370,
#  '날': 371,
#  '교수': 372,
#  '승': 373,
#  '「': 374,
#  '앨범': 375,
#  '」': 376,
#  '타': 377,
#  '노래': 378,
#  '아버지': 379,
#  '각': 380,
#  '철도': 381,
#  '니': 382,
#  '전투': 383,
#  '도록': 384,
#  '용': 385,
#  '러시아': 386,
#  '관련': 387,
#  '반': 388,
#  '행정': 389,
#  '유럽': 390,
#  '죽음': 391,
#  '맡': 392,
#  'jpg': 393,
#  '어서': 394,
#  '이러': 395,
#  '진행': 396,
#  '작': 397,
#  '텔레비전': 398,
#  '제국': 399,
#  '과정': 400,
#  '발견': 401,
#  '공격': 402,
#  '불': 403,
#  '예': 404,
#  '죽': 405,
#  '과학': 406,
#  '미': 407,
#  '진출': 408,
#  '도쿄': 409,
#  '자유': 410,
#  '그녀': 411,
#  '천': 412,
#  '부분': 413,
#  '부산': 414,
#  '발생': 415,
#  '테': 416,
#  '이탈리아': 417,
#  '쓰': 418,
#  '층': 419,
#  '새': 420,
#  '구간': 421,
#  '결정': 422,
#  '여성': 423,
#  '별': 424,
#  '생': 425,
#  '볼': 426,
#  '같이': 427,
#  '데뷔': 428,
#  '얻': 429,
#  '키': 430,
#  '관리': 431,
#  '경기도': 432,
#  '프로': 433,
#  '기준': 434,
#  '상태': 435,
#  '필요': 436,
#  '운행': 437,
#  '로마': 438,
#  '노선': 439,
#  '등장': 440,
#  '했으며': 441,
#  'D': 442,
#  '버스': 443,
#  '선거': 444,
#  '의미': 445,
#  '란': 446,
#  'M': 447,
#  '부문': 448,
#  '대부분': 449,
#  '해서': 450,
#  '내용': 451,
#  '패': 452,
#  '고려': 453,
#  's': 454,
#  '아이': 455,
#  '거리': 456,
#  '하지만': 457,
#  '----': 458,
#  '으로서': 459,
#  '철도역': 460,
#  '참여': 461,
#  '음반': 462,
#  '연기': 463,
#  '수상': 464,
#  '기업': 465,
#  '애니메이션': 466,
#  '사업': 467,
#  '金': 468,
#  '상대': 469,
#  '중심': 470,
#  '구조': 471,
#  '이야기': 472,
#  '뜻': 473,
#  '특별': 474,
#  '끝': 475,
#  '형태': 476,
#  '인해': 477,
#  '사망': 478,
#  '외': 479,
#  '인가': 480,
#  '새로운': 481,
#  '특히': 482,
#  '본': 483,
#  '즉': 484,
#  '발매': 485,
#  '조직': 486,
#  '현대': 487,
#  '이것': 488,
#  '계획': 489,
#  '순위': 490,
#  '의원': 491,
#  '李': 492,
#  '배': 493,
#  '사실': 494,
#  '싱글': 495,
#  '처럼': 496,
#  '계속': 497,
#  '시장': 498,
#  'S': 499,
#  '백': 500,
#  '카': 501,
#  '달': 502,
#  '학급': 503,
#  '성우': 504,
#  'U': 505,
#  '열': 506,
#  '모습': 507,
#  'X': 508,
#  '인간': 509,
#  '해당': 510,
#  '기간': 511,
#  '뿐': 512,
#  '됐': 513,
#  '야구': 514,
#  '영향': 515,
#  '→': 516,
#  '—': 517,
#  '회사': 518,
#  '시스템': 519,
#  'in': 520,
#  '후보': 521,
#  '치': 522,
#  '마지막': 523,
#  '바': 524,
#  '주로': 525,
#  '딸': 526,
#  '↔': 527,
#  '국': 528,
#  '매우': 529,
#  '골': 530,
#  '독립': 531,
#  '기관': 532,
#  '교통': 533,
#  '다양': 534,
#  '방면': 535,
#  '물': 536,
#  '중요': 537,
#  '보이': 538,
#  '지구': 539,
#  '×': 540,
#  '자리': 541,
#  '이유': 542,
#  '정책': 543,
#  '대신': 544,
#  '입': 545,
#  '편성': 546,
#  '영어': 547,
#  '인구': 548,
#  '방법': 549,
#  '양': 550,
#  '공동': 551,
#  '위원': 552,
#  '대구': 553,
#  '많이': 554,
#  '인물': 555,
#  '판': 556,
#  '성공': 557,
#  '생활': 558,
#  '겠': 559,
#  '르': 560,
#  '공화국': 561,
#  '산업': 562,
#  '조사': 563,
#  '국민': 564,
#  '모델': 565,
#  '홈페이지': 566,
#  '역할': 567,
#  '월드컵': 568,
#  '지금': 569,
#  '단체': 570,
#  '관한': 571,
#  '승리': 572,
#  '엔': 573,
#  '마을': 574,
#  '전국': 575,
#  '못하': 576,
#  '억': 577,
#  '제도': 578,
#  'F': 579,
#  '사이트': 580,
#  '선거구': 581,
#  '노': 582,
#  'E': 583,
#  '전체': 584,
#  ';': 585,
#  '급': 586,
#  '방식': 587,
#  '제공': 588,
#  '시기': 589,
#  '책': 590,
#  '평가': 591,
#  '코': 592,
#  '식': 593,
#  '구역': 594,
#  '결국': 595,
#  '존': 596,
#  '컵': 597,
#  '친구': 598,
#  '기타': 599,
#  '종': 600,
#  '루': 601,
#  '민족': 602,
#  '기원전': 603,
#  '앞': 604,
#  '협회': 605,
#  '=': 606,
#  '주요': 607,
#  '예술': 608,
#  '개최': 609,
#  '민주당': 610,
#  '작곡': 611,
#  '갖': 612,
#  '쇼': 613,
#  '였으나': 614,
#  '동시': 615,
#  '따르': 616,
#  '류': 617,
#  '몇': 618,
#  '온': 619,
#  '표현': 620,
#  '기능': 621,
#  '생산': 622,
#  '차지': 623,
#  '군사': 624,
#  '한편': 625,
#  '실': 626,
#  '정당': 627,
#  '추가': 628,
#  '어머니': 629,
#  '해야': 630,
#  '아래': 631,
#  '비고': 632,
#  '발': 633,
#  '공개': 634,
#  '가운데': 635,
#  '인천': 636,
#  '학생': 637,
#  '발전': 638,
#  '스타': 639,
#  '소': 640,
#  '우주': 641,
#  '여기': 642,
#  '건설': 643,
#  '작가': 644,
#  'FIFA': 645,
#  '유지': 646,
#  '이루': 647,
#  '초기': 648,
#  '으로써': 649,
#  '김': 650,
#  'O': 651,
#  '으로부터': 652,
#  '교회': 653,
#  '민주': 654,
#  '라디오': 655,
#  '비디오': 656,
#  '폐지': 657,
#  '연도': 658,
#  'R': 659,
#  '공연': 660,
#  '마': 661,
#  '출전': 662,
#  '공사': 663,
#  '연결': 664,
#  '스페인': 665,
#  '시절': 666,
#  '각각': 667,
#  '목록': 668,
#  '찾': 669,
#  '준': 670,
#  '항공': 671,
#  '・': 672,
#  '소설': 673,
#  '개인': 674,
#  '전기': 675,
#  '유명': 676,
#  '가족': 677,
#  '명칭': 678,
#  '공간': 679,
#  '육군': 680,
#  '피': 681,
#  '도로': 682,
#  '티': 683,
#  '통합': 684,
#  '문': 685,
#  '손': 686,
#  'T': 687,
#  'I': 688,
#  '상황': 689,
#  '밤': 690,
#  '결혼': 691,
#  '스포츠': 692,
#  '언어': 693,
#  '경': 694,
#  '공': 695,
#  '장관': 696,
#  '공항': 697,
#  '임': 698,
#  '인민공화국': 699,
#  '열린': 700,
#  '이론': 701,
#  '거의': 702,
#  '계약': 703,
#  'G': 704,
#  '수록': 705,
#  '연속': 706,
#  '잉글랜드': 707,
#  '잡': 708,
#  '반대': 709,
#  '어떤': 710,
#  '직접': 711,
#  '따라서': 712,
#  '웹': 713,
#  '서비스': 714,
#  '역시': 715,
#  '정의': 716,
#  '선정': 717,
#  '규모': 718,
#  '시설': 719,
#  '클럽': 720,
#  '광주': 721,
#  '배경': 722,
#  '서로': 723,
#  '목적': 724,
#  '경상북도': 725,
#  '임명': 726,
#  '취임': 727,
#  '나오': 728,
#  '연합': 729,
#  'a': 730,
#  '그리스': 731,
#  '이르': 732,
#  '없이': 733,
#  '불리': 734,
#  '종합': 735,
#  '본선': 736,
#  '마음': 737,
#  '먼': 738,
#  '건물': 739,
#  'x': 740,
#  '즈': 741,
#  '소련': 742,
#  '너무': 743,
#  '차량': 744,
#  '환경': 745,
#  '자료': 746,
#  '만든': 747,
#  '했으나': 748,
#  'J': 749,
#  '님': 750,
#  '이런': 751,
#  '황제': 752,
#  '거': 753,
#  '방향': 754,
#  '열차': 755,
#  '회장': 756,
#  '하계': 757,
#  '인도': 758,
#  '기본': 759,
#  '파': 760,
#  '『': 761,
#  '작사': 762,
#  '그것': 763,
#  '의회': 764,
#  '담당': 765,
#  '줄': 766,
#  '글': 767,
#  '됨': 768,
#  '능력': 769,
#  '행위': 770,
#  '건': 771,
#  '난': 772,
#  '경찰': 773,
#  '변화': 774,
#  '사상': 775,
#  '론': 776,
#  '자동차': 777,
#  '제외': 778,
#  '국회의원': 779,
#  '표': 780,
#  '기획': 781,
#  '사고': 782,
#  '동물': 783,
#  '달리': 784,
#  '국제공항': 785,
#  '학년': 786,
#  '실시': 787,
#  '아시아': 788,
#  '국립': 789,
#  '활약': 790,
#  '제목': 791,
#  '맞': 792,
#  '시켰': 793,
#  '도입': 794,
#  'V': 795,
#  '컴퓨터': 796,
#  '개통': 797,
#  '자연': 798,
#  '졌': 799,
#  '눈': 800,
#  '시청': 801,
#  '예선': 802,
#  '뉴욕': 803,
#  '전라남도': 804,
#  '\ufeff': 805,
#  '캐나다': 806,
#  '싶': 807,
#  '소재': 808,
#  '최대': 809,
#  '돈': 810,
#  '원래': 811,
#  '막': 812,
#  '낮': 813,
#  '밴드': 814,
#  '공원': 815,
#  '의한': 816,
#  '쿠': 817,
#  '인정': 818,
#  '최': 819,
#  '먹': 820,
#  '번호': 821,
#  '의하': 822,
#  '기독교': 823,
#  '시민': 824,
#  '대학원': 825,
#  '왔': 826,
#  '섬네일': 827,
#  '외국인': 828,
#  '평균': 829,
#  '멤버': 830,
#  '전자': 831,
#  '밖': 832,
#  '개교': 833,
#  '수도': 834,
#  '아닌': 835,
#  '힘': 836,
#  '칸': 837,
#  '요구': 838,
#  '비롯': 839,
#  '저': 840,
#  '알려져': 841,
#  '승강장': 842,
#  '아시안': 843,
#  '형성': 844,
#  '과거': 845,
#  '보통': 846,
#  '거주': 847,
#  '부대': 848,
#  '》,': 849,
#  '사진': 850,
#  '경상남도': 851,
#  '만화': 852,
#  'mm': 853,
#  '종교': 854,
#  '전문': 855,
#  '나이': 856,
#  '출시': 857,
#  '뮤직': 858,
#  '가진': 859,
#  '버전': 860,
#  '채': 861,
#  '측': 862,
#  '기존': 863,
#  '득점': 864,
#  '대해서': 865,
#  '실패': 866,
#  '레': 867,
#  '병원': 868,
#  '팔': 869,
#  '일원': 870,
#  '으면': 871,
#  '삼성': 872,
#  'FM': 873,
#  '어느': 874,
#  '자기': 875,
#  '차트': 876,
#  '형식': 877,
#  '이적': 878,
#  '교장': 879,
#  '모양': 880,
#  '챔피언': 881,
#  '한다는': 882,
#  '비판': 883,
#  '설명': 884,
#  '투수': 885,
#  '사단': 886,
#  '민주주의': 887,
#  'cm': 888,
#  '월드': 889,
#  '므로': 890,
#  '부르': 891,
#  '세력': 892,
#  '혹은': 893,
#  '촬영': 894,
#  '기반': 895,
#  '터미널': 896,
#  '뉴스': 897,
#  '족': 898,
#  '분야': 899,
#  '바로': 900,
#  '회의': 901,
#  '대하': 902,
#  '비슷': 903,
#  '효과': 904,
#  '속도': 905,
#  '행동': 906,
#  '수행': 907,
#  '마다': 908,
#  '선택': 909,
#  '특수': 910,
#  '보호': 911,
#  '병': 912,
#  '위하': 913,
#  '놓': 914,
#  '캐릭터': 915,
#  '케': 916,
#  '채널': 917,
#  '개시': 918,
#  '라운드': 919,
#  '박물관': 920,
#  '전통': 921,
#  '연방': 922,
#  '남부': 923,
#  '석': 924,
#  '걸': 925,
#  '애': 926,
#  '몸': 927,
#  '왕국': 928,
#  '연대': 929,
#  '초대': 930,
#  '확인': 931,
#  '대로': 932,
#  '작전': 933,
#  '쪽': 934,
#  '관': 935,
#  '넘': 936,
#  '부인': 937,
#  '문학': 938,
#  '습니다': 939,
#  '주연': 940,
#  '최종': 941,
#  '는가': 942,
#  '보여': 943,
#  '디지털': 944,
#  '방영': 945,
#  '거쳐': 946,
#  '대사': 947,
#  '예정': 948,
#  '디자인': 949,
#  'UEFA': 950,
#  '경기장': 951,
#  '박사': 952,
#  'H': 953,
#  '의사': 954,
#  '적용': 955,
#  '기자': 956,
#  '교황': 957,
#  '조약': 958,
#  '해군': 959,
#  '연구소': 960,
#  '일제': 961,
#  '직': 962,
#  '이때': 963,
#  '우수': 964,
#  '차이': 965,
#  '인기': 966,
#  '특징': 967,
#  '카드': 968,
#  'P': 969,
#  '자체': 970,
#  '못': 971,
#  '이미': 972,
#  '서울특별시': 973,
#  '본부': 974,
#  '역임': 975,
#  '주민': 976,
#  '특별시': 977,
#  '氏': 978,
#  '강원도': 979,
#  '종류': 980,
#  '주변': 981,
#  '법원': 982,
#  '에너지': 983,
#  '유일': 984,
#  '아프리카': 985,
#  '작업': 986,
#  '분리': 987,
#  '러': 988,
#  '』': 989,
#  '디': 990,
#  '높이': 991,
#  'W': 992,
#  '못했': 993,
#  '군대': 994,
#  '듯': 995,
#  'L': 996,
#  '비교': 997,
#  '는지': 998,
#  '맨': 999,
#  ...}

# %%
id2word
# Out:
# ['1',
#  '.',
#  '0',
#  '2',
#  '의',
#  ',',
#  '이',
#  '는',
#  '다',
#  ')',
#  '(',
#  '9',
#  '년',
#  '에',
#  '을',
#  '하',
#  '3',
#  '5',
#  '4',
#  '8',
#  '은',
#  '6',
#  '7',
#  ':',
#  '를',
#  '월',
#  '분류',
#  '일',
#  '고',
#  '-',
#  '가',
#  '있',
#  '에서',
#  '으로',
#  '로',
#  '한',
#  '되',
#  '었',
#  '과',
#  '들',
#  '와',
#  '도',
#  '했',
#  '적',
#  '인',
#  '였',
#  '그',
#  '어',
#  '기',
#  '《',
#  '제',
#  '것',
#  '*',
#  '~',
#  '게',
#  '지',
#  '"',
#  '》',
#  '여',
#  '한다',
#  '수',
#  '역',
#  '된',
#  '등',
#  '/',
#  '며',
#  '대',
#  '·',
#  '회',
#  '선수',
#  '영화',
#  '대한민국',
#  '할',
#  '던',
#  '해',
#  '아',
#  '만',
#  '%',
#  '명',
#  '않',
#  '자',
#  '시',
#  '에게',
#  '중',
#  '주',
#  '까지',
#  '미국',
#  '았',
#  '나',
#  '번',
#  '면',
#  '지만',
#  '일본',
#  '없',
#  '사람',
#  '받',
#  '성',
#  '위',
#  '때',
#  '축구',
#  '전',
#  '으며',
#  '#',
#  '된다',
#  '세',
#  '개',
#  '부터',
#  '후',
#  '화',
#  '라고',
#  '사용',
#  '호',
#  '같',
#  '말',
#  '라는',
#  '팀',
#  '학교',
#  '이후',
#  '및',
#  '?',
#  '는데',
#  '두',
#  '면서',
#  '선',
#  '한국',
#  '차',
#  '라',
#  '대학교',
#  '서울',
#  '–',
#  '보',
#  '대한',
#  '권',
#  '상',
#  '경기',
#  '|',
#  '지역',
#  '군',
#  '리그',
#  '다고',
#  '!',
#  '때문',
#  '국가',
#  '이름',
#  '시작',
#  '더',
#  '함께',
#  '세계',
#  '다른',
#  '내',
#  '경우',
#  '현재',
#  '살',
#  '위해',
#  '많',
#  '방송',
#  'KBS',
#  'of',
#  '부',
#  '여자',
#  '자신',
#  '기록',
#  '조선',
#  '또한',
#  '대표',
#  'A',
#  '안',
#  '다음',
#  '째',
#  '대학',
#  '사',
#  '당시',
#  '게임',
#  '분',
#  '형',
#  '오',
#  '하나',
#  '신',
#  '서',
#  '다는',
#  '배우',
#  '이나',
#  '가지',
#  'm',
#  '감독',
#  '고등학교',
#  '출신',
#  '작품',
#  '가장',
#  '씨',
#  '계',
#  '구',
#  '시즌',
#  '드라마',
#  '활동',
#  '남',
#  '당',
#  '그러나',
#  '+',
#  '〈',
#  '또는',
#  '데',
#  '..',
#  '위치',
#  '간',
#  '동',
#  '영국',
#  '점',
#  'MBC',
#  '시간',
#  '따라',
#  '‘',
#  '첫',
#  '원',
#  '태어남',
#  '남자',
#  '그리고',
#  '중국',
#  '대회',
#  '아니',
#  '시대',
#  '만들',
#  '지방',
#  '세기',
#  '다시',
#  '올림픽',
#  '의해',
#  '음',
#  '설립',
#  '도시',
#  '전쟁',
#  '보다',
#  '함',
#  '정부',
#  '프랑스',
#  '뒤',
#  'px',
#  '독일',
#  '조',
#  'TV',
#  '사이',
#  '’',
#  '현',
#  '〉',
#  '길',
#  '포함',
#  '사회',
#  '가능',
#  '통해',
#  '참가',
#  'the',
#  '이상',
#  'The',
#  '음악',
#  '알',
#  '스',
#  '비',
#  '동문',
#  '초등',
#  '교육',
#  '네',
#  '좋',
#  '모든',
#  '는다',
#  '우승',
#  '강',
#  '로서',
#  'km',
#  '연구',
#  '역사',
#  '다가',
#  '장',
#  '모두',
#  '왕',
#  '사건',
#  '정치',
#  '으나',
#  '지정',
#  '집',
#  '일부',
#  '공식',
#  '문화',
#  '&',
#  '위한',
#  '처음',
#  '여러',
#  '문제',
#  '졸업',
#  '큰',
#  '사랑',
#  '초',
#  '국제',
#  'SBS',
#  '개발',
#  '위원회',
#  '지원',
#  '소속',
#  '일반',
#  '대통령',
#  '아들',
#  '기술',
#  '크',
#  '**',
#  '곡',
#  '정보',
#  '산',
#  '정도',
#  '총',
#  '속',
#  '제작',
#  'B',
#  '리',
#  '결과',
#  '동안',
#  '출연',
#  '프로그램',
#  '존재',
#  '될',
#  '이용',
#  '진',
#  '최고',
#  '또',
#  'FC',
#  '설치',
#  '중학교',
#  '관계',
#  '약',
#  '거나',
#  '주장',
#  '트',
#  '드',
#  '삼',
#  '야',
#  '나라',
#  'C',
#  '무',
#  '발표',
#  '》(',
#  '구성',
#  '였으며',
#  '곳',
#  '단',
#  '시리즈',
#  '편',
#  '그룹',
#  '정',
#  '변경',
#  'and',
#  '생각',
#  '높',
#  '이전',
#  '대상',
#  '대해',
#  '경제',
#  '섬',
#  '대전',
#  'K',
#  '“',
#  '우리',
#  '법',
#  '센터',
#  '중앙',
#  '운동',
#  '”',
#  '운영',
#  '최초',
#  '가수',
#  '시키',
#  '로부터',
#  '재',
#  '잘',
#  '날',
#  '교수',
#  '승',
#  '「',
#  '앨범',
#  '」',
#  '타',
#  '노래',
#  '아버지',
#  '각',
#  '철도',
#  '니',
#  '전투',
#  '도록',
#  '용',
#  '러시아',
#  '관련',
#  '반',
#  '행정',
#  '유럽',
#  '죽음',
#  '맡',
#  'jpg',
#  '어서',
#  '이러',
#  '진행',
#  '작',
#  '텔레비전',
#  '제국',
#  '과정',
#  '발견',
#  '공격',
#  '불',
#  '예',
#  '죽',
#  '과학',
#  '미',
#  '진출',
#  '도쿄',
#  '자유',
#  '그녀',
#  '천',
#  '부분',
#  '부산',
#  '발생',
#  '테',
#  '이탈리아',
#  '쓰',
#  '층',
#  '새',
#  '구간',
#  '결정',
#  '여성',
#  '별',
#  '생',
#  '볼',
#  '같이',
#  '데뷔',
#  '얻',
#  '키',
#  '관리',
#  '경기도',
#  '프로',
#  '기준',
#  '상태',
#  '필요',
#  '운행',
#  '로마',
#  '노선',
#  '등장',
#  '했으며',
#  'D',
#  '버스',
#  '선거',
#  '의미',
#  '란',
#  'M',
#  '부문',
#  '대부분',
#  '해서',
#  '내용',
#  '패',
#  '고려',
#  's',
#  '아이',
#  '거리',
#  '하지만',
#  '----',
#  '으로서',
#  '철도역',
#  '참여',
#  '음반',
#  '연기',
#  '수상',
#  '기업',
#  '애니메이션',
#  '사업',
#  '金',
#  '상대',
#  '중심',
#  '구조',
#  '이야기',
#  '뜻',
#  '특별',
#  '끝',
#  '형태',
#  '인해',
#  '사망',
#  '외',
#  '인가',
#  '새로운',
#  '특히',
#  '본',
#  '즉',
#  '발매',
#  '조직',
#  '현대',
#  '이것',
#  '계획',
#  '순위',
#  '의원',
#  '李',
#  '배',
#  '사실',
#  '싱글',
#  '처럼',
#  '계속',
#  '시장',
#  'S',
#  '백',
#  '카',
#  '달',
#  '학급',
#  '성우',
#  'U',
#  '열',
#  '모습',
#  'X',
#  '인간',
#  '해당',
#  '기간',
#  '뿐',
#  '됐',
#  '야구',
#  '영향',
#  '→',
#  '—',
#  '회사',
#  '시스템',
#  'in',
#  '후보',
#  '치',
#  '마지막',
#  '바',
#  '주로',
#  '딸',
#  '↔',
#  '국',
#  '매우',
#  '골',
#  '독립',
#  '기관',
#  '교통',
#  '다양',
#  '방면',
#  '물',
#  '중요',
#  '보이',
#  '지구',
#  '×',
#  '자리',
#  '이유',
#  '정책',
#  '대신',
#  '입',
#  '편성',
#  '영어',
#  '인구',
#  '방법',
#  '양',
#  '공동',
#  '위원',
#  '대구',
#  '많이',
#  '인물',
#  '판',
#  '성공',
#  '생활',
#  '겠',
#  '르',
#  '공화국',
#  '산업',
#  '조사',
#  '국민',
#  '모델',
#  '홈페이지',
#  '역할',
#  '월드컵',
#  '지금',
#  '단체',
#  '관한',
#  '승리',
#  '엔',
#  '마을',
#  '전국',
#  '못하',
#  '억',
#  '제도',
#  'F',
#  '사이트',
#  '선거구',
#  '노',
#  'E',
#  '전체',
#  ';',
#  '급',
#  '방식',
#  '제공',
#  '시기',
#  '책',
#  '평가',
#  '코',
#  '식',
#  '구역',
#  '결국',
#  '존',
#  '컵',
#  '친구',
#  '기타',
#  '종',
#  '루',
#  '민족',
#  '기원전',
#  '앞',
#  '협회',
#  '=',
#  '주요',
#  '예술',
#  '개최',
#  '민주당',
#  '작곡',
#  '갖',
#  '쇼',
#  '였으나',
#  '동시',
#  '따르',
#  '류',
#  '몇',
#  '온',
#  '표현',
#  '기능',
#  '생산',
#  '차지',
#  '군사',
#  '한편',
#  '실',
#  '정당',
#  '추가',
#  '어머니',
#  '해야',
#  '아래',
#  '비고',
#  '발',
#  '공개',
#  '가운데',
#  '인천',
#  '학생',
#  '발전',
#  '스타',
#  '소',
#  '우주',
#  '여기',
#  '건설',
#  '작가',
#  'FIFA',
#  '유지',
#  '이루',
#  '초기',
#  '으로써',
#  '김',
#  'O',
#  '으로부터',
#  '교회',
#  '민주',
#  '라디오',
#  '비디오',
#  '폐지',
#  '연도',
#  'R',
#  '공연',
#  '마',
#  '출전',
#  '공사',
#  '연결',
#  '스페인',
#  '시절',
#  '각각',
#  '목록',
#  '찾',
#  '준',
#  '항공',
#  '・',
#  '소설',
#  '개인',
#  '전기',
#  '유명',
#  '가족',
#  '명칭',
#  '공간',
#  '육군',
#  '피',
#  '도로',
#  '티',
#  '통합',
#  '문',
#  '손',
#  'T',
#  'I',
#  '상황',
#  '밤',
#  '결혼',
#  '스포츠',
#  '언어',
#  '경',
#  '공',
#  '장관',
#  '공항',
#  '임',
#  '인민공화국',
#  '열린',
#  '이론',
#  '거의',
#  '계약',
#  'G',
#  '수록',
#  '연속',
#  '잉글랜드',
#  '잡',
#  '반대',
#  '어떤',
#  '직접',
#  '따라서',
#  '웹',
#  '서비스',
#  '역시',
#  '정의',
#  '선정',
#  '규모',
#  '시설',
#  '클럽',
#  '광주',
#  '배경',
#  '서로',
#  '목적',
#  '경상북도',
#  '임명',
#  '취임',
#  '나오',
#  '연합',
#  'a',
#  '그리스',
#  '이르',
#  '없이',
#  '불리',
#  '종합',
#  '본선',
#  '마음',
#  '먼',
#  '건물',
#  'x',
#  '즈',
#  '소련',
#  '너무',
#  '차량',
#  '환경',
#  '자료',
#  '만든',
#  '했으나',
#  'J',
#  '님',
#  '이런',
#  '황제',
#  '거',
#  '방향',
#  '열차',
#  '회장',
#  '하계',
#  '인도',
#  '기본',
#  '파',
#  '『',
#  '작사',
#  '그것',
#  '의회',
#  '담당',
#  '줄',
#  '글',
#  '됨',
#  '능력',
#  '행위',
#  '건',
#  '난',
#  '경찰',
#  '변화',
#  '사상',
#  '론',
#  '자동차',
#  '제외',
#  '국회의원',
#  '표',
#  '기획',
#  '사고',
#  '동물',
#  '달리',
#  '국제공항',
#  '학년',
#  '실시',
#  '아시아',
#  '국립',
#  '활약',
#  '제목',
#  '맞',
#  '시켰',
#  '도입',
#  'V',
#  '컴퓨터',
#  '개통',
#  '자연',
#  '졌',
#  '눈',
#  '시청',
#  '예선',
#  '뉴욕',
#  '전라남도',
#  '\ufeff',
#  '캐나다',
#  '싶',
#  '소재',
#  '최대',
#  '돈',
#  '원래',
#  '막',
#  '낮',
#  '밴드',
#  '공원',
#  '의한',
#  '쿠',
#  '인정',
#  '최',
#  '먹',
#  '번호',
#  '의하',
#  '기독교',
#  '시민',
#  '대학원',
#  '왔',
#  '섬네일',
#  '외국인',
#  '평균',
#  '멤버',
#  '전자',
#  '밖',
#  '개교',
#  '수도',
#  '아닌',
#  '힘',
#  '칸',
#  '요구',
#  '비롯',
#  '저',
#  '알려져',
#  '승강장',
#  '아시안',
#  '형성',
#  '과거',
#  '보통',
#  '거주',
#  '부대',
#  '》,',
#  '사진',
#  '경상남도',
#  '만화',
#  'mm',
#  '종교',
#  '전문',
#  '나이',
#  '출시',
#  '뮤직',
#  '가진',
#  '버전',
#  '채',
#  '측',
#  '기존',
#  '득점',
#  '대해서',
#  '실패',
#  '레',
#  '병원',
#  '팔',
#  '일원',
#  '으면',
#  '삼성',
#  'FM',
#  '어느',
#  '자기',
#  '차트',
#  '형식',
#  '이적',
#  '교장',
#  '모양',
#  '챔피언',
#  '한다는',
#  '비판',
#  '설명',
#  '투수',
#  '사단',
#  '민주주의',
#  'cm',
#  '월드',
#  '므로',
#  '부르',
#  '세력',
#  '혹은',
#  '촬영',
#  '기반',
#  '터미널',
#  '뉴스',
#  '족',
#  '분야',
#  '바로',
#  '회의',
#  '대하',
#  '비슷',
#  '효과',
#  '속도',
#  '행동',
#  '수행',
#  '마다',
#  '선택',
#  '특수',
#  '보호',
#  '병',
#  '위하',
#  '놓',
#  '캐릭터',
#  '케',
#  '채널',
#  '개시',
#  '라운드',
#  '박물관',
#  '전통',
#  '연방',
#  '남부',
#  '석',
#  '걸',
#  '애',
#  '몸',
#  '왕국',
#  '연대',
#  '초대',
#  '확인',
#  '대로',
#  '작전',
#  '쪽',
#  '관',
#  '넘',
#  '부인',
#  '문학',
#  '습니다',
#  '주연',
#  '최종',
#  '는가',
#  '보여',
#  '디지털',
#  '방영',
#  '거쳐',
#  '대사',
#  '예정',
#  '디자인',
#  'UEFA',
#  '경기장',
#  '박사',
#  'H',
#  '의사',
#  '적용',
#  '기자',
#  '교황',
#  '조약',
#  '해군',
#  '연구소',
#  '일제',
#  '직',
#  '이때',
#  '우수',
#  '차이',
#  '인기',
#  '특징',
#  '카드',
#  'P',
#  '자체',
#  '못',
#  '이미',
#  '서울특별시',
#  '본부',
#  '역임',
#  '주민',
#  '특별시',
#  '氏',
#  '강원도',
#  '종류',
#  '주변',
#  '법원',
#  '에너지',
#  '유일',
#  '아프리카',
#  '작업',
#  '분리',
#  '러',
#  '』',
#  '디',
#  '높이',
#  'W',
#  '못했',
#  '군대',
#  '듯',
#  'L',
#  '비교',
#  '는지',
#  '맨',
#  ...]

# %% [markdown]
# ### 이제 유사도를 측정해보자.

# %%
def similar_words(mat_df, word, k=10):
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    
    word_id = word2id[word]
    word_vec = torch.tensor(mat_df.loc[word].values).view(1,-1)
    word_mat = torch.tensor(mat_df.values)
#    print(word_vec.size(), word_mat.size())
    cos_mat = cos(word_vec, word_mat)
    sim, indices = torch.topk(cos_mat,k+1)
    
    
    word_list = []
    for i in indices:
        if i != word_id:
            word_list.append(id2word[i])

    return pd.Series(word_list, np.array(sim[1:].detach()))

# %%
similar_words(mat_df2, '한국')
# Out:
# 0.766142    대한민국
# 0.728997      국내
# 0.698197      협회
# 0.691419      문화
# 0.678622      세계
# 0.676159      대표
# 0.671660     연구소
# 0.660957      국제
# 0.660433      중국
# 0.657550     연구원
# dtype: object

# %%
similar_words(mat_df2, '대통령')
# Out:
# 0.745762    이명박
# 0.742417    노무현
# 0.718058     정부
# 0.717507    박근혜
# 0.715104    김대중
# 0.701533    부통령
# 0.699795    문재인
# 0.698852     총리
# 0.696139    박정희
# 0.684194     선거
# dtype: object

# %%
similar_words(mat_df2, '서울')
# Out:
# 0.768897      특별시
# 0.752911       부산
# 0.713688       대구
# 0.708653    서울특별시
# 0.693020     대한민국
# 0.676501      대학교
# 0.674008       인천
# 0.665950       한양
# 0.654892       광주
# 0.654595      서울시
# dtype: object

# %%
similar_words(mat_df2, '컴퓨터')
# Out:
# 0.831022       응용
# 0.779801      시스템
# 0.768034     하드웨어
# 0.765600    소프트웨어
# 0.729581       PC
# 0.715987       가상
# 0.707996       기기
# 0.704437      그래픽
# 0.703101       기술
# 0.693981       장치
# dtype: object

# %%
similar_words(mat_df2, '공부')
# Out:
# 0.798458    가르쳤
# 0.793902    가르치
# 0.775261     배웠
# 0.722765     유학
# 0.699725     수학
# 0.699584     수업
# 0.691074     입학
# 0.671551     학문
# 0.662154    열심히
# 0.654888     진학
# dtype: object

# %%
def analogy(mat_df, word1, word2, word3,k=10):
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    
    word_id1 = word2id[word1]
    word_id2 = word2id[word2]
    word_id3 = word2id[word3]
    word_vec1 = torch.tensor(mat_df.loc[word1].values).view(1,-1)
    word_vec2 = torch.tensor(mat_df.loc[word2].values).view(1,-1)
    word_vec3 = torch.tensor(mat_df.loc[word3].values).view(1,-1)
    word_mat = torch.tensor(mat_df.values)
    
    cos_mat = cos(word_vec1-word_vec2+word_vec3, word_mat)
    sim, indices = torch.topk(cos_mat,k+3)
    
    word_list = []
    sim_list = []
    for i, index in enumerate(indices):
        if index not in (word_id1, word_id2, word_id3):
            word_list.append(id2word[index])
            sim_list.append(sim[i].item())
        if len(word_list)==k:break
    return pd.Series(word_list, sim_list)

# %%
analogy(mat_df2,'한국','서울','파리')
# Out:
# 0.687797    프랑스
# 0.601987     유럽
# 0.564660     인도
# 0.551131     세계
# 0.539856    러시아
# 0.533136    벨기에
# 0.528558    스위스
# 0.527541     영국
# 0.520582    그리고
# 0.519037    캐나다
# dtype: object

# %%
analogy(mat_df2,'왕','남자','여자')
# Out:
# 0.663666     王
# 0.642142    공주
# 0.642031    군주
# 0.632903    태조
# 0.628493    왕자
# 0.623341    대왕
# 0.619844     세
# 0.610831    아들
# 0.610641    나라
# 0.588807    국왕
# dtype: object

# %% [markdown]
# 뭐 이 정도면 나쁘지 않은듯?
