# %% [markdown]
# # 4.1 NPLM (Neural Probability Language Model)
#
# NPLM을 파이토치로 구현해보자!
#
# <img src = '../images/NPLM.png' width=500>

# %%
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt

dev = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %%
N = 4 # n-gram의 갯수
VEC_DIM = 100 # 임베딩 차원
HIDDEN_DIM = 100 # 은닉 차원

# %% [markdown]
# ### 먼저 데이터를 벡터화부터 시작하자.

# %%
txt_path = '../data/tokenized/korquad_mecab.txt'
corpus = [sent.strip().split() for sent in open(txt_path, 'r', encoding='utf-8').readlines()]

# %%
for word in corpus[1]:
    print(word)
# Out:
# 바그너
# 는
# 괴테
# 의
# 파우스트
# 를
# 읽
# 고
# 무엇
# 을
# 쓰
# 고자
# 했
# 는가
# ?
# 교향곡

# %%
def sent_to_ngram(n, sent):
    ngrams = []
    
    for i in range(len(sent)-n+1):
        ngram = []
        for j in range(n):
            ngram.append(sent[i+j])
        ngrams.append(ngram)
            
    return ngrams

# %%
sent_to_ngram(N, corpus[1])
# Out:
# [['바그너', '는', '괴테', '의', '파우스트'],
#  ['는', '괴테', '의', '파우스트', '를'],
#  ['괴테', '의', '파우스트', '를', '읽'],
#  ['의', '파우스트', '를', '읽', '고'],
#  ['파우스트', '를', '읽', '고', '무엇'],
#  ['를', '읽', '고', '무엇', '을'],
#  ['읽', '고', '무엇', '을', '쓰'],
#  ['고', '무엇', '을', '쓰', '고자'],
#  ['무엇', '을', '쓰', '고자', '했'],
#  ['을', '쓰', '고자', '했', '는가'],
#  ['쓰', '고자', '했', '는가', '?'],
#  ['고자', '했', '는가', '?', '교향곡']]

# %% [markdown]
# 단어장과 인덱스를 만들자

# %%
vocab = set()
for i in range(len(corpus)):
    vocab.update(corpus[i])
    
len(vocab)
# Out:
# 83593

# %%
word_to_id = dict()
for word in vocab:
    word_to_id[word]=len(word_to_id)    

len(word_to_id)
# Out:
# 83593

# %%
word_to_id
# Out:
# {'주파수대': 0,
#  '종카': 1,
#  '제갈성렬': 2,
#  '보다': 3,
#  '품격': 4,
#  '분사': 5,
#  '전무후무': 6,
#  '투박': 7,
#  '답한': 8,
#  '섬겨': 9,
#  '及': 10,
#  '그라': 11,
#  '숲길': 12,
#  '김지운': 13,
#  '김상현': 14,
#  '기초자': 15,
#  '총칭': 16,
#  'Ellen': 17,
#  '걸쳐야': 18,
#  '고독': 19,
#  '조범현': 20,
#  '필립스': 21,
#  '텔레비전': 22,
#  '대구부': 23,
#  '칙': 24,
#  'fringillae': 25,
#  '틀어졌': 26,
#  '내사': 27,
#  '센텀': 28,
#  '巴': 29,
#  '우방': 30,
#  '상도동': 31,
#  'Bihac': 32,
#  '가미교': 33,
#  '별기': 34,
#  '금권': 35,
#  'DVS': 36,
#  'Called': 37,
#  'Darboven': 38,
#  '사블리코바': 39,
#  '장날': 40,
#  'dorsalis': 41,
#  '말': 42,
#  '안도감': 43,
#  '식스': 44,
#  '헁': 45,
#  '소하천': 46,
#  '불만': 47,
#  '장훈': 48,
#  'LM': 49,
#  'Fame': 50,
#  '노트북': 51,
#  '중견': 52,
#  '기탁금': 53,
#  '난리': 54,
#  '퍼펙트': 55,
#  'Ivan': 56,
#  'bizarre': 57,
#  '니': 58,
#  '둥양': 59,
#  '앞발': 60,
#  '늘어진': 61,
#  '포변': 62,
#  '선급': 63,
#  '왕복': 64,
#  '정갑': 65,
#  '산집': 66,
#  '염직': 67,
#  '겐키치': 68,
#  '인코딩': 69,
#  '차바퀴': 70,
#  '화성학': 71,
#  '빈센트': 72,
#  'OFFICIAL': 73,
#  '뒤덮여': 74,
#  '한숨짓': 75,
#  'Hell': 76,
#  '유키히코': 77,
#  '忍冬': 78,
#  '공격전': 79,
#  '근저': 80,
#  '아라이': 81,
#  '기숙사': 82,
#  'SPD': 83,
#  '에드문즈': 84,
#  'Emilio': 85,
#  '쥬': 86,
#  '약전': 87,
#  '건제': 88,
#  '마할': 89,
#  'Raspberry': 90,
#  '양계': 91,
#  'Nordschleife': 92,
#  '부자연': 93,
#  'naso': 94,
#  '곁들였': 95,
#  '퐁': 96,
#  '교황청': 97,
#  '경향': 98,
#  '종정부': 99,
#  'NOLZA': 100,
#  '신여': 101,
#  'concentric': 102,
#  '벤투리': 103,
#  '정칙': 104,
#  '단근질': 105,
#  '병': 106,
#  '바일': 107,
#  '목': 108,
#  '초고온': 109,
#  '가쓰요시': 110,
#  '최고조': 111,
#  '경시': 112,
#  '세워질': 113,
#  '아울리': 114,
#  '각조': 115,
#  '브로니': 116,
#  '경매': 117,
#  '신흥공업국': 118,
#  '변개': 119,
#  '返還': 120,
#  '쳐들어갈': 121,
#  '진해구': 122,
#  '입석': 123,
#  '인기투표': 124,
#  'Neal': 125,
#  '탄수': 126,
#  '바디스': 127,
#  '엇갈려서': 128,
#  '만화방': 129,
#  '코너킥': 130,
#  'Legion': 131,
#  '무거워': 132,
#  '공매': 133,
#  '심수경': 134,
#  '대륙성': 135,
#  '탈진': 136,
#  '읍소': 137,
#  '율법': 138,
#  '새터민': 139,
#  'Credo': 140,
#  '마사회': 141,
#  '치매': 142,
#  '외교가': 143,
#  '리브르': 144,
#  '지매': 145,
#  '끼우': 146,
#  '비튼': 147,
#  '최고': 148,
#  '주기성': 149,
#  '쳐서': 150,
#  'con': 151,
#  'Brien': 152,
#  '헤이즈': 153,
#  '맥길': 154,
#  '로코퀸': 155,
#  '백귀야행': 156,
#  '관측자': 157,
#  '중량': 158,
#  '페데리코': 159,
#  '아미나': 160,
#  '븀': 161,
#  'Milenko': 162,
#  '교육': 163,
#  '産業': 164,
#  '프런트로': 165,
#  '소아': 166,
#  '컴리': 167,
#  '청소년기': 168,
#  '나팔수': 169,
#  '독립신문': 170,
#  '도니스': 171,
#  '프레시': 172,
#  '유희': 173,
#  '찬탁': 174,
#  '송구': 175,
#  'Ms': 176,
#  '흥산': 177,
#  '기략': 178,
#  '경전차': 179,
#  'sunt': 180,
#  'Hobbins': 181,
#  '여가': 182,
#  '체크인': 183,
#  '지제교': 184,
#  '폴커': 185,
#  '방풍벽': 186,
#  '여학교': 187,
#  '나라종금': 188,
#  '略': 189,
#  '맞물': 190,
#  '군벌': 191,
#  'AMA': 192,
#  '벌일': 193,
#  '정동수': 194,
#  'UP': 195,
#  '격조': 196,
#  '스켈톤': 197,
#  '티몬스': 198,
#  '그리움': 199,
#  '베르고미': 200,
#  '져버려': 201,
#  '친조모': 202,
#  '전북': 203,
#  '將軍': 204,
#  '잭맨': 205,
#  '인형극': 206,
#  'Napoleon': 207,
#  '웹진': 208,
#  '成宗': 209,
#  '신유': 210,
#  '서품식': 211,
#  '일링': 212,
#  '테하다': 213,
#  '죽음': 214,
#  '최우선': 215,
#  '때린': 216,
#  '번호표': 217,
#  'Labor': 218,
#  '거미': 219,
#  '가즈시게': 220,
#  '공평': 221,
#  '네스트': 222,
#  'Усомнившийся': 223,
#  '철선': 224,
#  '단발기': 225,
#  '고토쿠': 226,
#  '뜨거운': 227,
#  '보살계': 228,
#  'ˠ': 229,
#  '奉天': 230,
#  '표창원': 231,
#  '신지': 232,
#  '大寺': 233,
#  '반창고': 234,
#  '총액': 235,
#  '아서': 236,
#  '츨라르에서': 237,
#  '뉴런': 238,
#  '차두리': 239,
#  'Colours': 240,
#  '장제스': 241,
#  '아르기닌': 242,
#  '한성부': 243,
#  '맹장군': 244,
#  '식종': 245,
#  '꾀했': 246,
#  '둘러쌓': 247,
#  '레판토': 248,
#  '흉물': 249,
#  '돈다': 250,
#  '다임러': 251,
#  '사옹원': 252,
#  '윤색': 253,
#  '표상': 254,
#  'für': 255,
#  '나르도': 256,
#  '깔리': 257,
#  '쌓': 258,
#  '대연습': 259,
#  'HDI': 260,
#  '관용': 261,
#  '라마': 262,
#  '재수감': 263,
#  '블론드': 264,
#  '자라났': 265,
#  '산산조각': 266,
#  '스펙트럼선': 267,
#  '묠니르': 268,
#  'ANGEL': 269,
#  '중포병': 270,
#  '작사가': 271,
#  '김영란': 272,
#  '트라이베카': 273,
#  '발전사': 274,
#  '원기둥': 275,
#  '란데': 276,
#  'via': 277,
#  '얼음장': 278,
#  '원종': 279,
#  '상의원': 280,
#  '동법': 281,
#  'Zowie': 282,
#  '리미트리스': 283,
#  '개력': 284,
#  'conspiracy': 285,
#  '스터': 286,
#  '刺針': 287,
#  '불신자': 288,
#  '我所': 289,
#  '顔': 290,
#  '수준급': 291,
#  '조선대': 292,
#  '다칠': 293,
#  '시게미쓰': 294,
#  '시그네': 295,
#  '음': 296,
#  '법상종': 297,
#  'BCH': 298,
#  'ITPRO': 299,
#  '암꽃이삭': 300,
#  '남양주': 301,
#  '아침밥': 302,
#  '발라진': 303,
#  '기마': 304,
#  '부부': 305,
#  '효고현': 306,
#  'Shirazi': 307,
#  'part': 308,
#  '선거인단': 309,
#  'DINOS': 310,
#  '띄우': 311,
#  '환멸': 312,
#  'NADP': 313,
#  '호칭': 314,
#  'GOD': 315,
#  '가건물': 316,
#  'Eorpach': 317,
#  'Jūngwàh': 318,
#  'Legendary': 319,
#  '와': 320,
#  '크리오스': 321,
#  '알천': 322,
#  '김철': 323,
#  '시중금리': 324,
#  '선염': 325,
#  '인비저블': 326,
#  '현안': 327,
#  '강인': 328,
#  '누군가': 329,
#  '필동': 330,
#  '말벌': 331,
#  '라야': 332,
#  'Γανυμήδης': 333,
#  '중석기': 334,
#  '사버': 335,
#  '내성': 336,
#  '결계': 337,
#  'aluco': 338,
#  '침범': 339,
#  '진행할': 340,
#  '고속화': 341,
#  '박사유': 342,
#  '수리정온': 343,
#  '휴가지': 344,
#  '영풍': 345,
#  'proposition': 346,
#  '해골': 347,
#  '유혜영': 348,
#  '고성': 349,
#  'Genre': 350,
#  '물탱크': 351,
#  '공민권법': 352,
#  'Nola': 353,
#  '당제': 354,
#  '발렌시아가': 355,
#  '시게루': 356,
#  'alumina': 357,
#  'intermodulation': 358,
#  '대주교': 359,
#  '인쇄판': 360,
#  '산노': 361,
#  '시엠': 362,
#  '패트릭': 363,
#  '칭명': 364,
#  '제재소': 365,
#  '발신기': 366,
#  '데려간다': 367,
#  '돋을새김': 368,
#  '가리': 369,
#  'JB': 370,
#  '서기관': 371,
#  '장작': 372,
#  '트레이너': 373,
#  '대세': 374,
#  '혼재': 375,
#  '실소유주': 376,
#  '잊혀진': 377,
#  '리브리': 378,
#  'Verse': 379,
#  '알아채': 380,
#  '혼돈': 381,
#  '군기대신': 382,
#  '싸웁니까': 383,
#  '米': 384,
#  '결점': 385,
#  '론슨': 386,
#  '이아라': 387,
#  '점심때': 388,
#  '위난': 389,
#  'Lawn': 390,
#  '심포지엄': 391,
#  '마크린': 392,
#  'й': 393,
#  '도브': 394,
#  '시달릴': 395,
#  '커리지': 396,
#  '강원도': 397,
#  '전기공업': 398,
#  '양전백': 399,
#  '동락': 400,
#  '중간착취': 401,
#  '서민호': 402,
#  '쉴러': 403,
#  '국론': 404,
#  'Vaillons': 405,
#  '데블스': 406,
#  'wäre': 407,
#  '출국': 408,
#  '瞋': 409,
#  '아홉': 410,
#  '몬테카를로': 411,
#  '부풀려졌': 412,
#  'Rheydt': 413,
#  '알렉': 414,
#  '했으므로': 415,
#  '・': 416,
#  'Schwietzerhoff': 417,
#  'Back': 418,
#  '금강삼매경론': 419,
#  '로고스': 420,
#  '통해서': 421,
#  '마도': 422,
#  '신계': 423,
#  '하만': 424,
#  '九龍淵': 425,
#  'Pearls': 426,
#  '범법자': 427,
#  '사전': 428,
#  '교복': 429,
#  '헤레스': 430,
#  '조관우': 431,
#  '발정': 432,
#  '입종': 433,
#  '태수': 434,
#  '은하단': 435,
#  '둘러보': 436,
#  '액상': 437,
#  '임춘앵': 438,
#  '닭': 439,
#  'Segalanya': 440,
#  '원외': 441,
#  'とうほくちほうたいへいようおきじしん': 442,
#  '세레': 443,
#  '공영제': 444,
#  '입니까': 445,
#  'Pixel': 446,
#  '툴루이': 447,
#  '이보형': 448,
#  '모레아': 449,
#  'Ⅳ': 450,
#  'AFKN': 451,
#  '복된': 452,
#  '하이먼': 453,
#  '김봉환': 454,
#  '감미': 455,
#  '총가': 456,
#  'ENa': 457,
#  '기자': 458,
#  '니나': 459,
#  '씻겨': 460,
#  '에와': 461,
#  'cortex': 462,
#  '졌었': 463,
#  '꽝꽝': 464,
#  '야간열차': 465,
#  '淵': 466,
#  '스티스': 467,
#  '아몬': 468,
#  '섹터': 469,
#  '나무망치': 470,
#  '총좌': 471,
#  'NGC': 472,
#  '늦': 473,
#  '북마리아나': 474,
#  'French': 475,
#  '추오': 476,
#  '벨리즈': 477,
#  '인텔리': 478,
#  'Jessie': 479,
#  '흡': 480,
#  '백세': 481,
#  '챃청': 482,
#  '衛兵': 483,
#  '우유': 484,
#  '문지르': 485,
#  '말아톤': 486,
#  '스테프니': 487,
#  '허위문자': 488,
#  '이목': 489,
#  '고조': 490,
#  '퇴거': 491,
#  '빡빡': 492,
#  '홍세완': 493,
#  '봉준': 494,
#  '난이도': 495,
#  '당년': 496,
#  '낙동강': 497,
#  '사이퍼즈': 498,
#  '君': 499,
#  '토식': 500,
#  'Colby': 501,
#  'Liberation': 502,
#  '크기': 503,
#  'firebrand': 504,
#  '帝王': 505,
#  '모리세이': 506,
#  '성민': 507,
#  'wo': 508,
#  '알아보': 509,
#  '허위사실유포': 510,
#  '카위트': 511,
#  '그라이키아': 512,
#  '해발고도': 513,
#  '영화시': 514,
#  '비춰': 515,
#  '조타수': 516,
#  '각원': 517,
#  'track': 518,
#  '한길': 519,
#  '특례법': 520,
#  '마노스': 521,
#  '소유자': 522,
#  '영지': 523,
#  '그쳤으며': 524,
#  '명배우': 525,
#  '조반류': 526,
#  '검관': 527,
#  '브라초': 528,
#  '石井': 529,
#  '자격': 530,
#  '타오르': 531,
#  '밀리': 532,
#  'loaded': 533,
#  '徙': 534,
#  '소간': 535,
#  '命名': 536,
#  '환송연': 537,
#  'Cronbach': 538,
#  '소작인': 539,
#  '끌려도': 540,
#  '종현': 541,
#  'Bum': 542,
#  '劇團': 543,
#  '긴밀히': 544,
#  '값진': 545,
#  '웨스트포인트': 546,
#  '策': 547,
#  '위곡': 548,
#  '고럴': 549,
#  '플루오르화': 550,
#  '양절': 551,
#  '랭보': 552,
#  '차창': 553,
#  '출전': 554,
#  '겁먹': 555,
#  'Barbarossa': 556,
#  '수산화': 557,
#  'Dizzee': 558,
#  '아르튀르': 559,
#  'betray': 560,
#  '떠드': 561,
#  '전생서': 562,
#  '이즘': 563,
#  '궁술사': 564,
#  '坪': 565,
#  '라나': 566,
#  '고원준': 567,
#  '우트': 568,
#  '마테이선': 569,
#  '윤춘근': 570,
#  '天子': 571,
#  '당진': 572,
#  'lngénu': 573,
#  '루초': 574,
#  '제영': 575,
#  '현정은': 576,
#  '메이저': 577,
#  '전투차': 578,
#  '루시타니아': 579,
#  '화이트': 580,
#  '치원': 581,
#  'Silver': 582,
#  '卜': 583,
#  '분절': 584,
#  'Yad': 585,
#  '다녀오': 586,
#  'RT': 587,
#  '외형': 588,
#  '펑톈': 589,
#  '묶': 590,
#  '민속학': 591,
#  '사무직': 592,
#  '이라': 593,
#  '枝': 594,
#  '형판': 595,
#  '고형욱': 596,
#  '유령': 597,
#  '더그': 598,
#  '분방': 599,
#  '아케르나르': 600,
#  '돌부리': 601,
#  '폼페오': 602,
#  'Iron': 603,
#  '연병장': 604,
#  '톻화인캔디는': 605,
#  '곡기': 606,
#  '이수광': 607,
#  'SMTown': 608,
#  '완정': 609,
#  '명하': 610,
#  '조칙': 611,
#  '폭설': 612,
#  '소래산': 613,
#  '外形': 614,
#  '신길': 615,
#  '성형외과': 616,
#  '아현': 617,
#  'Cephaloscyllium': 618,
#  'yelps': 619,
#  '쭈그러들': 620,
#  '마키노': 621,
#  '豫': 622,
#  '領': 623,
#  'Orientu': 624,
#  '맴돌': 625,
#  'CHILD': 626,
#  '이불': 627,
#  'Popjustice': 628,
#  '안토니우': 629,
#  'Sorel': 630,
#  '연락회': 631,
#  '친다며': 632,
#  '無邊': 633,
#  '전시공산주의': 634,
#  '지시문': 635,
#  '프레리': 636,
#  '선거자': 637,
#  '출혈': 638,
#  '성덕': 639,
#  '재정경제부': 640,
#  '중곡': 641,
#  '몽': 642,
#  '학관': 643,
#  '마이클잭슨': 644,
#  'lukwos': 645,
#  'Projects': 646,
#  'non': 647,
#  '쓸려가': 648,
#  '종가': 649,
#  '이놈': 650,
#  '사죄': 651,
#  'Prix': 652,
#  '지면': 653,
#  '봇': 654,
#  '獄中': 655,
#  '개관': 656,
#  '리야': 657,
#  '안인수': 658,
#  '부풀': 659,
#  '재역': 660,
#  '인책': 661,
#  '쑤셔': 662,
#  '두드린': 663,
#  '발식': 664,
#  '별제': 665,
#  '참브로타': 666,
#  'adversidades': 667,
#  '법과': 668,
#  '오펜바흐': 669,
#  'Revolver': 670,
#  '사이언스': 671,
#  '산란': 672,
#  '私田': 673,
#  '親親': 674,
#  '아디이아': 675,
#  'ex': 676,
#  'Clio': 677,
#  '과로사': 678,
#  '매슨': 679,
#  '세서': 680,
#  'tortuosa': 681,
#  '두샨': 682,
#  '야전군': 683,
#  '正平': 684,
#  '대립': 685,
#  '지표': 686,
#  '매표소': 687,
#  '쿠엔': 688,
#  '백종열': 689,
#  '지하철': 690,
#  '궈단': 691,
#  'Eiropas': 692,
#  '순이': 693,
#  '운사': 694,
#  '지정은제': 695,
#  '经': 696,
#  '진술': 697,
#  'E': 698,
#  '행렬': 699,
#  '코울': 700,
#  'IWW': 701,
#  '로리스': 702,
#  '사기죄': 703,
#  '왜행성': 704,
#  '知': 705,
#  '전사자': 706,
#  '萬人': 707,
#  '국재': 708,
#  '카츠라': 709,
#  '빗나간': 710,
#  '이감': 711,
#  '플': 712,
#  '연대학': 713,
#  '맞아들이': 714,
#  '업무': 715,
#  '羲': 716,
#  '잉커우': 717,
#  '플로르': 718,
#  'longipes': 719,
#  '날카롭': 720,
#  '감표': 721,
#  'Chaillet': 722,
#  '김종호': 723,
#  '우덕순': 724,
#  '수지': 725,
#  'KIA': 726,
#  'ancylostomae': 727,
#  '허공': 728,
#  '어퍼컷': 729,
#  '가수': 730,
#  '侯王': 731,
#  '수리남': 732,
#  '유물론': 733,
#  '헌혈자': 734,
#  'Ph': 735,
#  'Ordinary': 736,
#  '珪素': 737,
#  '에르나': 738,
#  '우르바노': 739,
#  '고슬링': 740,
#  '맡긴': 741,
#  '어물쩍': 742,
#  '禪': 743,
#  '인코스': 744,
#  '수산청': 745,
#  '武學': 746,
#  '융기부': 747,
#  'Bisamberg': 748,
#  '》)': 749,
#  '복사열': 750,
#  '田': 751,
#  '우생학': 752,
#  '접질리': 753,
#  '두근두근': 754,
#  '혜종': 755,
#  '봉래': 756,
#  '홍사익': 757,
#  '체의': 758,
#  '영하': 759,
#  '제산': 760,
#  '싱에': 761,
#  '특칙은': 762,
#  '으로부터': 763,
#  '원빈': 764,
#  '탄산': 765,
#  'Jazz': 766,
#  '`````-': 767,
#  '모셔': 768,
#  '피운': 769,
#  '가례도감의궤': 770,
#  '세영': 771,
#  '몰로': 772,
#  '인증': 773,
#  'USS': 774,
#  '알려서': 775,
#  '노토': 776,
#  '주웠': 777,
#  '빨간빛': 778,
#  '온다는': 779,
#  'Declaration': 780,
#  '완득이': 781,
#  'se': 782,
#  '벤쿠버': 783,
#  '열구': 784,
#  'girls': 785,
#  'Heretical': 786,
#  'Curtain': 787,
#  '요새': 788,
#  '은박지': 789,
#  '메릿': 790,
#  '주성철': 791,
#  '브래디': 792,
#  '비법': 793,
#  '천주교인': 794,
#  '덴표호지': 795,
#  '관동군': 796,
#  '컨템퍼러리': 797,
#  '기다렸': 798,
#  '가재': 799,
#  '운디네': 800,
#  '천궁': 801,
#  'Hiller': 802,
#  '기쿠치': 803,
#  '먹이': 804,
#  '采': 805,
#  '북조': 806,
#  '길동무': 807,
#  '겨웠': 808,
#  '볼턴': 809,
#  '카파': 810,
#  '박양': 811,
#  '로르': 812,
#  '좌의정': 813,
#  '특수교육': 814,
#  'Fasti': 815,
#  '덩이': 816,
#  '름': 817,
#  'Tragedy': 818,
#  '플랜더스': 819,
#  '레슬러': 820,
#  '창간': 821,
#  '>·': 822,
#  '갈라진다': 823,
#  'Anniversary': 824,
#  '카브리니': 825,
#  '친러파': 826,
#  '살인마': 827,
#  '크레인스': 828,
#  '쥬스': 829,
#  '저장물': 830,
#  '독고': 831,
#  '정우': 832,
#  '되살아난다': 833,
#  '쇼핑': 834,
#  '怪獸': 835,
#  '휘터': 836,
#  '국비': 837,
#  'Marching': 838,
#  '설도': 839,
#  '바꾼다': 840,
#  'transfer': 841,
#  '유니': 842,
#  '하워스': 843,
#  '노란': 844,
#  '난입': 845,
#  '집성촌': 846,
#  '리프먼': 847,
#  '동석': 848,
#  '행위': 849,
#  '휘젓': 850,
#  '우승자': 851,
#  '재회': 852,
#  '구상체': 853,
#  '리에': 854,
#  '낵스는': 855,
#  '영채': 856,
#  '분류법': 857,
#  '하마사카': 858,
#  'Quatuor': 859,
#  '게이머즈': 860,
#  '정례화': 861,
#  '귀금속': 862,
#  'Dias': 863,
#  'skrjabini': 864,
#  'Buckle': 865,
#  'Silverplate': 866,
#  '국영': 867,
#  '안산시': 868,
#  '바뤼흐': 869,
#  '디아비': 870,
#  '광고판': 871,
#  'Kristen': 872,
#  '에페이로스': 873,
#  '검투사': 874,
#  '얀젠': 875,
#  'SEP': 876,
#  '결성': 877,
#  '전쟁': 878,
#  'Saga': 879,
#  '끼친다': 880,
#  '주치': 881,
#  '다레스': 882,
#  '이케다': 883,
#  '김석범': 884,
#  '임호테프': 885,
#  '이라크': 886,
#  '회군': 887,
#  '대괄호': 888,
#  '압': 889,
#  '箭': 890,
#  '알아낸': 891,
#  '거듭날': 892,
#  '러키': 893,
#  '빌레': 894,
#  '카레라': 895,
#  '^–': 896,
#  '벌어진다': 897,
#  '시내버스': 898,
#  '김병헌': 899,
#  '명명법': 900,
#  '축자영감설': 901,
#  '건드릴': 902,
#  'CHO': 903,
#  '슬라이': 904,
#  '호민': 905,
#  '나호': 906,
#  '정보과': 907,
#  '이교도': 908,
#  '정희식': 909,
#  'Molina': 910,
#  '수양버들': 911,
#  '숙친': 912,
#  '환속': 913,
#  '파항': 914,
#  '오해영': 915,
#  '뀌': 916,
#  '안경옥': 917,
#  '판도': 918,
#  'P': 919,
#  '바비': 920,
#  '베네토어': 921,
#  '이니': 922,
#  'Häusser': 923,
#  '조혼': 924,
#  '슬럼가': 925,
#  '종인': 926,
#  'alteración': 927,
#  '지훈련': 928,
#  '매지': 929,
#  '암거래': 930,
#  '절대다수': 931,
#  '신심': 932,
#  '국권': 933,
#  '종사품': 934,
#  '센다이': 935,
#  '손잡': 936,
#  '군포': 937,
#  '성영': 938,
#  '무덕': 939,
#  '이상돈': 940,
#  '○': 941,
#  '카간': 942,
#  'Paolo': 943,
#  '물밑': 944,
#  '妃': 945,
#  '갈릴리': 946,
#  '폭파대': 947,
#  '신필': 948,
#  '갈라서': 949,
#  '표현법': 950,
#  'DHTML': 951,
#  '조성희': 952,
#  '최고상': 953,
#  '證得': 954,
#  '허스키': 955,
#  '대니': 956,
#  '올해': 957,
#  '情熱': 958,
#  '후작': 959,
#  'Tell': 960,
#  '대동지지': 961,
#  'Blenheim': 962,
#  '公然': 963,
#  '넵': 964,
#  '구세주': 965,
#  '황도': 966,
#  '클리퍼': 967,
#  '고두': 968,
#  '양식장': 969,
#  'nigga': 970,
#  '페르디난트': 971,
#  'Philpotts': 972,
#  '一二': 973,
#  '진경수': 974,
#  '온종일': 975,
#  '방명록': 976,
#  '쓰러뜨려': 977,
#  '事象': 978,
#  '자코브': 979,
#  '지진학': 980,
#  '엑소시스트': 981,
#  '차이점': 982,
#  '민자당': 983,
#  '끎과': 984,
#  '실리콘': 985,
#  '감속재': 986,
#  'concept': 987,
#  '-》(': 988,
#  '모였': 989,
#  '阿斯達': 990,
#  '부다페스트': 991,
#  'Strange': 992,
#  '취업': 993,
#  '끼': 994,
#  '머치': 995,
#  '목포일보': 996,
#  '도제': 997,
#  'i': 998,
#  'porch': 999,
#  ...}

# %%
id_to_word = []
for word in word_to_id.keys():
    id_to_word.append(word)

# %% [markdown]
# 훈련 데이터를 만들자

# %%
train_data = []
for i in range(len(corpus)):
    train_data += sent_to_ngram(N, corpus[i])

# %%
train_data
# Out:
# [['1', '8', '3', '9', '년'],
#  ['8', '3', '9', '년', '바그너'],
#  ['3', '9', '년', '바그너', '는'],
#  ['9', '년', '바그너', '는', '괴테'],
#  ['년', '바그너', '는', '괴테', '의'],
#  ['바그너', '는', '괴테', '의', '파우스트'],
#  ['는', '괴테', '의', '파우스트', '을'],
#  ['괴테', '의', '파우스트', '을', '처음'],
#  ['의', '파우스트', '을', '처음', '읽'],
#  ['파우스트', '을', '처음', '읽', '고'],
#  ['을', '처음', '읽', '고', '그'],
#  ['처음', '읽', '고', '그', '내용'],
#  ['읽', '고', '그', '내용', '에'],
#  ['고', '그', '내용', '에', '마음'],
#  ['그', '내용', '에', '마음', '이'],
#  ['내용', '에', '마음', '이', '끌려'],
#  ['에', '마음', '이', '끌려', '이'],
#  ['마음', '이', '끌려', '이', '를'],
#  ['이', '끌려', '이', '를', '소재'],
#  ['끌려', '이', '를', '소재', '로'],
#  ['이', '를', '소재', '로', '해서'],
#  ['를', '소재', '로', '해서', '하나'],
#  ['소재', '로', '해서', '하나', '의'],
#  ['로', '해서', '하나', '의', '교향곡'],
#  ['해서', '하나', '의', '교향곡', '을'],
#  ['하나', '의', '교향곡', '을', '쓰'],
#  ['의', '교향곡', '을', '쓰', '려는'],
#  ['교향곡', '을', '쓰', '려는', '뜻'],
#  ['을', '쓰', '려는', '뜻', '을'],
#  ['쓰', '려는', '뜻', '을', '갖'],
#  ['려는', '뜻', '을', '갖', '는다'],
#  ['뜻', '을', '갖', '는다', '.'],
#  ['을', '갖', '는다', '.', '이'],
#  ['갖', '는다', '.', '이', '시기'],
#  ['는다', '.', '이', '시기', '바그너'],
#  ['.', '이', '시기', '바그너', '는'],
#  ['이', '시기', '바그너', '는', '1'],
#  ['시기', '바그너', '는', '1', '8'],
#  ['바그너', '는', '1', '8', '3'],
#  ['는', '1', '8', '3', '8'],
#  ['1', '8', '3', '8', '년'],
#  ['8', '3', '8', '년', '에'],
#  ['3', '8', '년', '에', '빛'],
#  ['8', '년', '에', '빛', '독촉'],
#  ['년', '에', '빛', '독촉', '으로'],
#  ['에', '빛', '독촉', '으로', '산전수전'],
#  ['빛', '독촉', '으로', '산전수전', '을'],
#  ['독촉', '으로', '산전수전', '을', '다'],
#  ['으로', '산전수전', '을', '다', '걲은'],
#  ['산전수전', '을', '다', '걲은', '상황'],
#  ['을', '다', '걲은', '상황', '이'],
#  ['다', '걲은', '상황', '이', '라'],
#  ['걲은', '상황', '이', '라', '좌절'],
#  ['상황', '이', '라', '좌절', '과'],
#  ['이', '라', '좌절', '과', '실망'],
#  ['라', '좌절', '과', '실망', '에'],
#  ['좌절', '과', '실망', '에', '가득'],
#  ['과', '실망', '에', '가득', '했으며'],
#  ['실망', '에', '가득', '했으며', '메피스토펠레스'],
#  ['에', '가득', '했으며', '메피스토펠레스', '를'],
#  ['가득', '했으며', '메피스토펠레스', '를', '만나'],
#  ['했으며', '메피스토펠레스', '를', '만나', '는'],
#  ['메피스토펠레스', '를', '만나', '는', '파우스트'],
#  ['를', '만나', '는', '파우스트', '의'],
#  ['만나', '는', '파우스트', '의', '심경'],
#  ['는', '파우스트', '의', '심경', '에'],
#  ['파우스트', '의', '심경', '에', '공감'],
#  ['의', '심경', '에', '공감', '했'],
#  ['심경', '에', '공감', '했', '다고'],
#  ['에', '공감', '했', '다고', '한다'],
#  ['공감', '했', '다고', '한다', '.'],
#  ['했', '다고', '한다', '.', '또한'],
#  ['다고', '한다', '.', '또한', '파리'],
#  ['한다', '.', '또한', '파리', '에서'],
#  ['.', '또한', '파리', '에서', '아'],
#  ['또한', '파리', '에서', '아', '브네'],
#  ['파리', '에서', '아', '브네', '크'],
#  ['에서', '아', '브네', '크', '의'],
#  ['아', '브네', '크', '의', '지휘'],
#  ['브네', '크', '의', '지휘', '로'],
#  ['크', '의', '지휘', '로', '파리'],
#  ['의', '지휘', '로', '파리', '음악원'],
#  ['지휘', '로', '파리', '음악원', '관현악단'],
#  ['로', '파리', '음악원', '관현악단', '이'],
#  ['파리', '음악원', '관현악단', '이', '연주'],
#  ['음악원', '관현악단', '이', '연주', '하'],
#  ['관현악단', '이', '연주', '하', '는'],
#  ['이', '연주', '하', '는', '베토벤'],
#  ['연주', '하', '는', '베토벤', '의'],
#  ['하', '는', '베토벤', '의', '교향곡'],
#  ['는', '베토벤', '의', '교향곡', '9'],
#  ['베토벤', '의', '교향곡', '9', '번'],
#  ['의', '교향곡', '9', '번', '을'],
#  ['교향곡', '9', '번', '을', '듣'],
#  ['9', '번', '을', '듣', '고'],
#  ['번', '을', '듣', '고', '깊'],
#  ['을', '듣', '고', '깊', '은'],
#  ['듣', '고', '깊', '은', '감명'],
#  ['고', '깊', '은', '감명', '을'],
#  ['깊', '은', '감명', '을', '받'],
#  ['은', '감명', '을', '받', '았'],
#  ['감명', '을', '받', '았', '는데'],
#  ['을', '받', '았', '는데', ','],
#  ['받', '았', '는데', ',', '이것'],
#  ['았', '는데', ',', '이것', '이'],
#  ['는데', ',', '이것', '이', '이듬해'],
#  [',', '이것', '이', '이듬해', '1'],
#  ['이것', '이', '이듬해', '1', '월'],
#  ['이', '이듬해', '1', '월', '에'],
#  ['이듬해', '1', '월', '에', '파우스트'],
#  ['1', '월', '에', '파우스트', '의'],
#  ['월', '에', '파우스트', '의', '서곡'],
#  ['에', '파우스트', '의', '서곡', '으로'],
#  ['파우스트', '의', '서곡', '으로', '쓰여진'],
#  ['의', '서곡', '으로', '쓰여진', '이'],
#  ['서곡', '으로', '쓰여진', '이', '작품'],
#  ['으로', '쓰여진', '이', '작품', '에'],
#  ['쓰여진', '이', '작품', '에', '조금'],
#  ['이', '작품', '에', '조금', '이'],
#  ['작품', '에', '조금', '이', '라도'],
#  ['에', '조금', '이', '라도', '영향'],
#  ['조금', '이', '라도', '영향', '을'],
#  ['이', '라도', '영향', '을', '끼쳤'],
#  ['라도', '영향', '을', '끼쳤', '으리라는'],
#  ['영향', '을', '끼쳤', '으리라는', '것'],
#  ['을', '끼쳤', '으리라는', '것', '은'],
#  ['끼쳤', '으리라는', '것', '은', '의심'],
#  ['으리라는', '것', '은', '의심', '할'],
#  ['것', '은', '의심', '할', '여지'],
#  ['은', '의심', '할', '여지', '가'],
#  ['의심', '할', '여지', '가', '없'],
#  ['할', '여지', '가', '없', '다'],
#  ['여지', '가', '없', '다', '.'],
#  ['가', '없', '다', '.', '여기'],
#  ['없', '다', '.', '여기', '의'],
#  ['다', '.', '여기', '의', '라단조'],
#  ['.', '여기', '의', '라단조', '조성'],
#  ['여기', '의', '라단조', '조성', '의'],
#  ['의', '라단조', '조성', '의', '경우'],
#  ['라단조', '조성', '의', '경우', '에'],
#  ['조성', '의', '경우', '에', '도'],
#  ['의', '경우', '에', '도', '그'],
#  ['경우', '에', '도', '그', '의'],
#  ['에', '도', '그', '의', '전기'],
#  ['도', '그', '의', '전기', '에'],
#  ['그', '의', '전기', '에', '적혀'],
#  ['의', '전기', '에', '적혀', '있'],
#  ['전기', '에', '적혀', '있', '는'],
#  ['에', '적혀', '있', '는', '것'],
#  ['적혀', '있', '는', '것', '처럼'],
#  ['있', '는', '것', '처럼', '단순'],
#  ['는', '것', '처럼', '단순', '한'],
#  ['것', '처럼', '단순', '한', '정신'],
#  ['처럼', '단순', '한', '정신', '적'],
#  ['단순', '한', '정신', '적', '피로'],
#  ['한', '정신', '적', '피로', '나'],
#  ['정신', '적', '피로', '나', '실의'],
#  ['적', '피로', '나', '실의', '가'],
#  ['피로', '나', '실의', '가', '반영'],
#  ['나', '실의', '가', '반영', '된'],
#  ['실의', '가', '반영', '된', '것'],
#  ['가', '반영', '된', '것', '이'],
#  ['반영', '된', '것', '이', '아니'],
#  ['된', '것', '이', '아니', '라'],
#  ['것', '이', '아니', '라', '베토벤'],
#  ['이', '아니', '라', '베토벤', '의'],
#  ['아니', '라', '베토벤', '의', '합창'],
#  ['라', '베토벤', '의', '합창', '교향곡'],
#  ['베토벤', '의', '합창', '교향곡', '조성'],
#  ['의', '합창', '교향곡', '조성', '의'],
#  ['합창', '교향곡', '조성', '의', '영향'],
#  ['교향곡', '조성', '의', '영향', '을'],
#  ['조성', '의', '영향', '을', '받'],
#  ['의', '영향', '을', '받', '은'],
#  ['영향', '을', '받', '은', '것'],
#  ['을', '받', '은', '것', '을'],
#  ['받', '은', '것', '을', '볼'],
#  ['은', '것', '을', '볼', '수'],
#  ['것', '을', '볼', '수', '있'],
#  ['을', '볼', '수', '있', '다'],
#  ['볼', '수', '있', '다', '.'],
#  ['수', '있', '다', '.', '그렇게'],
#  ['있', '다', '.', '그렇게', '교향곡'],
#  ['다', '.', '그렇게', '교향곡', '작곡'],
#  ['.', '그렇게', '교향곡', '작곡', '을'],
#  ['그렇게', '교향곡', '작곡', '을', '1'],
#  ['교향곡', '작곡', '을', '1', '8'],
#  ['작곡', '을', '1', '8', '3'],
#  ['을', '1', '8', '3', '9'],
#  ['1', '8', '3', '9', '년'],
#  ['8', '3', '9', '년', '부터'],
#  ['3', '9', '년', '부터', '4'],
#  ['9', '년', '부터', '4', '0'],
#  ['년', '부터', '4', '0', '년'],
#  ['부터', '4', '0', '년', '에'],
#  ['4', '0', '년', '에', '걸쳐'],
#  ['0', '년', '에', '걸쳐', '파리'],
#  ['년', '에', '걸쳐', '파리', '에서'],
#  ['에', '걸쳐', '파리', '에서', '착수'],
#  ['걸쳐', '파리', '에서', '착수', '했으나'],
#  ['파리', '에서', '착수', '했으나', '1'],
#  ['에서', '착수', '했으나', '1', '악장'],
#  ['착수', '했으나', '1', '악장', '을'],
#  ['했으나', '1', '악장', '을', '쓴'],
#  ['1', '악장', '을', '쓴', '뒤'],
#  ['악장', '을', '쓴', '뒤', '에'],
#  ['을', '쓴', '뒤', '에', '중단'],
#  ['쓴', '뒤', '에', '중단', '했'],
#  ['뒤', '에', '중단', '했', '다'],
#  ['에', '중단', '했', '다', '.'],
#  ['중단', '했', '다', '.', '또한'],
#  ['했', '다', '.', '또한', '작품'],
#  ['다', '.', '또한', '작품', '의'],
#  ['.', '또한', '작품', '의', '완성'],
#  ['또한', '작품', '의', '완성', '과'],
#  ['작품', '의', '완성', '과', '동시'],
#  ['의', '완성', '과', '동시', '에'],
#  ['완성', '과', '동시', '에', '그'],
#  ['과', '동시', '에', '그', '는'],
#  ['동시', '에', '그', '는', '이'],
#  ['에', '그', '는', '이', '서곡'],
#  ['그', '는', '이', '서곡', '('],
#  ['는', '이', '서곡', '(', '1'],
#  ['이', '서곡', '(', '1', '악장'],
#  ['서곡', '(', '1', '악장', ')'],
#  ['(', '1', '악장', ')', '을'],
#  ['1', '악장', ')', '을', '파리'],
#  ['악장', ')', '을', '파리', '음악원'],
#  [')', '을', '파리', '음악원', '의'],
#  ['을', '파리', '음악원', '의', '연주회'],
#  ['파리', '음악원', '의', '연주회', '에서'],
#  ['음악원', '의', '연주회', '에서', '연주'],
#  ['의', '연주회', '에서', '연주', '할'],
#  ['연주회', '에서', '연주', '할', '파트'],
#  ['에서', '연주', '할', '파트', '보'],
#  ['연주', '할', '파트', '보', '까지'],
#  ['할', '파트', '보', '까지', '준비'],
#  ['파트', '보', '까지', '준비', '하'],
#  ['보', '까지', '준비', '하', '였으나'],
#  ['까지', '준비', '하', '였으나', ','],
#  ['준비', '하', '였으나', ',', '실제로'],
#  ['하', '였으나', ',', '실제로', '는'],
#  ['였으나', ',', '실제로', '는', '이루'],
#  [',', '실제로', '는', '이루', '어'],
#  ['실제로', '는', '이루', '어', '지지'],
#  ['는', '이루', '어', '지지', '는'],
#  ['이루', '어', '지지', '는', '않'],
#  ['어', '지지', '는', '않', '았'],
#  ['지지', '는', '않', '았', '다'],
#  ['는', '않', '았', '다', '.'],
#  ['않', '았', '다', '.', '결국'],
#  ['았', '다', '.', '결국', '초연'],
#  ['다', '.', '결국', '초연', '은'],
#  ['.', '결국', '초연', '은', '4'],
#  ['결국', '초연', '은', '4', '년'],
#  ['초연', '은', '4', '년', '반'],
#  ['은', '4', '년', '반', '이'],
#  ['4', '년', '반', '이', '지난'],
#  ['년', '반', '이', '지난', '후'],
#  ['반', '이', '지난', '후', '에'],
#  ['이', '지난', '후', '에', '드레스덴'],
#  ['지난', '후', '에', '드레스덴', '에서'],
#  ['후', '에', '드레스덴', '에서', '연주'],
#  ['에', '드레스덴', '에서', '연주', '되'],
#  ['드레스덴', '에서', '연주', '되', '었'],
#  ['에서', '연주', '되', '었', '고'],
#  ['연주', '되', '었', '고', '재연'],
#  ['되', '었', '고', '재연', '도'],
#  ['었', '고', '재연', '도', '이루'],
#  ['고', '재연', '도', '이루', '어'],
#  ['재연', '도', '이루', '어', '졌'],
#  ['도', '이루', '어', '졌', '지만'],
#  ['이루', '어', '졌', '지만', ','],
#  ['어', '졌', '지만', ',', '이후'],
#  ['졌', '지만', ',', '이후', '에'],
#  ['지만', ',', '이후', '에', '그대로'],
#  [',', '이후', '에', '그대로', '방치'],
#  ['이후', '에', '그대로', '방치', '되'],
#  ['에', '그대로', '방치', '되', '고'],
#  ['그대로', '방치', '되', '고', '말'],
#  ['방치', '되', '고', '말', '았'],
#  ['되', '고', '말', '았', '다'],
#  ['고', '말', '았', '다', '.'],
#  ['말', '았', '다', '.', '그'],
#  ['았', '다', '.', '그', '사이'],
#  ['다', '.', '그', '사이', '에'],
#  ['.', '그', '사이', '에', '그'],
#  ['그', '사이', '에', '그', '는'],
#  ['사이', '에', '그', '는', '리엔치'],
#  ['에', '그', '는', '리엔치', '와'],
#  ['그', '는', '리엔치', '와', '방황'],
#  ['는', '리엔치', '와', '방황', '하'],
#  ['리엔치', '와', '방황', '하', '는'],
#  ['와', '방황', '하', '는', '네덜란드인'],
#  ['방황', '하', '는', '네덜란드인', '을'],
#  ['하', '는', '네덜란드인', '을', '완성'],
#  ['는', '네덜란드인', '을', '완성', '하'],
#  ['네덜란드인', '을', '완성', '하', '고'],
#  ['을', '완성', '하', '고', '탄호이저'],
#  ['완성', '하', '고', '탄호이저', '에'],
#  ['하', '고', '탄호이저', '에', '도'],
#  ['고', '탄호이저', '에', '도', '착수'],
#  ['탄호이저', '에', '도', '착수', '하'],
#  ['에', '도', '착수', '하', '는'],
#  ['도', '착수', '하', '는', '등'],
#  ['착수', '하', '는', '등', '분주'],
#  ['하', '는', '등', '분주', '한'],
#  ['는', '등', '분주', '한', '시간'],
#  ['등', '분주', '한', '시간', '을'],
#  ['분주', '한', '시간', '을', '보냈'],
#  ['한', '시간', '을', '보냈', '는데'],
#  ['시간', '을', '보냈', '는데', ','],
#  ['을', '보냈', '는데', ',', '그런'],
#  ['보냈', '는데', ',', '그런', '바쁜'],
#  ['는데', ',', '그런', '바쁜', '생활'],
#  [',', '그런', '바쁜', '생활', '이'],
#  ['그런', '바쁜', '생활', '이', '이'],
#  ['바쁜', '생활', '이', '이', '곡'],
#  ['생활', '이', '이', '곡', '을'],
#  ['이', '이', '곡', '을', '잊'],
#  ['이', '곡', '을', '잊', '게'],
#  ['곡', '을', '잊', '게', '한'],
#  ['을', '잊', '게', '한', '것'],
#  ['잊', '게', '한', '것', '이'],
#  ['게', '한', '것', '이', '아닌가'],
#  ['한', '것', '이', '아닌가', '하'],
#  ['것', '이', '아닌가', '하', '는'],
#  ['이', '아닌가', '하', '는', '의견'],
#  ['아닌가', '하', '는', '의견', '도'],
#  ['하', '는', '의견', '도', '있'],
#  ['는', '의견', '도', '있', '다'],
#  ['의견', '도', '있', '다', '.'],
#  ['바그너', '는', '괴테', '의', '파우스트'],
#  ['는', '괴테', '의', '파우스트', '를'],
#  ['괴테', '의', '파우스트', '를', '읽'],
#  ['의', '파우스트', '를', '읽', '고'],
#  ['파우스트', '를', '읽', '고', '무엇'],
#  ['를', '읽', '고', '무엇', '을'],
#  ['읽', '고', '무엇', '을', '쓰'],
#  ['고', '무엇', '을', '쓰', '고자'],
#  ['무엇', '을', '쓰', '고자', '했'],
#  ['을', '쓰', '고자', '했', '는가'],
#  ['쓰', '고자', '했', '는가', '?'],
#  ['고자', '했', '는가', '?', '교향곡'],
#  ['바그너', '는', '교향곡', '작곡', '을'],
#  ['는', '교향곡', '작곡', '을', '어디'],
#  ['교향곡', '작곡', '을', '어디', '까지'],
#  ['작곡', '을', '어디', '까지', '쓴'],
#  ['을', '어디', '까지', '쓴', '뒤'],
#  ['어디', '까지', '쓴', '뒤', '에'],
#  ['까지', '쓴', '뒤', '에', '중단'],
#  ['쓴', '뒤', '에', '중단', '했'],
#  ['뒤', '에', '중단', '했', '는가'],
#  ['에', '중단', '했', '는가', '?'],
#  ['중단', '했', '는가', '?', '1'],
#  ['했', '는가', '?', '1', '악장'],
#  ['바그너', '가', '파우스트', '서곡', '을'],
#  ['가', '파우스트', '서곡', '을', '쓸'],
#  ['파우스트', '서곡', '을', '쓸', '때'],
#  ['서곡', '을', '쓸', '때', '어떤'],
#  ['을', '쓸', '때', '어떤', '곡'],
#  ['쓸', '때', '어떤', '곡', '의'],
#  ['때', '어떤', '곡', '의', '영향'],
#  ['어떤', '곡', '의', '영향', '을'],
#  ['곡', '의', '영향', '을', '받'],
#  ['의', '영향', '을', '받', '았'],
#  ['영향', '을', '받', '았', '는가'],
#  ['을', '받', '았', '는가', '?'],
#  ['받', '았', '는가', '?', '베토벤'],
#  ['았', '는가', '?', '베토벤', '의'],
#  ['는가', '?', '베토벤', '의', '교향곡'],
#  ['?', '베토벤', '의', '교향곡', '9'],
#  ['베토벤', '의', '교향곡', '9', '번'],
#  ['1', '8', '3', '9', '년'],
#  ['8', '3', '9', '년', '바그너'],
#  ['3', '9', '년', '바그너', '가'],
#  ['9', '년', '바그너', '가', '교향곡'],
#  ['년', '바그너', '가', '교향곡', '의'],
#  ['바그너', '가', '교향곡', '의', '소재'],
#  ['가', '교향곡', '의', '소재', '로'],
#  ['교향곡', '의', '소재', '로', '쓰'],
#  ['의', '소재', '로', '쓰', '려고'],
#  ['소재', '로', '쓰', '려고', '했'],
#  ['로', '쓰', '려고', '했', '던'],
#  ['쓰', '려고', '했', '던', '책'],
#  ['려고', '했', '던', '책', '은'],
#  ['했', '던', '책', '은', '?'],
#  ['던', '책', '은', '?', '파우스트'],
#  ['파우스트', '서곡', '의', '라단조', '조성'],
#  ['서곡', '의', '라단조', '조성', '이'],
#  ['의', '라단조', '조성', '이', '영향'],
#  ['라단조', '조성', '이', '영향', '을'],
#  ['조성', '이', '영향', '을', '받'],
#  ['이', '영향', '을', '받', '은'],
#  ['영향', '을', '받', '은', '베토벤'],
#  ['을', '받', '은', '베토벤', '의'],
#  ['받', '은', '베토벤', '의', '곡'],
#  ['은', '베토벤', '의', '곡', '은'],
#  ['베토벤', '의', '곡', '은', '?'],
#  ['의', '곡', '은', '?', '합창'],
#  ['곡', '은', '?', '합창', '교향곡'],
#  ['바그너', '가', '파우스트', '를', '처음'],
#  ['가', '파우스트', '를', '처음', '으로'],
#  ['파우스트', '를', '처음', '으로', '읽'],
#  ['를', '처음', '으로', '읽', '은'],
#  ['처음', '으로', '읽', '은', '년'],
#  ['으로', '읽', '은', '년', '도'],
#  ['읽', '은', '년', '도', '는'],
#  ['은', '년', '도', '는', '?'],
#  ['년', '도', '는', '?', '1'],
#  ['도', '는', '?', '1', '8'],
#  ['는', '?', '1', '8', '3'],
#  ['?', '1', '8', '3', '9'],
#  ['바그너', '가', '처음', '교향곡', '작곡'],
#  ['가', '처음', '교향곡', '작곡', '을'],
#  ['처음', '교향곡', '작곡', '을', '한'],
#  ['교향곡', '작곡', '을', '한', '장소'],
#  ['작곡', '을', '한', '장소', '는'],
#  ['을', '한', '장소', '는', '?'],
#  ['한', '장소', '는', '?', '파리'],
#  ['바그너', '의', '1', '악장', '의'],
#  ['의', '1', '악장', '의', '초연'],
#  ['1', '악장', '의', '초연', '은'],
#  ['악장', '의', '초연', '은', '어디'],
#  ['의', '초연', '은', '어디', '서'],
#  ['초연', '은', '어디', '서', '연주'],
#  ['은', '어디', '서', '연주', '되'],
#  ['어디', '서', '연주', '되', '었'],
#  ['서', '연주', '되', '었', '는가'],
#  ['연주', '되', '었', '는가', '?'],
#  ['되', '었', '는가', '?', '드레스'],
#  ['었', '는가', '?', '드레스', '덴'],
#  ['한편', '1', '8', '4', '0'],
#  ['1', '8', '4', '0', '년'],
#  ['8', '4', '0', '년', '부터'],
#  ['4', '0', '년', '부터', '바그너'],
#  ['0', '년', '부터', '바그너', '와'],
#  ['년', '부터', '바그너', '와', '알'],
#  ['부터', '바그너', '와', '알', '고'],
#  ['바그너', '와', '알', '고', '지내'],
#  ['와', '알', '고', '지내', '던'],
#  ['알', '고', '지내', '던', '리스트'],
#  ['고', '지내', '던', '리스트', '가'],
#  ['지내', '던', '리스트', '가', '잊혀져'],
#  ['던', '리스트', '가', '잊혀져', '있'],
#  ['리스트', '가', '잊혀져', '있', '던'],
#  ['가', '잊혀져', '있', '던', '1'],
#  ['잊혀져', '있', '던', '1', '악장'],
#  ['있', '던', '1', '악장', '을'],
#  ['던', '1', '악장', '을', '부활'],
#  ['1', '악장', '을', '부활', '시켜'],
#  ['악장', '을', '부활', '시켜', '1'],
#  ['을', '부활', '시켜', '1', '8'],
#  ['부활', '시켜', '1', '8', '5'],
#  ['시켜', '1', '8', '5', '2'],
#  ['1', '8', '5', '2', '년'],
#  ['8', '5', '2', '년', '에'],
#  ['5', '2', '년', '에', '바이마르'],
#  ['2', '년', '에', '바이마르', '에서'],
#  ['년', '에', '바이마르', '에서', '연주'],
#  ['에', '바이마르', '에서', '연주', '했'],
#  ['바이마르', '에서', '연주', '했', '다'],
#  ['에서', '연주', '했', '다', '.'],
#  ['연주', '했', '다', '.', '이것'],
#  ['했', '다', '.', '이것', '을'],
#  ['다', '.', '이것', '을', '계기'],
#  ['.', '이것', '을', '계기', '로'],
#  ['이것', '을', '계기', '로', '바그너'],
#  ['을', '계기', '로', '바그너', '도'],
#  ['계기', '로', '바그너', '도', '이'],
#  ['로', '바그너', '도', '이', '작품'],
#  ['바그너', '도', '이', '작품', '에'],
#  ['도', '이', '작품', '에', '다시'],
#  ['이', '작품', '에', '다시', '관심'],
#  ['작품', '에', '다시', '관심', '을'],
#  ['에', '다시', '관심', '을', '갖'],
#  ['다시', '관심', '을', '갖', '게'],
#  ['관심', '을', '갖', '게', '되'],
#  ['을', '갖', '게', '되', '었'],
#  ['갖', '게', '되', '었', '고'],
#  ['게', '되', '었', '고', ','],
#  ['되', '었', '고', ',', '그'],
#  ['었', '고', ',', '그', '해'],
#  ['고', ',', '그', '해', '9'],
#  [',', '그', '해', '9', '월'],
#  ['그', '해', '9', '월', '에'],
#  ['해', '9', '월', '에', '는'],
#  ['9', '월', '에', '는', '총보'],
#  ['월', '에', '는', '총보', '의'],
#  ['에', '는', '총보', '의', '반환'],
#  ['는', '총보', '의', '반환', '을'],
#  ['총보', '의', '반환', '을', '요구'],
#  ['의', '반환', '을', '요구', '하'],
#  ['반환', '을', '요구', '하', '여'],
#  ['을', '요구', '하', '여', '이'],
#  ['요구', '하', '여', '이', '를'],
#  ['하', '여', '이', '를', '서곡'],
#  ['여', '이', '를', '서곡', '으로'],
#  ['이', '를', '서곡', '으로', '간추린'],
#  ['를', '서곡', '으로', '간추린', '다음'],
#  ['서곡', '으로', '간추린', '다음', '수정'],
#  ['으로', '간추린', '다음', '수정', '을'],
#  ['간추린', '다음', '수정', '을', '했'],
#  ['다음', '수정', '을', '했', '고'],
#  ['수정', '을', '했', '고', '브라이트'],
#  ['을', '했', '고', '브라이트', '코프'],
#  ['했', '고', '브라이트', '코프', '흐'],
#  ['고', '브라이트', '코프', '흐', '&'],
#  ['브라이트', '코프', '흐', '&', '헤르'],
#  ['코프', '흐', '&', '헤르', '텔'],
#  ['흐', '&', '헤르', '텔', '출판사'],
#  ['&', '헤르', '텔', '출판사', '에서'],
#  ['헤르', '텔', '출판사', '에서', '출판'],
#  ['텔', '출판사', '에서', '출판', '할'],
#  ['출판사', '에서', '출판', '할', '개정판'],
#  ['에서', '출판', '할', '개정판', '도'],
#  ['출판', '할', '개정판', '도', '준비'],
#  ['할', '개정판', '도', '준비', '했'],
#  ['개정판', '도', '준비', '했', '다'],
#  ['도', '준비', '했', '다', '.'],
#  ['준비', '했', '다', '.', '1'],
#  ['했', '다', '.', '1', '8'],
#  ['다', '.', '1', '8', '5'],
#  ['.', '1', '8', '5', '3'],
#  ['1', '8', '5', '3', '년'],
#  ['8', '5', '3', '년', '5'],
#  ['5', '3', '년', '5', '월'],
#  ['3', '년', '5', '월', '에'],
#  ['년', '5', '월', '에', '는'],
#  ['5', '월', '에', '는', '리스트'],
#  ['월', '에', '는', '리스트', '가'],
#  ['에', '는', '리스트', '가', '이'],
#  ['는', '리스트', '가', '이', '작품'],
#  ['리스트', '가', '이', '작품', '이'],
#  ['가', '이', '작품', '이', '수정'],
#  ['이', '작품', '이', '수정', '되'],
#  ['작품', '이', '수정', '되', '었'],
#  ['이', '수정', '되', '었', '다는'],
#  ['수정', '되', '었', '다는', '것'],
#  ['되', '었', '다는', '것', '을'],
#  ['었', '다는', '것', '을', '인정'],
#  ['다는', '것', '을', '인정', '했'],
#  ['것', '을', '인정', '했', '지만'],
#  ['을', '인정', '했', '지만', ','],
#  ['인정', '했', '지만', ',', '끝내'],
#  ['했', '지만', ',', '끝내', '바그너'],
#  ['지만', ',', '끝내', '바그너', '의'],
#  [',', '끝내', '바그너', '의', '출판'],
#  ['끝내', '바그너', '의', '출판', '계획'],
#  ['바그너', '의', '출판', '계획', '은'],
#  ['의', '출판', '계획', '은', '무산'],
#  ['출판', '계획', '은', '무산', '되'],
#  ['계획', '은', '무산', '되', '고'],
#  ['은', '무산', '되', '고', '말'],
#  ['무산', '되', '고', '말', '았'],
#  ['되', '고', '말', '았', '다'],
#  ['고', '말', '았', '다', '.'],
#  ['말', '았', '다', '.', '이후'],
#  ['았', '다', '.', '이후', '1'],
#  ['다', '.', '이후', '1', '8'],
#  ['.', '이후', '1', '8', '5'],
#  ['이후', '1', '8', '5', '5'],
#  ['1', '8', '5', '5', '년'],
#  ['8', '5', '5', '년', '에'],
#  ['5', '5', '년', '에', '리스트'],
#  ['5', '년', '에', '리스트', '가'],
#  ['년', '에', '리스트', '가', '자신'],
#  ['에', '리스트', '가', '자신', '의'],
#  ['리스트', '가', '자신', '의', '작품'],
#  ['가', '자신', '의', '작품', '파우스트'],
#  ['자신', '의', '작품', '파우스트', '교향곡'],
#  ['의', '작품', '파우스트', '교향곡', '을'],
#  ['작품', '파우스트', '교향곡', '을', '거의'],
#  ['파우스트', '교향곡', '을', '거의', '완성'],
#  ['교향곡', '을', '거의', '완성', '하'],
#  ['을', '거의', '완성', '하', '여'],
#  ['거의', '완성', '하', '여', '그'],
#  ['완성', '하', '여', '그', '사실'],
#  ['하', '여', '그', '사실', '을'],
#  ['여', '그', '사실', '을', '바그너'],
#  ['그', '사실', '을', '바그너', '에게'],
#  ['사실', '을', '바그너', '에게', '알렸'],
#  ['을', '바그너', '에게', '알렸', '고'],
#  ['바그너', '에게', '알렸', '고', ','],
#  ['에게', '알렸', '고', ',', '바그너'],
#  ['알렸', '고', ',', '바그너', '는'],
#  ['고', ',', '바그너', '는', '다시'],
#  [',', '바그너', '는', '다시', '개정'],
#  ['바그너', '는', '다시', '개정', '된'],
#  ['는', '다시', '개정', '된', '총보'],
#  ['다시', '개정', '된', '총보', '를'],
#  ['개정', '된', '총보', '를', '리스트'],
#  ['된', '총보', '를', '리스트', '에게'],
#  ['총보', '를', '리스트', '에게', '보내'],
#  ['를', '리스트', '에게', '보내', '고'],
#  ['리스트', '에게', '보내', '고', '브라이트'],
#  ['에게', '보내', '고', '브라이트', '코프'],
#  ['보내', '고', '브라이트', '코프', '흐'],
#  ['고', '브라이트', '코프', '흐', '&'],
#  ['브라이트', '코프', '흐', '&', '헤르'],
#  ['코프', '흐', '&', '헤르', '텔'],
#  ['흐', '&', '헤르', '텔', '출판사'],
#  ['&', '헤르', '텔', '출판사', '에'],
#  ['헤르', '텔', '출판사', '에', '는'],
#  ['텔', '출판사', '에', '는', '2'],
#  ['출판사', '에', '는', '2', '0'],
#  ['에', '는', '2', '0', '루이'],
#  ['는', '2', '0', '루이', '의'],
#  ['2', '0', '루이', '의', '금'],
#  ['0', '루이', '의', '금', '을'],
#  ['루이', '의', '금', '을', '받'],
#  ['의', '금', '을', '받', '고'],
#  ['금', '을', '받', '고', '팔'],
#  ['을', '받', '고', '팔', '았'],
#  ['받', '고', '팔', '았', '다'],
#  ['고', '팔', '았', '다', '.'],
#  ['팔', '았', '다', '.', '또한'],
#  ['았', '다', '.', '또한', '그'],
#  ['다', '.', '또한', '그', '의'],
#  ['.', '또한', '그', '의', '작품'],
#  ['또한', '그', '의', '작품', '을'],
#  ['그', '의', '작품', '을', '“'],
#  ['의', '작품', '을', '“', '하나하나'],
#  ['작품', '을', '“', '하나하나', '의'],
#  ['을', '“', '하나하나', '의', '음표'],
#  ['“', '하나하나', '의', '음표', '가'],
#  ['하나하나', '의', '음표', '가', '시인'],
#  ['의', '음표', '가', '시인', '의'],
#  ['음표', '가', '시인', '의', '피'],
#  ['가', '시인', '의', '피', '로'],
#  ['시인', '의', '피', '로', '쓰여졌'],
#  ['의', '피', '로', '쓰여졌', '다'],
#  ['피', '로', '쓰여졌', '다', '”'],
#  ['로', '쓰여졌', '다', '”', '며'],
#  ['쓰여졌', '다', '”', '며', '극찬'],
#  ['다', '”', '며', '극찬', '했'],
#  ['”', '며', '극찬', '했', '던'],
#  ['며', '극찬', '했', '던', '한스'],
#  ['극찬', '했', '던', '한스', '폰'],
#  ['했', '던', '한스', '폰', '뷜로'],
#  ['던', '한스', '폰', '뷜로', '가'],
#  ['한스', '폰', '뷜로', '가', '그것'],
#  ['폰', '뷜로', '가', '그것', '을'],
#  ['뷜로', '가', '그것', '을', '피아노'],
#  ['가', '그것', '을', '피아노', '독주'],
#  ['그것', '을', '피아노', '독주', '용'],
#  ['을', '피아노', '독주', '용', '으로'],
#  ['피아노', '독주', '용', '으로', '편곡'],
#  ['독주', '용', '으로', '편곡', '했'],
#  ['용', '으로', '편곡', '했', '는데'],
#  ['으로', '편곡', '했', '는데', ','],
#  ['편곡', '했', '는데', ',', '리스트'],
#  ['했', '는데', ',', '리스트', '는'],
#  ['는데', ',', '리스트', '는', '그것'],
#  [',', '리스트', '는', '그것', '을'],
#  ['리스트', '는', '그것', '을', '약간'],
#  ['는', '그것', '을', '약간', '변형'],
#  ['그것', '을', '약간', '변형', '되'],
#  ['을', '약간', '변형', '되', '었'],
#  ['약간', '변형', '되', '었', '을'],
#  ['변형', '되', '었', '을', '뿐'],
#  ['되', '었', '을', '뿐', '이'],
#  ['었', '을', '뿐', '이', '라고'],
#  ['을', '뿐', '이', '라고', '지적'],
#  ['뿐', '이', '라고', '지적', '했'],
#  ['이', '라고', '지적', '했', '다'],
#  ['라고', '지적', '했', '다', '.'],
#  ['지적', '했', '다', '.', '이'],
#  ['했', '다', '.', '이', '서곡'],
#  ['다', '.', '이', '서곡', '의'],
#  ['.', '이', '서곡', '의', '총보'],
#  ['이', '서곡', '의', '총보', '첫머리'],
#  ['서곡', '의', '총보', '첫머리', '에'],
#  ['의', '총보', '첫머리', '에', '는'],
#  ['총보', '첫머리', '에', '는', '파우스트'],
#  ['첫머리', '에', '는', '파우스트', '1'],
#  ['에', '는', '파우스트', '1', '부'],
#  ['는', '파우스트', '1', '부', '의'],
#  ['파우스트', '1', '부', '의', '내용'],
#  ['1', '부', '의', '내용', '중'],
#  ['부', '의', '내용', '중', '한'],
#  ['의', '내용', '중', '한', '구절'],
#  ['내용', '중', '한', '구절', '을'],
#  ['중', '한', '구절', '을', '인용'],
#  ['한', '구절', '을', '인용', '하'],
#  ['구절', '을', '인용', '하', '고'],
#  ['을', '인용', '하', '고', '있'],
#  ['인용', '하', '고', '있', '다'],
#  ['하', '고', '있', '다', '.'],
#  ['바그너', '의', '작품', '을', '시인'],
#  ['의', '작품', '을', '시인', '의'],
#  ['작품', '을', '시인', '의', '피'],
#  ['을', '시인', '의', '피', '로'],
#  ['시인', '의', '피', '로', '쓰여졌'],
#  ['의', '피', '로', '쓰여졌', '다고'],
#  ['피', '로', '쓰여졌', '다고', '극찬'],
#  ['로', '쓰여졌', '다고', '극찬', '한'],
#  ['쓰여졌', '다고', '극찬', '한', '것'],
#  ['다고', '극찬', '한', '것', '은'],
#  ['극찬', '한', '것', '은', '누구'],
#  ['한', '것', '은', '누구', '인가'],
#  ['것', '은', '누구', '인가', '?'],
#  ['은', '누구', '인가', '?', '한스'],
#  ['누구', '인가', '?', '한스', '폰'],
#  ['인가', '?', '한스', '폰', '뷜로'],
#  ['잊혀져', '있', '는', '파우스트', '서곡'],
#  ['있', '는', '파우스트', '서곡', '1'],
#  ['는', '파우스트', '서곡', '1', '악장'],
#  ['파우스트', '서곡', '1', '악장', '을'],
#  ['서곡', '1', '악장', '을', '부활'],
#  ['1', '악장', '을', '부활', '시킨'],
#  ['악장', '을', '부활', '시킨', '것'],
#  ['을', '부활', '시킨', '것', '은'],
#  ['부활', '시킨', '것', '은', '누구'],
#  ['시킨', '것', '은', '누구', '인가'],
#  ['것', '은', '누구', '인가', '?'],
#  ['은', '누구', '인가', '?', '리스트'],
#  ['바그너', '는', '다시', '개정', '된'],
#  ['는', '다시', '개정', '된', '총보'],
#  ['다시', '개정', '된', '총보', '를'],
#  ['개정', '된', '총보', '를', '얼마'],
#  ['된', '총보', '를', '얼마', '를'],
#  ['총보', '를', '얼마', '를', '받'],
#  ['를', '얼마', '를', '받', '고'],
#  ['얼마', '를', '받', '고', '팔'],
#  ['를', '받', '고', '팔', '았'],
#  ['받', '고', '팔', '았', '는가'],
#  ['고', '팔', '았', '는가', '?'],
#  ['팔', '았', '는가', '?', '2'],
#  ['았', '는가', '?', '2', '0'],
#  ['는가', '?', '2', '0', '루이'],
#  ['?', '2', '0', '루이', '의'],
#  ['2', '0', '루이', '의', '금'],
#  ['파우스트', '교향곡', '을', '부활', '시킨'],
#  ['교향곡', '을', '부활', '시킨', '사람'],
#  ['을', '부활', '시킨', '사람', '은'],
#  ['부활', '시킨', '사람', '은', '?'],
#  ['시킨', '사람', '은', '?', '리스트'],
#  ['파우스트', '교향곡', '을', '피아노', '독주'],
#  ['교향곡', '을', '피아노', '독주', '용'],
#  ['을', '피아노', '독주', '용', '으로'],
#  ['피아노', '독주', '용', '으로', '편곡'],
#  ['독주', '용', '으로', '편곡', '한'],
#  ['용', '으로', '편곡', '한', '사람'],
#  ['으로', '편곡', '한', '사람', '은'],
#  ['편곡', '한', '사람', '은', '?'],
#  ['한', '사람', '은', '?', '한스'],
#  ['사람', '은', '?', '한스', '폰'],
#  ['은', '?', '한스', '폰', '뷜로'],
#  ['1', '악장', '을', '부활', '시켜'],
#  ['악장', '을', '부활', '시켜', '연주'],
#  ['을', '부활', '시켜', '연주', '한'],
#  ['부활', '시켜', '연주', '한', '사람'],
#  ['시켜', '연주', '한', '사람', '은'],
#  ['연주', '한', '사람', '은', '?'],
#  ['한', '사람', '은', '?', '리스트'],
#  ['파우스트', '교향곡', '에', '감탄', '하'],
#  ['교향곡', '에', '감탄', '하', '여'],
#  ['에', '감탄', '하', '여', '피아노'],
#  ['감탄', '하', '여', '피아노', '곡'],
#  ['하', '여', '피아노', '곡', '으로'],
#  ['여', '피아노', '곡', '으로', '편곡'],
#  ['피아노', '곡', '으로', '편곡', '한'],
#  ['곡', '으로', '편곡', '한', '사람'],
#  ['으로', '편곡', '한', '사람', '은'],
#  ['편곡', '한', '사람', '은', '?'],
#  ['한', '사람', '은', '?', '한스'],
#  ['사람', '은', '?', '한스', '폰'],
#  ['은', '?', '한스', '폰', '뷜로'],
#  ['리스트', '가', '바그너', '와', '알'],
#  ['가', '바그너', '와', '알', '게'],
#  ['바그너', '와', '알', '게', '된'],
#  ['와', '알', '게', '된', '연도'],
#  ['알', '게', '된', '연도', '는'],
#  ['게', '된', '연도', '는', '?'],
#  ['된', '연도', '는', '?', '1'],
#  ['연도', '는', '?', '1', '8'],
#  ['는', '?', '1', '8', '4'],
#  ['?', '1', '8', '4', '0'],
#  ['1', '8', '4', '0', '년'],
#  ['이', '작품', '은', '라단조', ','],
#  ['작품', '은', '라단조', ',', 'Sehr'],
#  ['은', '라단조', ',', 'Sehr', 'gehalten'],
#  ['라단조', ',', 'Sehr', 'gehalten', '('],
#  [',', 'Sehr', 'gehalten', '(', '아주'],
#  ['Sehr', 'gehalten', '(', '아주', '신중'],
#  ['gehalten', '(', '아주', '신중', '하'],
#  ['(', '아주', '신중', '하', '게'],
#  ['아주', '신중', '하', '게', ')'],
#  ['신중', '하', '게', ')', ','],
#  ['하', '게', ')', ',', '4'],
#  ['게', ')', ',', '4', '/'],
#  [')', ',', '4', '/', '4'],
#  [',', '4', '/', '4', '박자'],
#  ['4', '/', '4', '박자', '의'],
#  ['/', '4', '박자', '의', '부드러운'],
#  ['4', '박자', '의', '부드러운', '서주'],
#  ['박자', '의', '부드러운', '서주', '로'],
#  ['의', '부드러운', '서주', '로', '서주'],
#  ['부드러운', '서주', '로', '서주', '로'],
#  ['서주', '로', '서주', '로', '시작'],
#  ['로', '서주', '로', '시작', '되'],
#  ['서주', '로', '시작', '되', '는데'],
#  ['로', '시작', '되', '는데', ','],
#  ['시작', '되', '는데', ',', '여기'],
#  ['되', '는데', ',', '여기', '에'],
#  ['는데', ',', '여기', '에', '는'],
#  [',', '여기', '에', '는', '주요'],
#  ['여기', '에', '는', '주요', '주제'],
#  ['에', '는', '주요', '주제', ','],
#  ['는', '주요', '주제', ',', '동기'],
#  ['주요', '주제', ',', '동기', '의'],
#  ['주제', ',', '동기', '의', '대부분'],
#  [',', '동기', '의', '대부분', '이'],
#  ['동기', '의', '대부분', '이', '암시'],
#  ['의', '대부분', '이', '암시', ','],
#  ['대부분', '이', '암시', ',', '예고'],
#  ['이', '암시', ',', '예고', '되'],
#  ['암시', ',', '예고', '되', '어'],
#  [',', '예고', '되', '어', '있'],
#  ['예고', '되', '어', '있', '다'],
#  ['되', '어', '있', '다', '.'],
#  ['어', '있', '다', '.', '첫'],
#  ['있', '다', '.', '첫', '부분'],
#  ['다', '.', '첫', '부분', '의'],
#  ['.', '첫', '부분', '의', '저음'],
#  ['첫', '부분', '의', '저음', '주제'],
#  ['부분', '의', '저음', '주제', '는'],
#  ['의', '저음', '주제', '는', '주요'],
#  ['저음', '주제', '는', '주요', '주제'],
#  ['주제', '는', '주요', '주제', '('],
#  ['는', '주요', '주제', '(', '고뇌'],
#  ['주요', '주제', '(', '고뇌', '와'],
#  ['주제', '(', '고뇌', '와', '갈망'],
#  ['(', '고뇌', '와', '갈망', '동기'],
#  ['고뇌', '와', '갈망', '동기', ','],
#  ['와', '갈망', '동기', ',', '청춘'],
#  ['갈망', '동기', ',', '청춘', '의'],
#  ['동기', ',', '청춘', '의', '사랑'],
#  [',', '청춘', '의', '사랑', '동기'],
#  ['청춘', '의', '사랑', '동기', ')'],
#  ['의', '사랑', '동기', ')', '를'],
#  ['사랑', '동기', ')', '를', '암시'],
#  ['동기', ')', '를', '암시', '하'],
#  [')', '를', '암시', '하', '고'],
#  ['를', '암시', '하', '고', '있'],
#  ['암시', '하', '고', '있', '으며'],
#  ['하', '고', '있', '으며', ','],
#  ['고', '있', '으며', ',', '제'],
#  ['있', '으며', ',', '제', '1'],
#  ['으며', ',', '제', '1', '바이올린'],
#  [',', '제', '1', '바이올린', '으로'],
#  ['제', '1', '바이올린', '으로', '더욱'],
#  ['1', '바이올린', '으로', '더욱', '명확'],
#  ['바이올린', '으로', '더욱', '명확', '하'],
#  ['으로', '더욱', '명확', '하', '게'],
#  ['더욱', '명확', '하', '게', '나타난다'],
#  ['명확', '하', '게', '나타난다', '.'],
#  ['하', '게', '나타난다', '.', '또한'],
#  ['게', '나타난다', '.', '또한', '그것'],
#  ['나타난다', '.', '또한', '그것', '을'],
#  ['.', '또한', '그것', '을', '이어받'],
#  ['또한', '그것', '을', '이어받', '는'],
#  ['그것', '을', '이어받', '는', '동기'],
#  ['을', '이어받', '는', '동기', '도'],
#  ['이어받', '는', '동기', '도', '중요'],
#  ['는', '동기', '도', '중요', '한'],
#  ['동기', '도', '중요', '한', '역할'],
#  ['도', '중요', '한', '역할', '을'],
#  ['중요', '한', '역할', '을', '한다'],
#  ['한', '역할', '을', '한다', '.'],
#  ['역할', '을', '한다', '.', '여기'],
#  ['을', '한다', '.', '여기', '에'],
#  ['한다', '.', '여기', '에', '새로운'],
#  ['.', '여기', '에', '새로운', '소재'],
#  ['여기', '에', '새로운', '소재', '가'],
#  ['에', '새로운', '소재', '가', '더'],
#  ['새로운', '소재', '가', '더', '해진'],
#  ['소재', '가', '더', '해진', '뒤'],
#  ['가', '더', '해진', '뒤', '에'],
#  ['더', '해진', '뒤', '에', '새로운'],
#  ['해진', '뒤', '에', '새로운', '주제'],
#  ['뒤', '에', '새로운', '주제', '도'],
#  ['에', '새로운', '주제', '도', '연주'],
#  ['새로운', '주제', '도', '연주', '된다'],
#  ['주제', '도', '연주', '된다', '.'],
#  ['도', '연주', '된다', '.', '주요부'],
#  ['연주', '된다', '.', '주요부', '는'],
#  ['된다', '.', '주요부', '는', 'Sehr'],
#  ['.', '주요부', '는', 'Sehr', 'bewegt'],
#  ['주요부', '는', 'Sehr', 'bewegt', '('],
#  ['는', 'Sehr', 'bewegt', '(', '아주'],
#  ['Sehr', 'bewegt', '(', '아주', '격동'],
#  ['bewegt', '(', '아주', '격동', '적'],
#  ['(', '아주', '격동', '적', '으로'],
#  ['아주', '격동', '적', '으로', ')'],
#  ['격동', '적', '으로', ')', ','],
#  ['적', '으로', ')', ',', '2'],
#  ['으로', ')', ',', '2', '/'],
#  [')', ',', '2', '/', '2'],
#  [',', '2', '/', '2', '박자'],
#  ['2', '/', '2', '박자', '의'],
#  ['/', '2', '박자', '의', '자유'],
#  ['2', '박자', '의', '자유', '로운'],
#  ['박자', '의', '자유', '로운', '소나타'],
#  ['의', '자유', '로운', '소나타', '형식'],
#  ['자유', '로운', '소나타', '형식', '으로'],
#  ['로운', '소나타', '형식', '으로', '매우'],
#  ['소나타', '형식', '으로', '매우', '드라마틱'],
#  ['형식', '으로', '매우', '드라마틱', '한'],
#  ['으로', '매우', '드라마틱', '한', '구상'],
#  ['매우', '드라마틱', '한', '구상', '과'],
#  ['드라마틱', '한', '구상', '과', '유기'],
#  ['한', '구상', '과', '유기', '적'],
#  ['구상', '과', '유기', '적', '인'],
#  ['과', '유기', '적', '인', '구성'],
#  ['유기', '적', '인', '구성', '을'],
#  ['적', '인', '구성', '을', '하'],
#  ['인', '구성', '을', '하', '고'],
#  ['구성', '을', '하', '고', '있'],
#  ['을', '하', '고', '있', '다'],
#  ['하', '고', '있', '다', '.'],
#  ['고', '있', '다', '.', '여기'],
#  ['있', '다', '.', '여기', '에'],
#  ['다', '.', '여기', '에', '는'],
#  ['.', '여기', '에', '는', '지금'],
#  ['여기', '에', '는', '지금', '까지'],
#  ['에', '는', '지금', '까지', '의'],
#  ['는', '지금', '까지', '의', '주제'],
#  ['지금', '까지', '의', '주제', '나'],
#  ['까지', '의', '주제', '나', '소재'],
#  ['의', '주제', '나', '소재', '외'],
#  ['주제', '나', '소재', '외', '에'],
#  ['나', '소재', '외', '에', '도'],
#  ['소재', '외', '에', '도', '오보에'],
#  ['외', '에', '도', '오보에', '에'],
#  ['에', '도', '오보에', '에', '의한'],
#  ['도', '오보에', '에', '의한', '선율'],
#  ['오보에', '에', '의한', '선율', '과'],
#  ['에', '의한', '선율', '과', '제'],
#  ['의한', '선율', '과', '제', '2'],
#  ['선율', '과', '제', '2', '주제'],
#  ['과', '제', '2', '주제', '를'],
#  ['제', '2', '주제', '를', '떠올리'],
#  ['2', '주제', '를', '떠올리', '게'],
#  ['주제', '를', '떠올리', '게', '하'],
#  ['를', '떠올리', '게', '하', '는'],
#  ['떠올리', '게', '하', '는', '부차'],
#  ['게', '하', '는', '부차', '적'],
#  ['하', '는', '부차', '적', '인'],
#  ['는', '부차', '적', '인', '주제'],
#  ['부차', '적', '인', '주제', '가'],
#  ['적', '인', '주제', '가', '더'],
#  ['인', '주제', '가', '더', '해'],
#  ['주제', '가', '더', '해', '지'],
#  ['가', '더', '해', '지', '는데'],
#  ['더', '해', '지', '는데', ','],
#  ['해', '지', '는데', ',', '중간부'],
#  ['지', '는데', ',', '중간부', '에서'],
#  ['는데', ',', '중간부', '에서', '는'],
#  [',', '중간부', '에서', '는', '약보'],
#  ['중간부', '에서', '는', '약보', '3'],
#  ['에서', '는', '약보', '3', '이'],
#  ['는', '약보', '3', '이', '중심'],
#  ['약보', '3', '이', '중심', '이'],
#  ['3', '이', '중심', '이', '되'],
#  ['이', '중심', '이', '되', '고'],
#  ['중심', '이', '되', '고', '제'],
#  ['이', '되', '고', '제', '2'],
#  ['되', '고', '제', '2', '주제'],
#  ['고', '제', '2', '주제', '는'],
#  ['제', '2', '주제', '는', '축소'],
#  ['2', '주제', '는', '축소', '된'],
#  ['주제', '는', '축소', '된', '재현부'],
#  ['는', '축소', '된', '재현부', '에서'],
#  ['축소', '된', '재현부', '에서', 'D'],
#  ['된', '재현부', '에서', 'D', '장조'],
#  ['재현부', '에서', 'D', '장조', '로'],
#  ['에서', 'D', '장조', '로', '재현'],
#  ['D', '장조', '로', '재현', '된다'],
#  ['장조', '로', '재현', '된다', '.'],
#  ['로', '재현', '된다', '.', '마지막'],
#  ['재현', '된다', '.', '마지막', '에'],
#  ['된다', '.', '마지막', '에', '는'],
#  ['.', '마지막', '에', '는', '주요'],
#  ['마지막', '에', '는', '주요', '주제'],
#  ['에', '는', '주요', '주제', '를'],
#  ['는', '주요', '주제', '를', '회상'],
#  ['주요', '주제', '를', '회상', '하'],
#  ['주제', '를', '회상', '하', '면서'],
#  ['를', '회상', '하', '면서', '조용히'],
#  ['회상', '하', '면서', '조용히', '마친다'],
#  ['하', '면서', '조용히', '마친다', '.'],
#  ['서주', '에', '는', '무엇', '이'],
#  ['에', '는', '무엇', '이', '암시'],
#  ['는', '무엇', '이', '암시', '되'],
#  ['무엇', '이', '암시', '되', '어'],
#  ['이', '암시', '되', '어', '있'],
#  ['암시', '되', '어', '있', '는가'],
#  ['되', '어', '있', '는가', '?'],
#  ...]

# %%
len(train_data)
# Out:
# 3786082

# %%
def sent_to_vec(sent):
    vec = []
    for word in sent:
        vec.append(word_to_id[word])
    return vec

# %%
train_input = []
train_target = []
for data in train_data:
    train_input.append(sent_to_vec(data[:-1]))
    train_target.append(word_to_id[data[-1]])

# %%
len(train_input), len(train_target)
# Out:
# (3786082, 3786082)

# %%
train_input[0], train_target[0]
# Out:
# ([58352, 72677, 81809, 73522], 62224)

# %%
train_input_ts = torch.tensor(train_input)
train_target_ts = torch.tensor(train_target)

# %%
train = torch.utils.data.TensorDataset(train_input_ts, train_target_ts)

# %% [markdown]
# ### 모델을 만들어보자.
#
# 먼저 임베딩 벡터를 concatenate하는 방법에 대해 고민해보자.

# %%
emb = nn.Embedding(len(vocab) * (N-1), 5)

# %%
vec = emb(torch.tensor([train_input[0]]))
vec.shape
# Out:
# torch.Size([1, 3, 5])

# %%
torch.flatten(vec[0])
# Out:
# tensor([-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#          1.9236,  0.6581,  1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#        grad_fn=<AsStridedBackward>)

# %% [markdown]
# 따라서 입력을 하나씩 받을 경우는 그냥 flatten 쓰면 되지만, 배치로 받을 때는?

# %%
vec = emb(torch.tensor([train_input[0],train_input[1]]))
vec.shape
# Out:
# torch.Size([2, 3, 5])

# %%
vec
# Out:
# tensor([[[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704],
#          [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581],
#          [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994]],
#
#         [[ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581],
#          [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#          [-3.7253,  0.1673,  0.1281,  0.9819, -0.5825]]],
#        grad_fn=<EmbeddingBackward>)

# %%
vec_tu= torch.cat(tuple(vec),1)
vec_tu
# Out:
# tensor([[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#           1.9236,  0.6581],
#         [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581,  1.2249, -0.0710,  0.6953,
#          -0.9278, -0.0994],
#         [ 1.2249, -0.0710,  0.6953, -0.9278, -0.0994, -3.7253,  0.1673,  0.1281,
#           0.9819, -0.5825]], grad_fn=<CatBackward>)

# %% [markdown]
# torch.cat은 안될 것 같고, 찾아보니 flatten에 start_dim 옵션이 있음!

# %%
torch.flatten??

# %%
vec_tu= torch.flatten(vec,1)
vec_tu
# Out:
# tensor([[-0.9689,  0.5371,  2.0395,  1.3356, -0.6704,  0.0093, -1.1420,  1.7707,
#           1.9236,  0.6581,  1.2249, -0.0710,  0.6953, -0.9278, -0.0994],
#         [ 0.0093, -1.1420,  1.7707,  1.9236,  0.6581,  1.2249, -0.0710,  0.6953,
#          -0.9278, -0.0994, -3.7253,  0.1673,  0.1281,  0.9819, -0.5825]],
#        grad_fn=<AsStridedBackward>)

# %% [markdown]
# 원하는 결과를 얻음!

# %% [markdown]
# 근데 어차피 Linear layer가 필요하므로 원핫인코딩을 해야함...

# %%
batch = torch.tensor([train_input[0],train_input[1]])
batch.shape
# Out:
# torch.Size([2, 3])

# %% [markdown]
# 인덱스 벡터를 받으면 원핫인코딩 벡터를 반환하는 함수를 만들자

# %%
def vec_to_onehot(vec, oh_len):
    ohv = torch.zeros((batch.shape[0], batch.shape[1], oh_len))
    for i in range(vec.shape[0]):
        for j in range(vec.shape[1]):
            ohv[i][j][vec[i][j]] = 1
            
    return ohv

# %%
vec_to_onehot(batch, len(vocab)).shape
# Out:
# torch.Size([2, 3, 83593])

# %%
vec_oh = vec_to_onehot(batch, len(vocab))
vec_oh_tu= torch.flatten(vec_oh,1)

# %%
vec_oh_tu.shape
# Out:
# torch.Size([2, 250779])

# %%
lin = nn.Linear(len(vocab) * (N-1), 5)

# %%
lin(vec_oh_tu).shape
# Out:
# torch.Size([2, 5])

# %% [markdown]
# 아예 이 과정을 하나의 함수로 만들자.

# %%
def batch_to_input(batch, oh_len):
    ohv = torch.zeros((batch.shape[0], batch.shape[1], oh_len))
    for i in range(batch.shape[0]):
        for j in range(batch.shape[1]):
            ohv[i][j][batch[i][j]] = 1
            
    return torch.flatten(ohv,1)

# %%
batch_to_input(batch, len(vocab)).shape
# Out:
# torch.Size([2, 250779])

# %%
lin(batch_to_input(batch, len(vocab))).shape
# Out:
# torch.Size([2, 5])

# %% [markdown]
# 생각해보니 착각을 했다. 모델의 입력은 인덱스로 받아서 먼저 벡터 임베딩 후 Linear layer에 태우면 되니까, 그냥 임베딩 써도 됨

# %%
loss_f = nn.CrossEntropyLoss()

# %%
class NPLM(nn.Module):
    def __init__(self, n, vec_dim, hidden_dim):
        super(NPLM,self).__init__()
        self.emb = nn.Embedding(len(vocab), vec_dim)
        self.lin1 = nn.Linear(vec_dim * (n-1), hidden_dim)
        self.lin2 = nn.Linear(hidden_dim, len(vocab), bias=False)
        self.lin3 = nn.Linear(vec_dim * (n-1), len(vocab))
        
    def forward(self, x):
        # x : [BATCH_SIZE, N-1]
        # self.emb(x) : [BATCH_SIZE, N-1, VEC_DIM]
        x = self.emb(x).view(len(x),-1)
        y = torch.tanh(self.lin1(x))
        z = self.lin3(x) + self.lin2(y)
        return z

# %%
model = NPLM(N, VEC_DIM, HIDDEN_DIM)

# %%
target_batch = torch.tensor([train_target[0],train_target[1]])
target_batch
# Out:
# tensor([ 9126, 52737])

# %%
loss_f(output, target_batch)
# Out:
# tensor(11.2042, grad_fn=<NllLossBackward>)

# %% [markdown]
# 이 loss가 올바른 결과인지 확인해보자

# %%
F.softmax(output, 1) # output을 소프트맥스 변환
# Out:
# tensor([[1.4428e-05, 1.2722e-05, 2.4266e-05,  ..., 7.4909e-06, 8.3130e-06,
#          2.4767e-06],
#         [1.2748e-05, 1.0737e-05, 1.9825e-05,  ..., 8.3171e-06, 2.4149e-05,
#          3.8782e-06]], grad_fn=<SoftmaxBackward>)

# %%
F.softmax(output, 1)[0].sum() # 차원이 맞게 되었는지 확인
# Out:
# tensor(1.0000, grad_fn=<SumBackward0>)

# %%
torch.log(F.softmax(output, 1)[0][target_batch[0]]) # 출력의 target번째 좌표의 로그값
# Out:
# tensor(-11.4189, grad_fn=<LogBackward>)

# %%
torch.log(F.softmax(output, 1)[1][target_batch[1]])
# Out:
# tensor(-10.9895, grad_fn=<LogBackward>)

# %%
-(torch.log(F.softmax(output, 1)[0][target_batch[0]]) + torch.log(F.softmax(output, 1)[1][target_batch[1]]))/2
# Out:
# tensor(11.2042, grad_fn=<DivBackward0>)

# %% [markdown]
# 따라서 각각의 negative loss의 평균이다! 맞게 계산됨

# %% [markdown]
# ### 훈련 과정

# %%
BATCH_SIZE = 64
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
input_loader = torch.utils.data.DataLoader(train, batch_size=BATCH_SIZE)

# %%
x, y = next(iter(input_loader))

# %%
x.shape
# Out:
# torch.Size([64, 3])

# %%
y.shape
# Out:
# torch.Size([64])

# %% [markdown]
# 앞에서 임베딩도 잘못 했음...

# %%
emb = nn.Embedding(len(vocab), 10)

# %%
emb(x).shape
# Out:
# torch.Size([64, 3, 10])

# %%
out = emb(x)

# %%
out
# Out:
# tensor([[[-1.3797, -0.5497, -0.1819,  ...,  0.2293,  1.3921,  0.3705],
#          [-0.9443, -1.9360,  1.0009,  ...,  1.3524, -0.2080,  1.1619],
#          [ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067]],
#
#         [[-0.9443, -1.9360,  1.0009,  ...,  1.3524, -0.2080,  1.1619],
#          [ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067],
#          [ 0.6412, -0.5177,  1.2241,  ..., -0.3652, -0.4658,  1.4531]],
#
#         [[ 1.2290, -0.0642,  0.6032,  ..., -0.1276,  0.3939,  0.1067],
#          [ 0.6412, -0.5177,  1.2241,  ..., -0.3652, -0.4658,  1.4531],
#          [-0.6553, -0.0878,  0.1446,  ..., -0.9161,  1.3431,  0.0070]],
#
#         ...,
#
#         [[-0.6617,  0.6439, -0.0419,  ..., -0.3900,  0.9162, -0.4438],
#          [ 0.4282, -0.8271, -0.3454,  ..., -1.4361,  0.6106, -0.6443],
#          [ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068]],
#
#         [[ 0.4282, -0.8271, -0.3454,  ..., -1.4361,  0.6106, -0.6443],
#          [ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068],
#          [-0.9041,  0.3556, -0.0400,  ..., -0.0195, -1.1323, -1.1402]],
#
#         [[ 1.0708, -1.7279,  0.0475,  ...,  1.2346, -0.0447,  0.2068],
#          [-0.9041,  0.3556, -0.0400,  ..., -0.0195, -1.1323, -1.1402],
#          [ 0.7355,  0.0207, -1.0938,  ...,  0.7455, -1.3573, -1.6670]]],
#        grad_fn=<EmbeddingBackward>)

# %%
out.view(BATCH_SIZE,-1)
# Out:
# tensor([[-1.3797, -0.5497, -0.1819,  ..., -0.1276,  0.3939,  0.1067],
#         [-0.9443, -1.9360,  1.0009,  ..., -0.3652, -0.4658,  1.4531],
#         [ 1.2290, -0.0642,  0.6032,  ..., -0.9161,  1.3431,  0.0070],
#         ...,
#         [-0.6617,  0.6439, -0.0419,  ...,  1.2346, -0.0447,  0.2068],
#         [ 0.4282, -0.8271, -0.3454,  ..., -0.0195, -1.1323, -1.1402],
#         [ 1.0708, -1.7279,  0.0475,  ...,  0.7455, -1.3573, -1.6670]],
#        grad_fn=<ViewBackward>)

# %%
import time

# %%
# CPU time
start = time.time()

epoch = 1
loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % 50 == 0:        
            loss_list.append(loss_sum/50)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}s'.format(epo, i, loss_sum/50, time.time()-start))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 0.02, Elapsed time : 1
# Epoch : 0, Iteration : 50, Loss : 4.04, Elapsed time : 43
# Epoch : 0, Iteration : 100, Loss : 3.65, Elapsed time : 85
# Epoch : 0, Iteration : 150, Loss : 3.99, Elapsed time : 127
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-309-c5e025b229d9> in <module>
#      13         output = model(x)
#      14
# ---> 15         loss = loss_f(output, y)
#      16         loss.backward()
#      17         optimizer.step()
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\modules\loss.py in forward(self, input, target)
#     914     def forward(self, input, target):
#     915         return F.cross_entropy(input, target, weight=self.weight,
# --> 916                                ignore_index=self.ignore_index, reduction=self.reduction)
#     917
#     918
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction)
#    1993     if size_average is not None or reduce is not None:
#    1994         reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 1995     return nll_loss(log_softmax(input, 1), target, weight, None, ignore_index, None, reduction)
#    1996
#    1997
#
# G:\Anaconda3\envs\pytorch_ev\lib\site-packages\torch\nn\functional.py in log_softmax(input, dim, _stacklevel, dtype)
#    1314         dim = _get_softmax_dim('log_softmax', input.dim(), _stacklevel)
#    1315     if dtype is None:
# -> 1316         ret = input.log_softmax(dim)
#    1317     else:
#    1318         ret = input.log_softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# CPU 에서 GPU 로 옮겨서 해보자

# %%
model.to(dev)
# Out:
# NPLM(
#   (emb): Embedding(83593, 100)
#   (lin1): Linear(in_features=400, out_features=120, bias=True)
#   (lin2): Linear(in_features=120, out_features=83593, bias=False)
#   (lin3): Linear(in_features=400, out_features=83593, bias=True)
# )

# %%
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# GPU time
start = time.time()

epoch = 1
loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        x,y = x.to(dev), y.to(dev)
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % 50 == 0:        
            loss_list.append(loss_sum/50)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}s'.format(epo, i, loss_sum/50, time.time()-start))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 0.23, Elapsed time : 1s
# Epoch : 0, Iteration : 50, Loss : 8.84, Elapsed time : 2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-d4f6fb487592> in <module>
#      18         optimizer.step()
#      19
# ---> 20         loss_sum += loss.item()
#      21
#      22
#
# KeyboardInterrupt:

# %% [markdown]
# 대략 43/2 = 20배 정도 빨라짐... 갓 GPU

# %%
check = 50
epoch = 1

# %%
# GPU time
start = time.time()

loss_list = []

for epo in range(epoch):
    loss_sum = 0
    for i, (x, y) in enumerate(input_loader):

        x,y = x.to(dev), y.to(dev)
        optimizer.zero_grad()
        
        output = model(x)
        
        loss = loss_f(output, y)
        loss.backward()
        optimizer.step()
        
        loss_sum += loss.item()
        
        
        if i % check == 0:        
            elap = int(time.time() - start)
            loss_list.append(loss_sum/check)
            print('Epoch : {}, Iteration : {}, Loss : {:.2f}, Elapsed time : {:.0f}h {:.0f}m {}s'.format(\
                epo, i, loss_sum / check, elap // 3600, (elap % 3600) // 60, str(int((elap % 3600) % 60))))
            loss_sum = 0
# Out:
# Epoch : 0, Iteration : 0, Loss : 11.71, Elapsed time : 0h 0m 0s
# Epoch : 0, Iteration : 50, Loss : 7.29, Elapsed time : 0h 0m 2s
# Epoch : 0, Iteration : 100, Loss : 8.09, Elapsed time : 0h 0m 4s
# Epoch : 0, Iteration : 150, Loss : 9.08, Elapsed time : 0h 0m 6s
# Epoch : 0, Iteration : 200, Loss : 7.75, Elapsed time : 0h 0m 9s
# Epoch : 0, Iteration : 250, Loss : 8.59, Elapsed time : 0h 0m 11s
# Epoch : 0, Iteration : 300, Loss : 8.80, Elapsed time : 0h 0m 13s
# Epoch : 0, Iteration : 350, Loss : 9.84, Elapsed time : 0h 0m 15s
# Epoch : 0, Iteration : 400, Loss : 7.24, Elapsed time : 0h 0m 17s
# Epoch : 0, Iteration : 450, Loss : 11.60, Elapsed time : 0h 0m 20s
# Epoch : 0, Iteration : 500, Loss : 10.25, Elapsed time : 0h 0m 22s
# Epoch : 0, Iteration : 550, Loss : 11.53, Elapsed time : 0h 0m 24s
# Epoch : 0, Iteration : 600, Loss : 8.65, Elapsed time : 0h 0m 26s
# Epoch : 0, Iteration : 650, Loss : 5.32, Elapsed time : 0h 0m 28s
# Epoch : 0, Iteration : 700, Loss : 6.30, Elapsed time : 0h 0m 30s
# Epoch : 0, Iteration : 750, Loss : 2.89, Elapsed time : 0h 0m 32s
# Epoch : 0, Iteration : 800, Loss : 9.32, Elapsed time : 0h 0m 35s
# Epoch : 0, Iteration : 850, Loss : 9.71, Elapsed time : 0h 0m 37s

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-29b7a1fcada4> in <module>
#       8     for i, (x, y) in enumerate(input_loader):
#       9
# ---> 10         x,y = x.to(dev), y.to(dev)
#      11         optimizer.zero_grad()
#      12
#
# KeyboardInterrupt:

# %%
loss_list
# Out:
# [0.003563351058959961,
#  13.123785223007202,
#  13.492133664274215,
#  13.564518530368805,
#  13.924038747167588,
#  13.55278368525505,
#  13.879526993656158,
#  13.939610819435119,
#  13.943178425955772,
#  14.069551542043685,
#  14.337765142202377,
#  14.322136184215546,
#  14.232685096621513,
#  0.003597103500366211,
#  14.186336327838898,
#  14.51185095744133,
#  14.517371007347107,
#  14.828369925546646,
#  14.427447749996185,
#  14.717003632831574,
#  14.792902677345277,
#  14.732264914655685,
#  14.84330802230835,
#  15.110435535907746,
#  15.022088447093964,
#  14.922924023413659,
#  0.003869637680053711,
#  14.880918966674805,
#  15.217119395256043,
#  15.216982422828675,
#  15.522061238908767,
#  15.051010897541046,
#  15.33235601530075,
#  15.411670415019989,
#  15.284757848501206,
#  15.417456178379059,
#  15.634889381933212,
#  15.572572169685364,
#  15.46329218173027,
#  0.004076978302001953,
#  15.451665096759797,
#  15.753724389648438,
#  15.753408852767944,
#  16.036329578113556,
#  15.547572630214692,
#  15.87678755493164,
#  15.87316877374649,
#  15.761853644824027,
#  15.893808547782898,
#  16.132630137014388,
#  16.065691745090486,
#  15.927163265180587]

# %%
plt.plot(loss_list)

# %%
save_path = 'NPLM_{}epoch.pt'.format(epoch)
torch.save(model.state_dict(), save_path)

# %%
for data in model.emb.parameters():
    nplm_matrix = data

# %%
nplm_matrix
# Out:
# Parameter containing:
# tensor([[-1.5547, -1.6560, -2.5690,  ...,  0.2747,  0.7930, -1.5978],
#         [ 3.8324, -0.7555, -0.3985,  ..., -1.9352, -1.5792, -0.8591],
#         [-2.1034, -1.4747, -0.8482,  ...,  0.4838,  1.0369,  1.6503],
#         ...,
#         [ 0.6600, -2.3893, -0.4946,  ...,  0.7379, -0.7645,  2.1367],
#         [-1.1037,  0.1370,  2.3035,  ..., -1.9119, -0.9394, -0.0061],
#         [-0.0583,  0.2920, -0.8484,  ..., -0.7517, -0.2395,  0.7358]],
#        device='cuda:0', requires_grad=True)

# %%
from copy import deepcopy

# %%
save_path = 'NPLM_1epoch.pt'
model = NPLM(N, VEC_DIM, HIDDEN_DIM)
model.load_state_dict(torch.load(save_path))
model.eval()
# Out:
# NPLM(
#   (emb): Embedding(83593, 100)
#   (lin1): Linear(in_features=300, out_features=100, bias=True)
#   (lin2): Linear(in_features=100, out_features=83593, bias=False)
#   (lin3): Linear(in_features=300, out_features=83593, bias=True)
# )

# %%
def similar_words(model, word, k=10):
    cos = nn.CosineSimilarity(dim=1, eps=1e-6)
    
    word_id = torch.tensor([word_to_id[word]])
    word_vec = model.emb(word_id)
    word_mat = next(iter(model.emb.parameters())).detach()
    
    cos_mat = cos(word_vec, word_mat)
    sim, indices = torch.topk(cos_mat,k+1)
    
    
    word_list = []
    for i in indices:
        if i != word_id:
            word_list.append(id_to_word[i])
    return word_list, sim[1:].detach()

# %%
similar_words(model, '대학교')
# Out:
# (['배수갑문', '연출가', 'Morello', '邊', '레거', '마그다', '러브', '회전자', 'ich', '교습소'],
#  tensor([0.4228, 0.4067, 0.4058, 0.3882, 0.3865, 0.3797, 0.3795, 0.3750, 0.3631,
#          0.3594]))
